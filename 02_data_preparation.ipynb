# %% [markdown]
# # 02 Data Prep

# %%
# common imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sys
from datetime import datetime
import sklearn 

sys.executable
# Out:
# '/opt/anaconda3/bin/python'

# %%
# will display all the columns in the df moving forward
pd.set_option('display.max_columns', 500)

# %%
# viewing the paths connected to this file
sys.path
# Out:
# ['/Users/mirror/Desktop/GitHub/NFL_Game_Predictor',
#  '/opt/anaconda3/lib/python38.zip',
#  '/opt/anaconda3/lib/python3.8',
#  '/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/Users/mirror/.local/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/mirror/.ipython']

# %%
# Importing the data from a csv file
# avoid using hard coded paths like the next two lines
# path = "/Users/mirror/Desktop/GitHub/nfl_game_predictor/data/scraped_data.csv"
# df = pd.read_csv(path) # instead, use this

from src.config import DATA_DIR
path = DATA_DIR / 'scraped_data.csv'
df = pd.read_csv(path)

# previewing the data
df.head(30)
# Out:
#     season team       week  day          date        time result   ot record  \
# 0     2022  BUF          1  Thu   September 8   8:20PM ET      W  NaN    1-0
# 1     2022  BUF          2  Mon  September 19   7:15PM ET      W  NaN    2-0
# 2     2022  BUF          3  Sun  September 25   1:00PM ET      L  NaN    2-1
# 3     2022  BUF          4  Sun     October 2   1:00PM ET      W  NaN    3-1
# 4     2022  BUF          5  Sun     October 9   1:00PM ET      W  NaN    4-1
# 5     2022  BUF          6  Sun    October 16   4:25PM ET      W  NaN    5-1
# 6     2022  BUF          8  Sun    October 30   8:20PM ET      W  NaN    6-1
# 7     2022  BUF          9  Sun    November 6   1:00PM ET      L  NaN    6-2
# 8     2022  BUF         10  Sun   November 13   1:00PM ET      L   OT    6-3
# 9     2022  BUF         11  Sun   November 20   1:00PM ET      W  NaN    7-3
# 10    2022  BUF         12  Thu   November 24  12:30PM ET      W  NaN    8-3
# 11    2022  BUF         13  Thu    December 1   8:15PM ET      W  NaN    9-3
# 12    2022  BUF         14  Sun   December 11   1:00PM ET      W  NaN   10-3
# 13    2022  BUF         15  Sat   December 17   8:15PM ET      W  NaN   11-3
# 14    2022  BUF         16  Sat   December 24   1:00PM ET      W  NaN   12-3
# 15    2022  BUF         17  Mon     January 2   8:30PM ET      -  NaN   12-3
# 16    2022  BUF         18  Sun     January 8   1:00PM ET      W  NaN   13-3
# 17    2022  BUF  Wild Card  Sun    January 15   1:00PM ET      W  NaN   14-3
# 18    2022  BUF   Division  Sun    January 22   3:00PM ET      L  NaN   14-4
# 19    2022  MIA          1  Sun  September 11   1:00PM ET      W  NaN    1-0
# 20    2022  MIA          2  Sun  September 18   1:00PM ET      W  NaN    2-0
# 21    2022  MIA          3  Sun  September 25   1:00PM ET      W  NaN    3-0
# 22    2022  MIA          4  Thu  September 29   8:15PM ET      L  NaN    3-1
# 23    2022  MIA          5  Sun     October 9   1:00PM ET      L  NaN    3-2
# 24    2022  MIA          6  Sun    October 16   1:00PM ET      L  NaN    3-3
# 25    2022  MIA          7  Sun    October 23   8:20PM ET      W  NaN    4-3
# 26    2022  MIA          8  Sun    October 30   1:00PM ET      W  NaN    5-3
# 27    2022  MIA          9  Sun    November 6   1:00PM ET      W  NaN    6-3
# 28    2022  MIA         10  Sun   November 13   1:00PM ET      W  NaN    7-3
# 29    2022  MIA         12  Sun   November 27   1:00PM ET      W  NaN    8-3
#
#       @                   opp points_scored points_allowed 1st_downs  \
# 0     @      Los Angeles Rams            31             10        23
# 1   NaN      Tennessee Titans            41              7        23
# 2     @        Miami Dolphins            19             21        31
# 3     @      Baltimore Ravens            23             20        22
# 4   NaN   Pittsburgh Steelers            38              3        21
# 5     @    Kansas City Chiefs            24             20        26
# 6   NaN     Green Bay Packers            27             17        20
# 7     @         New York Jets            17             20        19
# 8   NaN     Minnesota Vikings            30             33        29
# 9   NaN      Cleveland Browns            31             23        22
# 10    @         Detroit Lions            28             25        28
# 11    @  New England Patriots            24             10        22
# 12  NaN         New York Jets            20             12        14
# 13  NaN        Miami Dolphins            32             29        29
# 14    @         Chicago Bears            35             13        20
# 15    @    Cincinnati Bengals      Canceled       Canceled  Canceled
# 16  NaN  New England Patriots            35             23        18
# 17  NaN        Miami Dolphins            34             31        25
# 18  NaN    Cincinnati Bengals            10             27        19
# 19  NaN  New England Patriots          20.0            7.0      18.0
# 20    @      Baltimore Ravens          42.0           38.0      27.0
# 21  NaN         Buffalo Bills          21.0           19.0      15.0
# 22    @    Cincinnati Bengals          15.0           27.0      20.0
# 23    @         New York Jets          17.0           40.0      19.0
# 24  NaN     Minnesota Vikings          16.0           24.0      23.0
# 25  NaN   Pittsburgh Steelers          16.0           10.0      17.0
# 26    @         Detroit Lions          31.0           27.0      27.0
# 27    @         Chicago Bears          35.0           32.0      21.0
# 28  NaN      Cleveland Browns          39.0           17.0      29.0
# 29  NaN        Houston Texans          30.0           15.0      25.0
#
#        totyd    passyd    rushyd        to 1st_downs_allowed totyd_allowed  \
# 0        413       292       121         4                19           243
# 1        414       313       101       NaN                12           187
# 2        497       382       115         1                15           212
# 3        326       201       125         2                22           296
# 4        552       432       120         2                23           364
# 5        443       318       125         1                23           387
# 6        369       216       153         2                21           398
# 7        317       183       134         2                21           310
# 8        486       311       175         4                24           481
# 9        357       186       171       NaN                27           396
# 10       401       237       164         1                22           326
# 11       355       223       132         1                14           242
# 12       232       130       102       NaN                19           309
# 13       446       296       150         1                20           405
# 14       426       172       254         3                11           209
# 15  Canceled  Canceled  Canceled  Canceled          Canceled      Canceled
# 16       327       237        90         3                20           341
# 17       423       316       107         3                16           231
# 18       325       261        64         1                30           412
# 19     307.0     242.0      65.0       NaN              17.0         271.0
# 20     547.0     461.0      86.0       2.0              23.0         473.0
# 21     212.0     171.0      41.0       NaN              31.0         497.0
# 22     378.0     293.0      85.0       2.0              16.0         371.0
# 23     295.0     158.0     137.0       2.0              21.0         322.0
# 24     458.0     385.0      73.0       3.0              11.0         234.0
# 25     372.0     261.0     111.0       NaN              19.0         341.0
# 26     476.0     369.0     107.0       1.0              22.0         393.0
# 27     379.0     302.0      77.0       NaN              23.0         368.0
# 28     491.0     296.0     195.0       NaN              20.0         297.0
# 29     339.0     273.0      66.0       1.0              14.0         210.0
#
#    passyd_allowed rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts
# 0             191             52         3       13.89       10.29       -3.96
# 1             107             80         4       17.69       18.01        1.55
# 2             171             41       NaN       15.88       -7.45       -4.86
# 3             134            162         2        2.10        2.66       -1.69
# 4             310             54         2       20.66        9.42        3.54
# 5             319             68         2       11.13       -6.45        0.56
# 6             190            208         1       12.79       -5.55        4.01
# 7             136            174         1        0.54       -7.64        2.11
# 8             334            147         2        1.45       -4.80       -0.39
# 9             316             80         1        6.00      -10.86       13.72
# 10            230             96         2       16.07      -12.71       -3.07
# 11            182             60       NaN        9.50        1.41        3.26
# 12            233             76         2       -5.17       12.35        3.77
# 13            217            188       NaN       19.07      -10.87       -4.20
# 14            129             80         2        9.47       20.55       -9.39
# 15       Canceled       Canceled  Canceled    Canceled    Canceled    Canceled
# 16            234            107         3        5.28        2.57        7.70
# 17            189             42         2       -2.41       15.56       -6.64
# 18            240            172       NaN        3.52      -22.03        1.83
# 19          193.0           78.0       3.0        6.08        8.28        1.98
# 20          318.0          155.0       NaN        32.0      -20.31       -7.09
# 21          382.0          115.0       1.0        7.45      -15.88        4.86
# 22          304.0           67.0       NaN        0.48       -9.11       -3.73
# 23          187.0          135.0       NaN       -6.15      -11.86       -3.66
# 24          156.0           78.0       NaN       -8.38        4.43       -4.75
# 25          246.0           95.0       3.0        0.04        6.72       -2.49
# 26          311.0           82.0       NaN       25.47      -19.14       -0.59
# 27          116.0          252.0       NaN       19.83      -17.18        2.01
# 28          185.0          112.0       1.0        28.5        1.04       -4.93
# 29          174.0           36.0       3.0        -1.9       22.74       -3.97

# %% [markdown]
# ### Quick Exploration

# %%
df.shape
# Out:
# (15322, 26)

# %%
df.dtypes
# Out:
# season                int64
# team                 object
# week                 object
# day                  object
# date                 object
# time                 object
# result               object
# ot                   object
# record               object
# @                    object
# opp                  object
# points_scored        object
# points_allowed       object
# 1st_downs            object
# totyd                object
# passyd               object
# rushyd               object
# to                   object
# 1st_downs_allowed    object
# totyd_allowed        object
# passyd_allowed       object
# rushyd_allowed       object
# to_forced            object
# off_exp_pts          object
# def_exp_pts          object
# sts_exp_pts          object
# dtype: object

# %%
# determining how many missing values are in each column
df.isnull().sum()
# Out:
# season                   0
# team                     0
# week                     0
# day                      0
# date                     0
# time                     0
# result                   0
# ot                   14374
# record                   0
# @                     7632
# opp                      0
# points_scored            0
# points_allowed           0
# 1st_downs                0
# totyd                    0
# passyd                   2
# rushyd                   0
# to                    3378
# 1st_downs_allowed        0
# totyd_allowed            0
# passyd_allowed           2
# rushyd_allowed           0
# to_forced             3378
# off_exp_pts              0
# def_exp_pts              0
# sts_exp_pts              0
# dtype: int64

# %%
# determining how many missing values are in specific column(s)
df['ot'].isnull().sum()
# Out:
# 14374

# %%
# discovering how many times an opponent played a game
df.opp.value_counts()
# Out:
# New England Patriots        515
# Green Bay Packers           507
# Pittsburgh Steelers         502
# Philadelphia Eagles         499
# Indianapolis Colts          498
# San Francisco 49ers         496
# Seattle Seahawks            495
# Kansas City Chiefs          491
# Denver Broncos              489
# Dallas Cowboys              488
# Minnesota Vikings           488
# New Orleans Saints          485
# New York Giants             485
# Tampa Bay Buccaneers        484
# Atlanta Falcons             484
# Cincinnati Bengals          480
# Buffalo Bills               480
# New York Jets               480
# Miami Dolphins              480
# Arizona Cardinals           478
# Chicago Bears               477
# Detroit Lions               473
# Carolina Panthers           467
# Jacksonville Jaguars        466
# Baltimore Ravens            462
# Washington Redskins         423
# Cleveland Browns            423
# Oakland Raiders             408
# Tennessee Titans            404
# San Diego Chargers          382
# Houston Texans              348
# St. Louis Rams              346
# Los Angeles Rams            140
# Los Angeles Chargers        101
# Las Vegas Raiders            51
# Houston Oilers               48
# Washington Football Team     34
# Tennessee Oilers             32
# Washington Commanders        17
# Los Angeles Raiders          16
# Name: opp, dtype: int64

# %% [markdown]
# ### SweeetViz

# %%
# # importing a new library that was recommended to me by my mentor
# import sweetviz as sv

# df_report = sv.analyze(df)
# df_report.show_html()
# #df_report.show_notebook()

# %%
# compares two dataframes via sweetviz
#df_comp = sv.compare(df)

# %%
# another way to get great insights is to use the comparison functionality to split your dataset into 2 sub-populations.
#df_comp_intra = sv.compare_intra(df)

# %% [markdown]
# ### Initial Data Cleansing

# %%
# there are only supposed to be 32 teams in the NFL. some teams have changed their name and/or location.
len(df.opp.unique())
# Out:
# 40

# %%
# some teams have changed their name and/or location, which created another opponent.
# manually replacing team names.
df.loc[df["opp"] == "Washington Redskins", "opp"] = "Washington Commanders"
df.loc[df["opp"] == "Washington Football Team", "opp"] = "Washington Commanders"
df.loc[df["opp"] == "Oakland Raiders", "opp"] = "Las Vegas Raiders"
df.loc[df["opp"] == "Los Angeles Raiders", "opp"] = "Las Vegas Raiders"
df.loc[df["opp"] == "Houston Oilers", "opp"] = "Tennessee Titans"
df.loc[df["opp"] == "Tennessee Oilers", "opp"] = "Tennessee Titans"
df.loc[df["opp"] == "San Diego Chargers", "opp"] = "Los Angeles Chargers"
df.loc[df["opp"] == "St. Louis Rams", "opp"] = "Los Angeles Rams"

# %%
# verifying that there are only 32 teams in the df.opp column now.
len(df.opp.unique())
# Out:
# 32

# %%
# first sort the df by season and week
df = df.sort_values(by=['season', 'week'], ascending=[False, True])

# %%
# reset index ###########
df = df.reset_index(drop=True)

# %%
# right now, we have two records for each game played because we scraped the data for each team's season
# we need to reduce the df to only have one record for each game played
# there should only be 16 week 1 entries for a given season, but here we have 32 week 1 entries
df.head(33)
# Out:
#     season team week  day          date       time result   ot record    @  \
# 0     2022  BUF    1  Thu   September 8  8:20PM ET      W  NaN    1-0    @
# 1     2022  MIA    1  Sun  September 11  1:00PM ET      W  NaN    1-0  NaN
# 2     2022   NE    1  Sun  September 11  1:00PM ET      L  NaN    0-1    @
# 3     2022  NYJ    1  Sun  September 11  1:00PM ET      L  NaN    0-1  NaN
# 4     2022  CIN    1  Sun  September 11  1:00PM ET      L   OT    0-1  NaN
# 5     2022  BAL    1  Sun  September 11  1:00PM ET      W  NaN    1-0    @
# 6     2022  PIT    1  Sun  September 11  1:00PM ET      W   OT    1-0    @
# 7     2022  CLE    1  Sun  September 11  1:00PM ET      W  NaN    1-0    @
#
# 13           64.0       3.0         6.3        2.73       -1.95
# 14           76.0       NaN       -2.73        -6.3        1.95
# 15           76.0       1.0        9.94        -4.1       -6.84
# 16          181.0       1.0       21.15      -15.67       -0.78
# 17          152.0       1.0       -19.4       -0.55        2.24
# 18           93.0       1.0        3.72       -5.97        2.44
# 19          123.0       1.0        9.54       -3.64        0.26
# 20          111.0       2.0        9.99        1.89        1.12
# 21          216.0       NaN       15.67      -21.15        0.78
# 22          126.0       NaN       -1.89       -9.99       -1.12
# 23          176.0       2.0        0.67       11.26       -0.42
# 24           71.0       1.0        0.55        19.4       -2.24
# 25          217.0       NaN        5.38       -6.82       -1.66
# 26          201.0       2.0        4.62        -7.5       -0.51
# 27          151.0       1.0         7.5       -4.62        0.51
# 28           99.0       1.0      -11.26       -0.67        0.42
# 29          103.0       2.0         4.1       -9.94        6.84
# 30          121.0       4.0      -10.29      -13.89        3.96
# 31          128.0       1.0        2.29      -33.41        6.88
# 32            147         2        1.45       -4.80       -0.39

# %%
# Team name column was also abbreviated, so it needs to match to the opp name column too
# y will be the list of team names from the opp column
# z will be the list of team abbrviations from the team column
z = set(df['team'].values.tolist())
y = set(df['opp'].values.tolist())
z = list(z)
z.sort()
y = list(y)
y.sort()

# %%
# verifying that the opp list only has 32 unqiue teams now
len(y)
len(set(y))
# Out:
# 32

# %%
y
# Out:
# ['Arizona Cardinals',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'Jacksonville Jaguars',
#  'Kansas City Chiefs',
#  'Las Vegas Raiders',
#  'Los Angeles Chargers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Tennessee Titans',
#  'Washington Commanders']

# %%
# we must reorder a couple of teams in z so that it matches y
z
# Out:
# ['ARZ',
#  'ATL',
#  'BAL',
#  'BUF',
#  'CAR',
#  'CHI',
#  'CIN',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GB',
#  'HOU',
#  'IND',
#  'JAX',
#  'KC',
#  'LAC',
#  'LAR',
#  'LV',
#  'MIA',
#  'MIN',
#  'NE',
#  'NO',
#  'NYG',
#  'NYJ',
#  'PHI',
#  'PIT',
#  'SEA',
#  'SF',
#  'TB',
#  'TEN',
#  'WAS']

# %%
z = z[0:16] + z[18:19] + z[16:17] + z[17:18] + z[19:-5] + z[-4:-3] + z[-5:-4] + z[-3:]
z
# Out:
# ['ARZ',
#  'ATL',
#  'BAL',
#  'BUF',
#  'CAR',
#  'CHI',
#  'CIN',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GB',
#  'HOU',
#  'IND',
#  'JAX',
#  'KC',
#  'LV',
#  'LAC',
#  'LAR',
#  'MIA',
#  'MIN',
#  'NE',
#  'NO',
#  'NYG',
#  'NYJ',
#  'PHI',
#  'PIT',
#  'SF',
#  'SEA',
#  'TB',
#  'TEN',
#  'WAS']

# %%
print(len(z))
print(len(set(z)))
# Out:
# 32
# 32

# %%
# creating dictionary with the two lists (z & y)
team_dict = dict(zip(z, y))
len(team_dict)
# Out:
# 32

# %%
# using the manually created team_dictionary to replace the team names.
df = df.replace({"team": team_dict})

# %%
df
# Out:
#        season                  team       week  day          date        time  \
# 0        2022         Buffalo Bills          1  Thu   September 8   8:20PM ET
# 1        2022        Miami Dolphins          1  Sun  September 11   1:00PM ET
# 2        2022  New England Patriots          1  Sun  September 11   1:00PM ET
# 3        2022         New York Jets          1  Sun  September 11   1:00PM ET
# 4        2022    Cincinnati Bengals          1  Sun  September 11   1:00PM ET
# ...       ...                   ...        ...  ...           ...         ...
# 15317    1994    Kansas City Chiefs  Wild Card  Sat   December 31   4:00PM ET
# 15318    1994     Minnesota Vikings  Wild Card  Sun     January 1   4:00PM ET
# 15319    1994     Green Bay Packers  Wild Card  Sat   December 31  12:30PM ET
# 15320    1994         Detroit Lions  Wild Card  Sat   December 31  12:30PM ET
# 15321    1994         Chicago Bears  Wild Card  Sun     January 1   4:00PM ET
#
#       result   ot record    @                   opp points_scored  \
# 0          W  NaN    1-0    @      Los Angeles Rams            31
# 1          W  NaN    1-0  NaN  New England Patriots          20.0
# 2          L  NaN    0-1    @        Miami Dolphins           7.0
# 3          L  NaN    0-1  NaN      Baltimore Ravens           9.0
# 4          L   OT    0-1  NaN   Pittsburgh Steelers            20
# ...      ...  ...    ...  ...                   ...           ...
# 15317      L  NaN    9-8    @        Miami Dolphins          17.0
# 15318      L  NaN   10-7  NaN         Chicago Bears          18.0
# 15319      W  NaN   10-7  NaN         Detroit Lions          16.0
# 15320      L  NaN    9-8    @     Green Bay Packers          12.0
# 15321      W  NaN   10-7    @     Minnesota Vikings          35.0
#
#       points_allowed 1st_downs  totyd passyd rushyd   to 1st_downs_allowed  \
# 0                 10        23    413    292    121    4                19
# 1                7.0      18.0  307.0  242.0   65.0  NaN              17.0
# 2               20.0      17.0  271.0  193.0   78.0  3.0              18.0
# 3               24.0      24.0  380.0  297.0   83.0  2.0              13.0
# 4                 23        32    432    299    133    5                13
# ...              ...       ...    ...    ...    ...  ...               ...
# 15317           27.0      24.0  414.0  314.0  100.0  2.0              22.0
# 15318           35.0      22.0  389.0  340.0   49.0  4.0              18.0
# 15319           12.0      18.0  336.0  255.0   81.0  NaN               9.0
# 15320           16.0       9.0  171.0  175.0   -4.0  NaN              18.0
# 15321           18.0      18.0  308.0  214.0   94.0  2.0              22.0
#
#       totyd_allowed passyd_allowed rushyd_allowed to_forced off_exp_pts  \
# 0               243            191             52         3       13.89
# 1             271.0          193.0           78.0       3.0        6.08
# 2             307.0          242.0           65.0       NaN       -8.28
# 3             274.0          211.0           63.0       1.0       -8.07
# 4               267            192             75       NaN       -7.49
# ...             ...            ...            ...       ...         ...
# 15317         381.0          249.0          132.0       NaN        8.31
# 15318         308.0          214.0           94.0       2.0       -9.54
# 15319         171.0          175.0           -4.0       NaN       -2.93
# 15320         336.0          255.0           81.0       NaN      -11.53
# 15321         389.0          340.0           49.0       4.0        6.07
#
#       def_exp_pts sts_exp_pts
# 0           10.29       -3.96
# 1            8.28        1.98
# 2           -6.08       -1.98
# 3           -3.65       -5.04
# 4            8.41       -4.85
# ...           ...         ...
# 15317      -15.96       -1.16
# 15318       -6.07        0.65
# 15319       11.53        0.69
# 15320        2.93       -0.69
# 15321        9.54       -0.65
#
# [15322 rows x 26 columns]

# %%
# create home team and away team columns. this will replace the "opp" and "team" columns.
# which will get me towards my goal of having one record per game instead of two.
# it was difficult for me to vectorize this transformation so I used a for loop instead
h = []
a = [] 
count = 0

# organizing teams by conference since the Super Bowl home/away teams are selected this way
afc = ['Baltimore Ravens', 'Buffalo Bills', 'Cincinnati Bengals', 'Cleveland Browns', 'Denver Broncos', 'Houston Texans', 
       'Indianapolis Colts', 'Jacksonville Jaguars', 'Kansas City Chiefs', 'Las Vegas Raiders','Los Angeles Chargers', 
       'Miami Dolphins', 'New England Patriots', 'New York Jets', 'Pittsburgh Steelers', 'Tennessee Titans']

nfc = ['Arizona Cardinals', 'Atlanta Falcons', 'Carolina Panthers', 'Chicago Bears', 'Dallas Cowboys', 'Detroit Lions',
       'Green Bay Packers', 'Los Angeles Rams', 'Minnesota Vikings', 'New Orleans Saints', 'New York Giants',
       'Philadelphia Eagles', 'San Francisco 49ers', 'Seattle Seahawks', 'Tampa Bay Buccaneers', 'Washington Commanders']


for i in df['@']:
    if '@' in str(i): # the presence of a @ symbol represents the team entry as the away team and the opp team entry as the home team
        h.append(df['opp'].iloc[count])
        a.append(df['team'].iloc[count])
        
            # we must determine which teams are the home teams and away teams for the SB. 
            # even year = AFC team is the home team for the SB, odd year = NFC team is the home team for the SB
            # the game is played on neutral ground where the location (typically a new stadium) is determined years in advance
            
    elif 'N' in str(i): # this entire elif block is to organize the home/away teams in a neutral 'N' stadium specifically for SuperBowls
        if int(df['season'].iloc[count])%2 == 0:
            if df['team'].iloc[count] in afc:
                h.append(df['team'].iloc[count])
                a.append(df['opp'].iloc[count])
            else: 
                h.append(df['opp'].iloc[count])
                a.append(df['team'].iloc[count])
        else:
            if df['team'].iloc[count] in nfc:
                h.append(df['team'].iloc[count])
                a.append(df['opp'].iloc[count])
            else:
                h.append(df['opp'].iloc[count])
                a.append(df['team'].iloc[count])
                
    else:    # the lack of @ symbol represents the team entry as the home team and the opp team entry as the away team
        h.append(df['team'].iloc[count])
        a.append(df['opp'].iloc[count])
    count += 1 # this counter allows me to iterate through the column one-by-one

# using the lists h & a to create new home_team and away_team columns in the dataframe
df = df.assign(away_t = a)
df = df.assign(home_t = h)

# %%
# attemping a vectorized version of the above ^^^, but this fails to drop duplicate records later on
# so keep the above code for now
###afc = ['Baltimore Ravens', 'Buffalo Bills', 'Cincinnati Bengals', 'Cleveland Browns', 
###       'Denver Broncos', 'Houston Texans', 'Indianapolis Colts', 'Jacksonville Jaguars', 
###       'Kansas City Chiefs', 'Las Vegas Raiders','Los Angeles Chargers', 'Miami Dolphins', 
###       'New England Patriots', 'New York Jets', 'Pittsburgh Steelers', 'Tennessee Titans']

###nfc = ['Arizona Cardinals', 'Atlanta Falcons', 'Carolina Panthers', 'Chicago Bears', 
###       'Dallas Cowboys', 'Detroit Lions', 'Green Bay Packers', 'Los Angeles Rams', 
###       'Minnesota Vikings', 'New Orleans Saints', 'New York Giants', 'Philadelphia Eagles', 
###       'San Francisco 49ers', 'Seattle Seahawks', 'Tampa Bay Buccaneers', 'Washington Commanders']

###def create_home_away_teams(df):
###    df['away_t'] = np.where(df['@'].str.contains('@'), df['team'], np.where(df['@'].str.contains('N'), 
###                           np.where(df['season'].astype(int) % 2 == 0, np.where(df['team'].isin(afc), df['opp'], df['team']), 
###                           np.where(df['team'].isin(nfc), df['opp'], df['team'])), df['opp']))
###    df['home_t'] = np.where(df['@'].str.contains('@'), df['opp'], np.where(df['@'].str.contains('N'), 
###                           np.where(df['season'].astype(int) % 2 == 0, np.where(df['team'].isin(afc), df['team'], df['opp']), 
###                           np.where(df['team'].isin(nfc), df['team'], df['opp'])), df['team']))
###    return df

###df = create_home_away_teams(df)

# %%
df
# Out:
#        season                  team       week  day          date        time  \
# 0        2022         Buffalo Bills          1  Thu   September 8   8:20PM ET
# 1        2022        Miami Dolphins          1  Sun  September 11   1:00PM ET
# 2        2022  New England Patriots          1  Sun  September 11   1:00PM ET
# 3        2022         New York Jets          1  Sun  September 11   1:00PM ET
# 4        2022    Cincinnati Bengals          1  Sun  September 11   1:00PM ET
# ...       ...                   ...        ...  ...           ...         ...
# 15317    1994    Kansas City Chiefs  Wild Card  Sat   December 31   4:00PM ET
# 15318    1994     Minnesota Vikings  Wild Card  Sun     January 1   4:00PM ET
# 15319    1994     Green Bay Packers  Wild Card  Sat   December 31  12:30PM ET
# 15320    1994         Detroit Lions  Wild Card  Sat   December 31  12:30PM ET
# 15321    1994         Chicago Bears  Wild Card  Sun     January 1   4:00PM ET
#
#       result   ot record    @                   opp points_scored  \
# 0          W  NaN    1-0    @      Los Angeles Rams            31
# 1          W  NaN    1-0  NaN  New England Patriots          20.0
# 2          L  NaN    0-1    @        Miami Dolphins           7.0
# 3          L  NaN    0-1  NaN      Baltimore Ravens           9.0
# 4          L   OT    0-1  NaN   Pittsburgh Steelers            20
# ...      ...  ...    ...  ...                   ...           ...
# 15317      L  NaN    9-8    @        Miami Dolphins          17.0
# 15318      L  NaN   10-7  NaN         Chicago Bears          18.0
# 15319      W  NaN   10-7  NaN         Detroit Lions          16.0
# 15320      L  NaN    9-8    @     Green Bay Packers          12.0
# 15321      W  NaN   10-7    @     Minnesota Vikings          35.0
#
#       points_allowed 1st_downs  totyd passyd rushyd   to 1st_downs_allowed  \
# 0                 10        23    413    292    121    4                19
# 1                7.0      18.0  307.0  242.0   65.0  NaN              17.0
# 2               20.0      17.0  271.0  193.0   78.0  3.0              18.0
# 3               24.0      24.0  380.0  297.0   83.0  2.0              13.0
# 4                 23        32    432    299    133    5                13
# ...              ...       ...    ...    ...    ...  ...               ...
# 15317           27.0      24.0  414.0  314.0  100.0  2.0              22.0
# 15318           35.0      22.0  389.0  340.0   49.0  4.0              18.0
# 15319           12.0      18.0  336.0  255.0   81.0  NaN               9.0
# 15320           16.0       9.0  171.0  175.0   -4.0  NaN              18.0
# 15321           18.0      18.0  308.0  214.0   94.0  2.0              22.0
#
#       totyd_allowed passyd_allowed rushyd_allowed to_forced off_exp_pts  \
# 0               243            191             52         3       13.89
# 1             271.0          193.0           78.0       3.0        6.08
# 2             307.0          242.0           65.0       NaN       -8.28
# 3             274.0          211.0           63.0       1.0       -8.07
# 4               267            192             75       NaN       -7.49
# ...             ...            ...            ...       ...         ...
# 15317         381.0          249.0          132.0       NaN        8.31
# 15318         308.0          214.0           94.0       2.0       -9.54
# 15319         171.0          175.0           -4.0       NaN       -2.93
# 15320         336.0          255.0           81.0       NaN      -11.53
# 15321         389.0          340.0           49.0       4.0        6.07
#
#       def_exp_pts sts_exp_pts                away_t              home_t
# 0           10.29       -3.96         Buffalo Bills    Los Angeles Rams
# 1            8.28        1.98  New England Patriots      Miami Dolphins
# 2           -6.08       -1.98  New England Patriots      Miami Dolphins
# 3           -3.65       -5.04      Baltimore Ravens       New York Jets
# 4            8.41       -4.85   Pittsburgh Steelers  Cincinnati Bengals
# ...           ...         ...                   ...                 ...
# 15317      -15.96       -1.16    Kansas City Chiefs      Miami Dolphins
# 15318       -6.07        0.65         Chicago Bears   Minnesota Vikings
# 15319       11.53        0.69         Detroit Lions   Green Bay Packers
# 15320        2.93       -0.69         Detroit Lions   Green Bay Packers
# 15321        9.54       -0.65         Chicago Bears   Minnesota Vikings
#
# [15322 rows x 28 columns]

# %% [markdown]
# ### Reduce the number of rows per game from two to one

# %%
# we have two rows of data for each game so we will reduce it to one row for each game
df = df.drop_duplicates(subset=['season', 'week', 'home_t', 'away_t'])

# %%
# reset index
df = df.reset_index(drop=True)

# %%
df = df.sort_values(by=['season', 'week'], ascending=[False, True])
# thinks season and week columns are string datatypes

# %%
df
# Out:
#       season                  team       week  day          date        time  \
# 0       2022         Buffalo Bills          1  Thu   September 8   8:20PM ET
# 1       2022        Miami Dolphins          1  Sun  September 11   1:00PM ET
# 2       2022         New York Jets          1  Sun  September 11   1:00PM ET
# 3       2022    Cincinnati Bengals          1  Sun  September 11   1:00PM ET
# 4       2022      Cleveland Browns          1  Sun  September 11   1:00PM ET
# ...      ...                   ...        ...  ...           ...         ...
# 7656    1994  Los Angeles Chargers  SuperBowl  Sun    January 29   6:00PM ET
# 7657    1994        Miami Dolphins  Wild Card  Sat   December 31   4:00PM ET
# 7658    1994  New England Patriots  Wild Card  Sun     January 1  12:30PM ET
# 7659    1994     Minnesota Vikings  Wild Card  Sun     January 1   4:00PM ET
# 7660    1994     Green Bay Packers  Wild Card  Sat   December 31  12:30PM ET
#
#      result   ot record    @                   opp points_scored  \
# 0         W  NaN    1-0    @      Los Angeles Rams            31
# 1         W  NaN    1-0  NaN  New England Patriots          20.0
# 2         L  NaN    0-1  NaN      Baltimore Ravens           9.0
# 3         L   OT    0-1  NaN   Pittsburgh Steelers            20
# 4         W  NaN    1-0    @     Carolina Panthers          26.0
# ...     ...  ...    ...  ...                   ...           ...
# 7656      L  NaN   13-6    N   San Francisco 49ers          26.0
# 7657      W  NaN   11-6  NaN    Kansas City Chiefs          27.0
# 7658      L  NaN   10-7    @      Cleveland Browns          13.0
# 7659      L  NaN   10-7  NaN         Chicago Bears          18.0
# 7660      W  NaN   10-7  NaN         Detroit Lions          16.0
#
#      points_allowed 1st_downs  totyd passyd rushyd   to 1st_downs_allowed  \
# 0                10        23    413    292    121    4                19
# 1               7.0      18.0  307.0  242.0   65.0  NaN              17.0
# 2              24.0      24.0  380.0  297.0   83.0  2.0              13.0
# 3                23        32    432    299    133    5                13
# 4              24.0      23.0  355.0  138.0  217.0  NaN              15.0
# ...             ...       ...    ...    ...    ...  ...               ...
# 7656           49.0      20.0  354.0  287.0   67.0  3.0              28.0
# 7657           17.0      22.0  381.0  249.0  132.0  NaN              24.0
# 7658           20.0      20.0  303.0  246.0   57.0  3.0              22.0
# 7659           35.0      22.0  389.0  340.0   49.0  4.0              18.0
# 7660           12.0      18.0  336.0  255.0   81.0  NaN               9.0
#
#      totyd_allowed passyd_allowed rushyd_allowed to_forced off_exp_pts  \
# 0              243            191             52         3       13.89
# 1            271.0          193.0           78.0       3.0        6.08
# 2            274.0          211.0           63.0       1.0       -8.07
# 3              267            192             75       NaN       -7.49
# 4            261.0          207.0           54.0       1.0        6.82
# ...            ...            ...            ...       ...         ...
# 7656         455.0          316.0          139.0       NaN       -3.94
# 7657         414.0          314.0          100.0       2.0       15.96
# 7658         379.0          254.0          125.0       1.0      -11.86
# 7659         308.0          214.0           94.0       2.0       -9.54
# 7660         171.0          175.0           -4.0       NaN       -2.93
#
#      def_exp_pts sts_exp_pts                away_t                home_t
# 0          10.29       -3.96         Buffalo Bills      Los Angeles Rams
# 1           8.28        1.98  New England Patriots        Miami Dolphins
# 2          -3.65       -5.04      Baltimore Ravens         New York Jets
# 3           8.41       -4.85   Pittsburgh Steelers    Cincinnati Bengals
# 4          -5.38        1.66      Cleveland Browns     Carolina Panthers
# ...          ...         ...                   ...                   ...
# 7656      -27.02        4.06   San Francisco 49ers  Los Angeles Chargers
# 7657       -8.31        1.16    Kansas City Chiefs        Miami Dolphins
# 7658       -8.13       10.97  New England Patriots      Cleveland Browns
# 7659       -6.07        0.65         Chicago Bears     Minnesota Vikings
# 7660       11.53        0.69         Detroit Lions     Green Bay Packers
#
# [7661 rows x 28 columns]

# %%
df.head(30)
# Out:
#     season                  team week  day          date       time result  \
# 0     2022         Buffalo Bills    1  Thu   September 8  8:20PM ET      W
# 1     2022        Miami Dolphins    1  Sun  September 11  1:00PM ET      W
# 2     2022         New York Jets    1  Sun  September 11  1:00PM ET      L
# 3     2022    Cincinnati Bengals    1  Sun  September 11  1:00PM ET      L
# 4     2022      Cleveland Browns    1  Sun  September 11  1:00PM ET      W
# 5     2022  Jacksonville Jaguars    1  Sun  September 11  1:00PM ET      L
# 6     2022      Tennessee Titans    1  Sun  September 11  4:25PM ET      L
# 7     2022    Indianapolis Colts    1  Sun  September 11  1:00PM ET      T
# 8     2022    Kansas City Chiefs    1  Sun  September 11  4:25PM ET      W
# 9     2022  Los Angeles Chargers    1  Sun  September 11  4:25PM ET      W
# 10    2022        Denver Broncos    1  Mon  September 12  8:20PM ET      L
# 16            334            147         2        1.45       -4.80
# 17          185.0          112.0       1.0        28.5        1.04
# 18          157.0           29.0       2.0       13.42        10.6
# 19          331.0          155.0       3.0        3.86      -23.27
# 20          248.0           65.0       1.0       -3.15        5.39
# 21          232.0           77.0       NaN       10.87        0.17
# 22          176.0          191.0       NaN         0.4      -10.29
# 23          230.0          157.0       1.0       -7.29        -6.2
# 24          178.0          152.0       2.0       -1.89       -4.13
# 25          208.0          207.0       2.0        2.81      -17.21
# 26          150.0          258.0       1.0       13.55       -9.38
# 27          244.0           39.0       1.0        13.2        0.15
# 28          153.0          138.0       1.0        2.11        6.14
# 29          220.0           78.0       NaN       -5.36       -5.83
#
#    sts_exp_pts                 away_t                 home_t
# 0        -3.96          Buffalo Bills       Los Angeles Rams
# 1         1.98   New England Patriots         Miami Dolphins
# 2        -5.04       Baltimore Ravens          New York Jets
# 3        -4.85    Pittsburgh Steelers     Cincinnati Bengals
# 4         1.66       Cleveland Browns      Carolina Panthers
# 5        -0.26   Jacksonville Jaguars  Washington Commanders
# 6        -2.44        New York Giants       Tennessee Titans
# 7        -9.43     Indianapolis Colts         Houston Texans
# 8        -6.88     Kansas City Chiefs      Arizona Cardinals
# 9        -1.95      Las Vegas Raiders   Los Angeles Chargers
# 10       -6.84         Denver Broncos       Seattle Seahawks
# 11       -0.78    Philadelphia Eagles          Detroit Lions
# 12        2.24   Tampa Bay Buccaneers         Dallas Cowboys
# 13        1.12      Green Bay Packers      Minnesota Vikings
# 14       -0.42    San Francisco 49ers          Chicago Bears
# 15       -0.51     New Orleans Saints        Atlanta Falcons
# 16       -0.39      Minnesota Vikings          Buffalo Bills
# 17       -4.93       Cleveland Browns         Miami Dolphins
# 18      -11.01     New Orleans Saints    Pittsburgh Steelers
# 19        7.32   Jacksonville Jaguars     Kansas City Chiefs
# 20        4.06         Denver Broncos       Tennessee Titans
# 21       -8.65     Indianapolis Colts      Las Vegas Raiders
# 22        0.41         Houston Texans        New York Giants
# 23        5.38   Los Angeles Chargers    San Francisco 49ers
# 24       -5.98  Washington Commanders    Philadelphia Eagles
# 25       10.13         Dallas Cowboys      Green Bay Packers
# 26        2.09          Detroit Lions          Chicago Bears
# 27       -7.78       Seattle Seahawks   Tampa Bay Buccaneers
# 28        0.94        Atlanta Falcons      Carolina Panthers
# 29        0.48      Arizona Cardinals       Los Angeles Rams

# %%
df.tail(30)
# Out:
#       season                  team          week  day         date  \
# 7631    1994    Kansas City Chiefs             8  Sun   October 23
# 7632    1994     Las Vegas Raiders             8  Sun   October 23
# 7633    1994        Dallas Cowboys             8  Sun   October 23
# 7634    1994     Minnesota Vikings             8  Thu   October 20
# 7635    1994         Detroit Lions             8  Sun   October 23
# 7636    1994  Tampa Bay Buccaneers             8  Sun   October 23
# 7637    1994    New Orleans Saints             8  Sun   October 23
# 7638    1994        Miami Dolphins             9  Sun   October 30
# 7639    1994    Indianapolis Colts             9  Sun   October 30
# 7640    1994         Buffalo Bills             9  Sun   October 30
# 2970         1.8   San Francisco 49ers      Baltimore Ravens
# 3237       -1.39  New England Patriots       New York Giants
# 3504         2.5     Green Bay Packers   Pittsburgh Steelers
# 3771       -8.49    Indianapolis Colts    New Orleans Saints
# 4038        1.91     Arizona Cardinals   Pittsburgh Steelers
# 4305        -0.7  New England Patriots       New York Giants
# 4572      -10.43         Chicago Bears    Indianapolis Colts
# 4839        7.56   Pittsburgh Steelers      Seattle Seahawks
# 5106        2.93   Philadelphia Eagles  New England Patriots
# 5373       -7.78  New England Patriots     Carolina Panthers
# 5640        9.42  Tampa Bay Buccaneers     Las Vegas Raiders
# 5899        3.96  New England Patriots      Los Angeles Rams
# 6158         0.7       New York Giants      Baltimore Ravens
# 6417       -1.52      Tennessee Titans      Los Angeles Rams
# 6668       -9.82       Atlanta Falcons        Denver Broncos
# 6919        7.71        Denver Broncos     Green Bay Packers
# 7170       -4.54     Green Bay Packers  New England Patriots
# 7421         0.2   Pittsburgh Steelers        Dallas Cowboys
# 7656        4.06   San Francisco 49ers  Los Angeles Chargers

# %% [markdown]
# ### Converting Missing Values and Categorical Data Types

# %%
df.isnull().sum()
# Out:
# season                  0
# team                    0
# week                    0
# day                     0
# date                    0
# time                    0
# result                  0
# ot                   7187
# record                  0
# @                    3836
# opp                     0
# points_scored           0
# points_allowed          0
# 1st_downs               0
# totyd                   0
# passyd                  1
# rushyd                  0
# to                   1868
# 1st_downs_allowed       0
# totyd_allowed           0
# passyd_allowed          1
# rushyd_allowed          0
# to_forced            1510
# off_exp_pts             0
# def_exp_pts             0
# sts_exp_pts             0
# away_t                  0
# home_t                  0
# dtype: int64

# %%
df.dtypes
# Out:
# season                int64
# team                 object
# week                 object
# day                  object
# date                 object
# time                 object
# result               object
# ot                   object
# record               object
# @                    object
# opp                  object
# points_scored        object
# points_allowed       object
# 1st_downs            object
# totyd                object
# passyd               object
# rushyd               object
# to                   object
# 1st_downs_allowed    object
# totyd_allowed        object
# passyd_allowed       object
# rushyd_allowed       object
# to_forced            object
# off_exp_pts          object
# def_exp_pts          object
# sts_exp_pts          object
# away_t               object
# home_t               object
# dtype: object

# %%
# convert NaN values for columns "ot" (overtime), "to" (turnovers), and "to_forced" to the integer 0.
df['ot'] = df['ot'].fillna(0)
df['to'] = df['to'].fillna(0)
df['to_forced'] = df['to_forced'].fillna(0)

# %%
# convert misc values for columns "home/away" (home team?) and "ot" (overtime) to a binary integer
df.loc[df["@"] == "@", "@"] = 0
df.loc[df["@"] == "N", "@"] = 0
df.loc[df["ot"] == "OT", "ot"] = 1

# %%
# changing the data types for some of the object columns
df[["ot"]] = df[["ot"]].apply(pd.to_numeric)

# %%
# convert NaN values for columns "home/away" (home team?) to the integer 1.
df['@'] = df['@'].fillna(1)

# %%
# checking how many rows still have missing values in them
df[df.isnull().any(axis=1)]
# Out:
#       season               team week  day         date       time result  ot  \
# 3637    2009      New York Jets   17  Sun    January 3  8:31PM ET      W   0
# 5246    2003  Las Vegas Raiders   17  Sun  December 28  4:15PM ET      L   0
#
#      record  @                   opp points_scored points_allowed 1st_downs  \
# 3637    9-7  1    Cincinnati Bengals          37.0            0.0      21.0
# 5246   4-12  0  Los Angeles Chargers          14.0           21.0       9.0
#
#       totyd passyd rushyd   to 1st_downs_allowed totyd_allowed passyd_allowed  \
# 3637  320.0   63.0  257.0    0               5.0          72.0            NaN
# 5246  141.0    NaN  141.0  1.0              20.0         337.0           74.0
#
#      rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts  \
# 3637           72.0       3.0       10.82       33.61       -6.11
# 5246          263.0         0      -25.91       -1.64       16.75
#
#                   away_t                home_t
# 3637  Cincinnati Bengals         New York Jets
# 5246   Las Vegas Raiders  Los Angeles Chargers

# %%
# converting the last four missing values to zero. The net passing yards equaled zero due to sacks.
df['passyd'] = df['passyd'].fillna(0)
df['passyd_allowed'] = df['passyd_allowed'].fillna(0)

# %%
# verifying the data types in the df
df.dtypes
# Out:
# season                int64
# team                 object
# week                 object
# day                  object
# date                 object
# time                 object
# result               object
# ot                    int64
# record               object
# @                     int64
# opp                  object
# points_scored        object
# points_allowed       object
# 1st_downs            object
# totyd                object
# passyd               object
# rushyd               object
# to                   object
# 1st_downs_allowed    object
# totyd_allowed        object
# passyd_allowed       object
# rushyd_allowed       object
# to_forced            object
# off_exp_pts          object
# def_exp_pts          object
# sts_exp_pts          object
# away_t               object
# home_t               object
# dtype: object

# %%
# checking how many rows still have missing values in them
len(df[df.isnull().any(axis=1)])
# Out:
# 0

# %% [markdown]
# ### Converting Date and Time columns

# %%
# "day" of the week needs to be converted into an integer.
day_dict = {"Tue":1, "Wed":2, "Thu":3, "Fri":4, "Sat":5, "Sun":6, "Mon":7}

# using the manually created day_dictionary to replace the day of the week.
df["day_of_week"] = df["day"].map(day_dict)

# %%
df
# Out:
#       season                  team       week  day          date        time  \
# 0       2022         Buffalo Bills          1  Thu   September 8   8:20PM ET
# 1       2022        Miami Dolphins          1  Sun  September 11   1:00PM ET
# 2       2022         New York Jets          1  Sun  September 11   1:00PM ET
# 3       2022    Cincinnati Bengals          1  Sun  September 11   1:00PM ET
# 4       2022      Cleveland Browns          1  Sun  September 11   1:00PM ET
# ...      ...                   ...        ...  ...           ...         ...
# 7656    1994  Los Angeles Chargers  SuperBowl  Sun    January 29   6:00PM ET
# 7657    1994        Miami Dolphins  Wild Card  Sat   December 31   4:00PM ET
# 7658    1994  New England Patriots  Wild Card  Sun     January 1  12:30PM ET
# 7659    1994     Minnesota Vikings  Wild Card  Sun     January 1   4:00PM ET
# 7660    1994     Green Bay Packers  Wild Card  Sat   December 31  12:30PM ET
#
#      result  ot record  @                   opp points_scored points_allowed  \
# 0         W   0    1-0  0      Los Angeles Rams            31             10
# 1         W   0    1-0  1  New England Patriots          20.0            7.0
# 2         L   0    0-1  1      Baltimore Ravens           9.0           24.0
# 3         L   1    0-1  1   Pittsburgh Steelers            20             23
# 4         W   0    1-0  0     Carolina Panthers          26.0           24.0
# ...     ...  ..    ... ..                   ...           ...            ...
# 7656      L   0   13-6  0   San Francisco 49ers          26.0           49.0
# 7657      W   0   11-6  1    Kansas City Chiefs          27.0           17.0
# 7658      L   0   10-7  0      Cleveland Browns          13.0           20.0
# 7659      L   0   10-7  1         Chicago Bears          18.0           35.0
# 7660      W   0   10-7  1         Detroit Lions          16.0           12.0
#
#      1st_downs  totyd passyd rushyd   to 1st_downs_allowed totyd_allowed  \
# 0           23    413    292    121    4                19           243
# 1         18.0  307.0  242.0   65.0    0              17.0         271.0
# 2         24.0  380.0  297.0   83.0  2.0              13.0         274.0
# 3           32    432    299    133    5                13           267
# 4         23.0  355.0  138.0  217.0    0              15.0         261.0
# ...        ...    ...    ...    ...  ...               ...           ...
# 7656      20.0  354.0  287.0   67.0  3.0              28.0         455.0
# 7657      22.0  381.0  249.0  132.0    0              24.0         414.0
# 7658      20.0  303.0  246.0   57.0  3.0              22.0         379.0
# 7659      22.0  389.0  340.0   49.0  4.0              18.0         308.0
# 7660      18.0  336.0  255.0   81.0    0               9.0         171.0
#
#      passyd_allowed rushyd_allowed to_forced off_exp_pts def_exp_pts  \
# 0               191             52         3       13.89       10.29
# 1             193.0           78.0       3.0        6.08        8.28
# 2             211.0           63.0       1.0       -8.07       -3.65
# 3               192             75         0       -7.49        8.41
# 4             207.0           54.0       1.0        6.82       -5.38
# ...             ...            ...       ...         ...         ...
# 7656          316.0          139.0         0       -3.94      -27.02
# 7657          314.0          100.0       2.0       15.96       -8.31
# 7658          254.0          125.0       1.0      -11.86       -8.13
# 7659          214.0           94.0       2.0       -9.54       -6.07
# 7660          175.0           -4.0         0       -2.93       11.53
#
#      sts_exp_pts                away_t                home_t  day_of_week
# 0          -3.96         Buffalo Bills      Los Angeles Rams            3
# 1           1.98  New England Patriots        Miami Dolphins            6
# 2          -5.04      Baltimore Ravens         New York Jets            6
# 3          -4.85   Pittsburgh Steelers    Cincinnati Bengals            6
# 4           1.66      Cleveland Browns     Carolina Panthers            6
# ...          ...                   ...                   ...          ...
# 7656        4.06   San Francisco 49ers  Los Angeles Chargers            6
# 7657        1.16    Kansas City Chiefs        Miami Dolphins            5
# 7658       10.97  New England Patriots      Cleveland Browns            6
# 7659        0.65         Chicago Bears     Minnesota Vikings            6
# 7660        0.69         Detroit Lions     Green Bay Packers            5
#
# [7661 rows x 29 columns]

# %%
# creating a year column out of the season column for future date transformations
df['year'] = df['season']

# %%
# Split the 'date' column into two new columns: 'month' and 'day'
df[['month', 'day']] = df['date'].str.split(' ', expand=True)

# Convert the 'day' column to integer type
df['day'] = df['day'].astype(int)

# %%
df
# Out:
#       season                  team       week  day          date        time  \
# 0       2022         Buffalo Bills          1    8   September 8   8:20PM ET
# 1       2022        Miami Dolphins          1   11  September 11   1:00PM ET
# 2       2022         New York Jets          1   11  September 11   1:00PM ET
# 3       2022    Cincinnati Bengals          1   11  September 11   1:00PM ET
# 4       2022      Cleveland Browns          1   11  September 11   1:00PM ET
# ...      ...                   ...        ...  ...           ...         ...
# 7656    1994  Los Angeles Chargers  SuperBowl   29    January 29   6:00PM ET
# 7657    1994        Miami Dolphins  Wild Card   31   December 31   4:00PM ET
# 7658    1994  New England Patriots  Wild Card    1     January 1  12:30PM ET
# 7659    1994     Minnesota Vikings  Wild Card    1     January 1   4:00PM ET
# 7660    1994     Green Bay Packers  Wild Card   31   December 31  12:30PM ET
#
#      result  ot record  @                   opp points_scored points_allowed  \
# 0         W   0    1-0  0      Los Angeles Rams            31             10
# 1         W   0    1-0  1  New England Patriots          20.0            7.0
# 2         L   0    0-1  1      Baltimore Ravens           9.0           24.0
# 3         L   1    0-1  1   Pittsburgh Steelers            20             23
# 4         W   0    1-0  0     Carolina Panthers          26.0           24.0
# ...     ...  ..    ... ..                   ...           ...            ...
# 7656      L   0   13-6  0   San Francisco 49ers          26.0           49.0
# 7657      W   0   11-6  1    Kansas City Chiefs          27.0           17.0
# 7658      L   0   10-7  0      Cleveland Browns          13.0           20.0
# 7659      L   0   10-7  1         Chicago Bears          18.0           35.0
# 7660      W   0   10-7  1         Detroit Lions          16.0           12.0
#
#      1st_downs  totyd passyd rushyd   to 1st_downs_allowed totyd_allowed  \
# 0           23    413    292    121    4                19           243
# 1         18.0  307.0  242.0   65.0    0              17.0         271.0
# 2         24.0  380.0  297.0   83.0  2.0              13.0         274.0
# 3           32    432    299    133    5                13           267
# 4         23.0  355.0  138.0  217.0    0              15.0         261.0
# ...        ...    ...    ...    ...  ...               ...           ...
# 7656      20.0  354.0  287.0   67.0  3.0              28.0         455.0
# 7657      22.0  381.0  249.0  132.0    0              24.0         414.0
# 7658      20.0  303.0  246.0   57.0  3.0              22.0         379.0
# 7659      22.0  389.0  340.0   49.0  4.0              18.0         308.0
# 7660      18.0  336.0  255.0   81.0    0               9.0         171.0
#
#      passyd_allowed rushyd_allowed to_forced off_exp_pts def_exp_pts  \
# 0               191             52         3       13.89       10.29
# 1             193.0           78.0       3.0        6.08        8.28
# 2             211.0           63.0       1.0       -8.07       -3.65
# 3               192             75         0       -7.49        8.41
# 4             207.0           54.0       1.0        6.82       -5.38
# ...             ...            ...       ...         ...         ...
# 7656          316.0          139.0         0       -3.94      -27.02
# 7657          314.0          100.0       2.0       15.96       -8.31
# 7658          254.0          125.0       1.0      -11.86       -8.13
# 7659          214.0           94.0       2.0       -9.54       -6.07
# 7660          175.0           -4.0         0       -2.93       11.53
#
#      sts_exp_pts                away_t                home_t  day_of_week  \
# 0          -3.96         Buffalo Bills      Los Angeles Rams            3
# 1           1.98  New England Patriots        Miami Dolphins            6
# 2          -5.04      Baltimore Ravens         New York Jets            6
# 3          -4.85   Pittsburgh Steelers    Cincinnati Bengals            6
# 4           1.66      Cleveland Browns     Carolina Panthers            6
# ...          ...                   ...                   ...          ...
# 7656        4.06   San Francisco 49ers  Los Angeles Chargers            6
# 7657        1.16    Kansas City Chiefs        Miami Dolphins            5
# 7658       10.97  New England Patriots      Cleveland Browns            6
# 7659        0.65         Chicago Bears     Minnesota Vikings            6
# 7660        0.69         Detroit Lions     Green Bay Packers            5
#
#       year      month
# 0     2022  September
# 1     2022  September
# 2     2022  September
# 3     2022  September
# 4     2022  September
# ...    ...        ...
# 7656  1994    January
# 7657  1994   December
# 7658  1994    January
# 7659  1994    January
# 7660  1994   December
#
# [7661 rows x 31 columns]

# %%
# converted to vectorized solution instead ^
# date need to be converted into a numerical value (month and day_of_month)
###c = []
###v = []
###for i in df['date']:
###    c.append((i.split(' ')[0]))
###    v.append(int(i.split(' ')[1]))
###df = df.assign(month = c)
###df = df.assign(day = v)

# %%
# "month of the year needs to be converted into an integer. NFL games start in August (preseason) and end in February (super bowl).
month_dict = {"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, 
            "July":7, "August":8, "September":9, "October":10, "November":11, "December":12}

# using the manually created day_dictionary to replace the day of the week.
df = df.replace({"month": month_dict})

# %%
# we can drop the date column after converting it
df = df.drop('date', axis=1)

# %%
# Extract the hour from the 'time' column
df['hour'] = df['time'].str[0].astype(int)

# Add 12 to the 'hour' column for times in the PM
df['hour'] += df['time'].str.contains('PM').astype(int) * 12

# %%
# converted into vectorized solution ^
# time needs to be converted into a numerical value
###b = []
###for i in df['time']:
###    if 'PM' in i:
###        b.append(int(i[0]) + 12)
###    else:
###        b.append(int(i[0]))
###df = df.assign(hour = b)

# %%
df
# Out:
#       season                  team       week  day        time result  ot  \
# 0       2022         Buffalo Bills          1    8   8:20PM ET      W   0
# 1       2022        Miami Dolphins          1   11   1:00PM ET      W   0
# 2       2022         New York Jets          1   11   1:00PM ET      L   0
# 3       2022    Cincinnati Bengals          1   11   1:00PM ET      L   1
# 4       2022      Cleveland Browns          1   11   1:00PM ET      W   0
# ...      ...                   ...        ...  ...         ...    ...  ..
# 7656    1994  Los Angeles Chargers  SuperBowl   29   6:00PM ET      L   0
# 7657    1994        Miami Dolphins  Wild Card   31   4:00PM ET      W   0
# 7658    1994  New England Patriots  Wild Card    1  12:30PM ET      L   0
# 7659    1994     Minnesota Vikings  Wild Card    1   4:00PM ET      L   0
# 7660    1994     Green Bay Packers  Wild Card   31  12:30PM ET      W   0
#
#      record  @                   opp points_scored points_allowed 1st_downs  \
# 0       1-0  0      Los Angeles Rams            31             10        23
# 1       1-0  1  New England Patriots          20.0            7.0      18.0
# 2       0-1  1      Baltimore Ravens           9.0           24.0      24.0
# 3       0-1  1   Pittsburgh Steelers            20             23        32
# 4       1-0  0     Carolina Panthers          26.0           24.0      23.0
# ...     ... ..                   ...           ...            ...       ...
# 7656   13-6  0   San Francisco 49ers          26.0           49.0      20.0
# 7657   11-6  1    Kansas City Chiefs          27.0           17.0      22.0
# 7658   10-7  0      Cleveland Browns          13.0           20.0      20.0
# 7659   10-7  1         Chicago Bears          18.0           35.0      22.0
# 7660   10-7  1         Detroit Lions          16.0           12.0      18.0
#
#       totyd passyd rushyd   to 1st_downs_allowed totyd_allowed passyd_allowed  \
# 0       413    292    121    4                19           243            191
# 1     307.0  242.0   65.0    0              17.0         271.0          193.0
# 2     380.0  297.0   83.0  2.0              13.0         274.0          211.0
# 3       432    299    133    5                13           267            192
# 4     355.0  138.0  217.0    0              15.0         261.0          207.0
# ...     ...    ...    ...  ...               ...           ...            ...
# 7656  354.0  287.0   67.0  3.0              28.0         455.0          316.0
# 7657  381.0  249.0  132.0    0              24.0         414.0          314.0
# 7658  303.0  246.0   57.0  3.0              22.0         379.0          254.0
# 7659  389.0  340.0   49.0  4.0              18.0         308.0          214.0
# 7660  336.0  255.0   81.0    0               9.0         171.0          175.0
#
#      rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts  \
# 0                52         3       13.89       10.29       -3.96
# 1              78.0       3.0        6.08        8.28        1.98
# 2              63.0       1.0       -8.07       -3.65       -5.04
# 3                75         0       -7.49        8.41       -4.85
# 4              54.0       1.0        6.82       -5.38        1.66
# ...             ...       ...         ...         ...         ...
# 7656          139.0         0       -3.94      -27.02        4.06
# 7657          100.0       2.0       15.96       -8.31        1.16
# 7658          125.0       1.0      -11.86       -8.13       10.97
# 7659           94.0       2.0       -9.54       -6.07        0.65
# 7660           -4.0         0       -2.93       11.53        0.69
#
#                     away_t                home_t  day_of_week  year  month  \
# 0            Buffalo Bills      Los Angeles Rams            3  2022      9
# 1     New England Patriots        Miami Dolphins            6  2022      9
# 2         Baltimore Ravens         New York Jets            6  2022      9
# 3      Pittsburgh Steelers    Cincinnati Bengals            6  2022      9
# 4         Cleveland Browns     Carolina Panthers            6  2022      9
# ...                    ...                   ...          ...   ...    ...
# 7656   San Francisco 49ers  Los Angeles Chargers            6  1994      1
# 7657    Kansas City Chiefs        Miami Dolphins            5  1994     12
# 7658  New England Patriots      Cleveland Browns            6  1994      1
# 7659         Chicago Bears     Minnesota Vikings            6  1994      1
# 7660         Detroit Lions     Green Bay Packers            5  1994     12
#
#       hour
# 0       20
# 1       13
# 2       13
# 3       13
# 4       13
# ...    ...
# 7656    18
# 7657    16
# 7658    13
# 7659    16
# 7660    13
#
# [7661 rows x 31 columns]

# %%
# we can drop the time column after converting it
df = df.drop('time', axis=1)

# %%
# creating an a datetime type column
df['date'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# %%
df
# Out:
#       season                  team       week  day result  ot record  @  \
# 0       2022         Buffalo Bills          1    8      W   0    1-0  0
# 1       2022        Miami Dolphins          1   11      W   0    1-0  1
# 2       2022         New York Jets          1   11      L   0    0-1  1
# 3       2022    Cincinnati Bengals          1   11      L   1    0-1  1
# 4       2022      Cleveland Browns          1   11      W   0    1-0  0
# ...      ...                   ...        ...  ...    ...  ..    ... ..
# 7656    1994  Los Angeles Chargers  SuperBowl   29      L   0   13-6  0
# 7657    1994        Miami Dolphins  Wild Card   31      W   0   11-6  1
# 7658    1994  New England Patriots  Wild Card    1      L   0   10-7  0
# 7659    1994     Minnesota Vikings  Wild Card    1      L   0   10-7  1
# 7660    1994     Green Bay Packers  Wild Card   31      W   0   10-7  1
#
#                        opp points_scored points_allowed 1st_downs  totyd  \
# 0         Los Angeles Rams            31             10        23    413
# 1     New England Patriots          20.0            7.0      18.0  307.0
# 2         Baltimore Ravens           9.0           24.0      24.0  380.0
# 3      Pittsburgh Steelers            20             23        32    432
# 4        Carolina Panthers          26.0           24.0      23.0  355.0
# ...                    ...           ...            ...       ...    ...
# 7656   San Francisco 49ers          26.0           49.0      20.0  354.0
# 7657    Kansas City Chiefs          27.0           17.0      22.0  381.0
# 7658      Cleveland Browns          13.0           20.0      20.0  303.0
# 7659         Chicago Bears          18.0           35.0      22.0  389.0
# 7660         Detroit Lions          16.0           12.0      18.0  336.0
#
#      passyd rushyd   to 1st_downs_allowed totyd_allowed passyd_allowed  \
# 0       292    121    4                19           243            191
# 1     242.0   65.0    0              17.0         271.0          193.0
# 2     297.0   83.0  2.0              13.0         274.0          211.0
# 3       299    133    5                13           267            192
# 4     138.0  217.0    0              15.0         261.0          207.0
# ...     ...    ...  ...               ...           ...            ...
# 7656  287.0   67.0  3.0              28.0         455.0          316.0
# 7657  249.0  132.0    0              24.0         414.0          314.0
# 7658  246.0   57.0  3.0              22.0         379.0          254.0
# 7659  340.0   49.0  4.0              18.0         308.0          214.0
# 7660  255.0   81.0    0               9.0         171.0          175.0
#
#      rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts  \
# 0                52         3       13.89       10.29       -3.96
# 1              78.0       3.0        6.08        8.28        1.98
# 2              63.0       1.0       -8.07       -3.65       -5.04
# 3                75         0       -7.49        8.41       -4.85
# 4              54.0       1.0        6.82       -5.38        1.66
# ...             ...       ...         ...         ...         ...
# 7656          139.0         0       -3.94      -27.02        4.06
# 7657          100.0       2.0       15.96       -8.31        1.16
# 7658          125.0       1.0      -11.86       -8.13       10.97
# 7659           94.0       2.0       -9.54       -6.07        0.65
# 7660           -4.0         0       -2.93       11.53        0.69
#
#                     away_t                home_t  day_of_week  year  month  \
# 0            Buffalo Bills      Los Angeles Rams            3  2022      9
# 1     New England Patriots        Miami Dolphins            6  2022      9
# 2         Baltimore Ravens         New York Jets            6  2022      9
# 3      Pittsburgh Steelers    Cincinnati Bengals            6  2022      9
# 4         Cleveland Browns     Carolina Panthers            6  2022      9
# ...                    ...                   ...          ...   ...    ...
# 7656   San Francisco 49ers  Los Angeles Chargers            6  1994      1
# 7657    Kansas City Chiefs        Miami Dolphins            5  1994     12
# 7658  New England Patriots      Cleveland Browns            6  1994      1
# 7659         Chicago Bears     Minnesota Vikings            6  1994      1
# 7660         Detroit Lions     Green Bay Packers            5  1994     12
#
#       hour                date
# 0       20 2022-09-08 20:00:00
# 1       13 2022-09-11 13:00:00
# 2       13 2022-09-11 13:00:00
# 3       13 2022-09-11 13:00:00
# 4       13 2022-09-11 13:00:00
# ...    ...                 ...
# 7656    18 1994-01-29 18:00:00
# 7657    16 1994-12-31 16:00:00
# 7658    13 1994-01-01 13:00:00
# 7659    16 1994-01-01 16:00:00
# 7660    13 1994-12-31 13:00:00
#
# [7661 rows x 31 columns]

# %%
# verifying the data types in the df
df.dtypes
# Out:
# season                        int64
# team                         object
# week                         object
# day                           int64
# result                       object
# ot                            int64
# record                       object
# @                             int64
# opp                          object
# points_scored                object
# points_allowed               object
# 1st_downs                    object
# totyd                        object
# passyd                       object
# rushyd                       object
# to                           object
# 1st_downs_allowed            object
# totyd_allowed                object
# passyd_allowed               object
# rushyd_allowed               object
# to_forced                    object
# off_exp_pts                  object
# def_exp_pts                  object
# sts_exp_pts                  object
# away_t                       object
# home_t                       object
# day_of_week                   int64
# year                          int64
# month                         int64
# hour                          int64
# date                 datetime64[ns]
# dtype: object

# %%
# we now have to create columns so that it is home_team_pts_scored, home_team_pts_allowed, etc.
# since we created home/away team columns, the stats for those games need to be converted accordingly
# those stats were based on the initial data source where we had two records for each game
# creating columns containing game stats from the home_team's point of view
ht_pts_scored = []
ht_pts_allowed = [] 
ht_1st_downs = []
ht_1st_downs_allowed = []
ht_totyd = []
ht_passyd = []
ht_rushyd = [] 
ht_to = []
ht_totyd_allowed = []
ht_passyd_allowed = []
ht_rushyd_allowed = []
ht_to_forced = []

counter = 0

for i in df['team']:
    if df['team'].iloc[counter] == df['home_t'].iloc[counter]:
        ht_pts_scored.append(df['points_scored'].iloc[counter])
        ht_pts_allowed.append(df['points_allowed'].iloc[counter])
        ht_1st_downs.append(df['1st_downs'].iloc[counter])
        ht_1st_downs_allowed.append(df['1st_downs_allowed'].iloc[counter])
        ht_totyd.append(df['totyd'].iloc[counter])
        ht_totyd_allowed.append(df['totyd_allowed'].iloc[counter])
        ht_passyd.append(df['passyd'].iloc[counter])
        ht_passyd_allowed.append(df['passyd_allowed'].iloc[counter])
        ht_rushyd.append(df['rushyd'].iloc[counter])
        ht_rushyd_allowed.append(df['rushyd_allowed'].iloc[counter])
        ht_to.append(df['to'].iloc[counter])
        ht_to_forced.append(df['to_forced'].iloc[counter])
    else:
        ht_pts_scored.append(df['points_allowed'].iloc[counter])
        ht_pts_allowed.append(df['points_scored'].iloc[counter])
        ht_1st_downs.append(df['1st_downs_allowed'].iloc[counter])
        ht_1st_downs_allowed.append(df['1st_downs'].iloc[counter])
        ht_totyd.append(df['totyd_allowed'].iloc[counter])
        ht_totyd_allowed.append(df['totyd'].iloc[counter])
        ht_passyd.append(df['passyd_allowed'].iloc[counter])
        ht_passyd_allowed.append(df['passyd'].iloc[counter])
        ht_rushyd.append(df['rushyd_allowed'].iloc[counter])
        ht_rushyd_allowed.append(df['rushyd'].iloc[counter])
        ht_to.append(df['to_forced'].iloc[counter])
        ht_to_forced.append(df['to'].iloc[counter])
    counter += 1

# %%
df
# Out:
#       season                  team       week  day result  ot record  @  \
# 0       2022         Buffalo Bills          1    8      W   0    1-0  0
# 1       2022        Miami Dolphins          1   11      W   0    1-0  1
# 2       2022         New York Jets          1   11      L   0    0-1  1
# 3       2022    Cincinnati Bengals          1   11      L   1    0-1  1
# 4       2022      Cleveland Browns          1   11      W   0    1-0  0
# ...      ...                   ...        ...  ...    ...  ..    ... ..
# 7656    1994  Los Angeles Chargers  SuperBowl   29      L   0   13-6  0
# 7657    1994        Miami Dolphins  Wild Card   31      W   0   11-6  1
# 7658    1994  New England Patriots  Wild Card    1      L   0   10-7  0
# 7659    1994     Minnesota Vikings  Wild Card    1      L   0   10-7  1
# 7660    1994     Green Bay Packers  Wild Card   31      W   0   10-7  1
#
#                        opp points_scored points_allowed 1st_downs  totyd  \
# 0         Los Angeles Rams            31             10        23    413
# 1     New England Patriots          20.0            7.0      18.0  307.0
# 2         Baltimore Ravens           9.0           24.0      24.0  380.0
# 3      Pittsburgh Steelers            20             23        32    432
# 4        Carolina Panthers          26.0           24.0      23.0  355.0
# ...                    ...           ...            ...       ...    ...
# 7656   San Francisco 49ers          26.0           49.0      20.0  354.0
# 7657    Kansas City Chiefs          27.0           17.0      22.0  381.0
# 7658      Cleveland Browns          13.0           20.0      20.0  303.0
# 7659         Chicago Bears          18.0           35.0      22.0  389.0
# 7660         Detroit Lions          16.0           12.0      18.0  336.0
#
#      passyd rushyd   to 1st_downs_allowed totyd_allowed passyd_allowed  \
# 0       292    121    4                19           243            191
# 1     242.0   65.0    0              17.0         271.0          193.0
# 2     297.0   83.0  2.0              13.0         274.0          211.0
# 3       299    133    5                13           267            192
# 4     138.0  217.0    0              15.0         261.0          207.0
# ...     ...    ...  ...               ...           ...            ...
# 7656  287.0   67.0  3.0              28.0         455.0          316.0
# 7657  249.0  132.0    0              24.0         414.0          314.0
# 7658  246.0   57.0  3.0              22.0         379.0          254.0
# 7659  340.0   49.0  4.0              18.0         308.0          214.0
# 7660  255.0   81.0    0               9.0         171.0          175.0
#
#      rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts  \
# 0                52         3       13.89       10.29       -3.96
# 1              78.0       3.0        6.08        8.28        1.98
# 2              63.0       1.0       -8.07       -3.65       -5.04
# 3                75         0       -7.49        8.41       -4.85
# 4              54.0       1.0        6.82       -5.38        1.66
# ...             ...       ...         ...         ...         ...
# 7656          139.0         0       -3.94      -27.02        4.06
# 7657          100.0       2.0       15.96       -8.31        1.16
# 7658          125.0       1.0      -11.86       -8.13       10.97
# 7659           94.0       2.0       -9.54       -6.07        0.65
# 7660           -4.0         0       -2.93       11.53        0.69
#
#                     away_t                home_t  day_of_week  year  month  \
# 0            Buffalo Bills      Los Angeles Rams            3  2022      9
# 1     New England Patriots        Miami Dolphins            6  2022      9
# 2         Baltimore Ravens         New York Jets            6  2022      9
# 3      Pittsburgh Steelers    Cincinnati Bengals            6  2022      9
# 4         Cleveland Browns     Carolina Panthers            6  2022      9
# ...                    ...                   ...          ...   ...    ...
# 7656   San Francisco 49ers  Los Angeles Chargers            6  1994      1
# 7657    Kansas City Chiefs        Miami Dolphins            5  1994     12
# 7658  New England Patriots      Cleveland Browns            6  1994      1
# 7659         Chicago Bears     Minnesota Vikings            6  1994      1
# 7660         Detroit Lions     Green Bay Packers            5  1994     12
#
#       hour                date
# 0       20 2022-09-08 20:00:00
# 1       13 2022-09-11 13:00:00
# 2       13 2022-09-11 13:00:00
# 3       13 2022-09-11 13:00:00
# 4       13 2022-09-11 13:00:00
# ...    ...                 ...
# 7656    18 1994-01-29 18:00:00
# 7657    16 1994-12-31 16:00:00
# 7658    13 1994-01-01 13:00:00
# 7659    16 1994-01-01 16:00:00
# 7660    13 1994-12-31 13:00:00
#
# [7661 rows x 31 columns]

# %%
ht_pts_scored[:5]
# Out:
# ['10', '20.0', '9.0', '20', '24.0']

# %%
df = df.assign(ht_pts_scored = ht_pts_scored)
df = df.assign(ht_pts_allowed = ht_pts_allowed)
df = df.assign(ht_1st_downs = ht_1st_downs)
df = df.assign(ht_totyd = ht_totyd)
df = df.assign(ht_passyd = ht_passyd)
df = df.assign(ht_rushyd = ht_rushyd)
df = df.assign(ht_to = ht_to)
df = df.assign(ht_1st_downs_allowed = ht_1st_downs_allowed)
df = df.assign(ht_totyd_allowed = ht_totyd_allowed)
df = df.assign(ht_passyd_allowed = ht_passyd_allowed)
df = df.assign(ht_rushyd_allowed = ht_rushyd_allowed)
df = df.assign(ht_to_forced = ht_to_forced)

# %%
df
# Out:
#       season                  team       week  day result  ot record  @  \
# 0       2022         Buffalo Bills          1    8      W   0    1-0  0
# 1       2022        Miami Dolphins          1   11      W   0    1-0  1
# 2       2022         New York Jets          1   11      L   0    0-1  1
# 3       2022    Cincinnati Bengals          1   11      L   1    0-1  1
# 4       2022      Cleveland Browns          1   11      W   0    1-0  0
# ...      ...                   ...        ...  ...    ...  ..    ... ..
# 7656    1994  Los Angeles Chargers  SuperBowl   29      L   0   13-6  0
# 7657    1994        Miami Dolphins  Wild Card   31      W   0   11-6  1
# 7658    1994  New England Patriots  Wild Card    1      L   0   10-7  0
# 7659    1994     Minnesota Vikings  Wild Card    1      L   0   10-7  1
# 7660    1994     Green Bay Packers  Wild Card   31      W   0   10-7  1
#
#                        opp points_scored points_allowed 1st_downs  totyd  \
# 0         Los Angeles Rams            31             10        23    413
# 1     New England Patriots          20.0            7.0      18.0  307.0
# 2         Baltimore Ravens           9.0           24.0      24.0  380.0
# 3      Pittsburgh Steelers            20             23        32    432
# 4        Carolina Panthers          26.0           24.0      23.0  355.0
# ...                    ...           ...            ...       ...    ...
# 7656   San Francisco 49ers          26.0           49.0      20.0  354.0
# 7657    Kansas City Chiefs          27.0           17.0      22.0  381.0
# 7658      Cleveland Browns          13.0           20.0      20.0  303.0
# 7659         Chicago Bears          18.0           35.0      22.0  389.0
# 7660         Detroit Lions          16.0           12.0      18.0  336.0
#
#      passyd rushyd   to 1st_downs_allowed totyd_allowed passyd_allowed  \
# 0       292    121    4                19           243            191
# 1     242.0   65.0    0              17.0         271.0          193.0
# 2     297.0   83.0  2.0              13.0         274.0          211.0
# 3       299    133    5                13           267            192
# 4     138.0  217.0    0              15.0         261.0          207.0
# ...     ...    ...  ...               ...           ...            ...
# 7656  287.0   67.0  3.0              28.0         455.0          316.0
# 7657  249.0  132.0    0              24.0         414.0          314.0
# 7658  246.0   57.0  3.0              22.0         379.0          254.0
# 7659  340.0   49.0  4.0              18.0         308.0          214.0
# 7660  255.0   81.0    0               9.0         171.0          175.0
#
#      rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts  \
# 0                52         3       13.89       10.29       -3.96
# 1              78.0       3.0        6.08        8.28        1.98
# 2              63.0       1.0       -8.07       -3.65       -5.04
# 3                75         0       -7.49        8.41       -4.85
# 4              54.0       1.0        6.82       -5.38        1.66
# ...             ...       ...         ...         ...         ...
# 7656          139.0         0       -3.94      -27.02        4.06
# 7657          100.0       2.0       15.96       -8.31        1.16
# 7658          125.0       1.0      -11.86       -8.13       10.97
# 7659           94.0       2.0       -9.54       -6.07        0.65
# 7660           -4.0         0       -2.93       11.53        0.69
#
#                     away_t                home_t  day_of_week  year  month  \
# 0            Buffalo Bills      Los Angeles Rams            3  2022      9
# 1     New England Patriots        Miami Dolphins            6  2022      9
# 2         Baltimore Ravens         New York Jets            6  2022      9
# 3      Pittsburgh Steelers    Cincinnati Bengals            6  2022      9
# 4         Cleveland Browns     Carolina Panthers            6  2022      9
# ...                    ...                   ...          ...   ...    ...
# 7656   San Francisco 49ers  Los Angeles Chargers            6  1994      1
# 7657    Kansas City Chiefs        Miami Dolphins            5  1994     12
# 7658  New England Patriots      Cleveland Browns            6  1994      1
# 7659         Chicago Bears     Minnesota Vikings            6  1994      1
# 7660         Detroit Lions     Green Bay Packers            5  1994     12
#
#       hour                date ht_pts_scored ht_pts_allowed ht_1st_downs  \
# 0       20 2022-09-08 20:00:00            10             31           19
# 1       13 2022-09-11 13:00:00          20.0            7.0         18.0
# 2       13 2022-09-11 13:00:00           9.0           24.0         24.0
# 3       13 2022-09-11 13:00:00            20             23           32
# 4       13 2022-09-11 13:00:00          24.0           26.0         15.0
# ...    ...                 ...           ...            ...          ...
# 7656    18 1994-01-29 18:00:00          26.0           49.0         20.0
# 7657    16 1994-12-31 16:00:00          27.0           17.0         22.0
# 7658    13 1994-01-01 13:00:00          20.0           13.0         22.0
# 7659    16 1994-01-01 16:00:00          18.0           35.0         22.0
# 7660    13 1994-12-31 13:00:00          16.0           12.0         18.0
#
#      ht_totyd ht_passyd ht_rushyd ht_to ht_1st_downs_allowed ht_totyd_allowed  \
# 0         243       191        52     3                   23              413
# 1       307.0     242.0      65.0     0                 17.0            271.0
# 2       380.0     297.0      83.0   2.0                 13.0            274.0
# 3         432       299       133     5                   13              267
# 4       261.0     207.0      54.0   1.0                 23.0            355.0
# ...       ...       ...       ...   ...                  ...              ...
# 7656    354.0     287.0      67.0   3.0                 28.0            455.0
# 7657    381.0     249.0     132.0     0                 24.0            414.0
# 7658    379.0     254.0     125.0   1.0                 20.0            303.0
# 7659    389.0     340.0      49.0   4.0                 18.0            308.0
# 7660    336.0     255.0      81.0     0                  9.0            171.0
#
#      ht_passyd_allowed ht_rushyd_allowed ht_to_forced
# 0                  292               121            4
# 1                193.0              78.0          3.0
# 2                211.0              63.0          1.0
# 3                  192                75            0
# 4                138.0             217.0            0
# ...                ...               ...          ...
# 7656             316.0             139.0            0
# 7657             314.0             100.0          2.0
# 7658             246.0              57.0          3.0
# 7659             214.0              94.0          2.0
# 7660             175.0              -4.0            0
#
# [7661 rows x 43 columns]

# %%
# we probably need to develop 'home_team_record' and 'away_team_record' columns, but it might be too difficult to engineer

# %% [markdown]
# ### Creating the Target feature

# %%
# Create the conditions
conditions = [
    (df['team'] == df['home_t']) & (df['result'] == 'W'),
    (df['team'] != df['home_t']) & (df['result'] == 'L')
]

# Create the choices
choices = [1, 0]

# Use np.select to create the 'home_team_wins' column
df['home_team_wins'] = np.select(conditions, choices)

# %%
# created a vectorized solution instead ^
# we have to create a target feature 'home_team_wins', where 0 = home team did not win, 1 = home team won
###ht_wins = []
###counter = 0
###
###for i in df['result']:
###    if df['team'].iloc[counter] == df['home_t'].iloc[counter]:
###        if i == 'W':
###            ht_wins.append(1)
###        else:
###            ht_wins.append(0)
###        counter += 1
###    else:
###        if i == 'W':
###            ht_wins.append(0)
###        else:
###            ht_wins.append(1)
###        counter += 1   

###df = df.assign(ht_wins = ht_wins)

# %%
df
# Out:
#       season                  team       week  day result  ot record  @  \
# 0       2022         Buffalo Bills          1    8      W   0    1-0  0
# 1       2022        Miami Dolphins          1   11      W   0    1-0  1
# 2       2022         New York Jets          1   11      L   0    0-1  1
# 3       2022    Cincinnati Bengals          1   11      L   1    0-1  1
# 4       2022      Cleveland Browns          1   11      W   0    1-0  0
# ...      ...                   ...        ...  ...    ...  ..    ... ..
# 7656    1994  Los Angeles Chargers  SuperBowl   29      L   0   13-6  0
# 7657    1994        Miami Dolphins  Wild Card   31      W   0   11-6  1
# 7658    1994  New England Patriots  Wild Card    1      L   0   10-7  0
# 7659    1994     Minnesota Vikings  Wild Card    1      L   0   10-7  1
# 7660    1994     Green Bay Packers  Wild Card   31      W   0   10-7  1
#
#                        opp points_scored points_allowed 1st_downs  totyd  \
# 0         Los Angeles Rams            31             10        23    413
# 1     New England Patriots          20.0            7.0      18.0  307.0
# 2         Baltimore Ravens           9.0           24.0      24.0  380.0
# 3      Pittsburgh Steelers            20             23        32    432
# 4        Carolina Panthers          26.0           24.0      23.0  355.0
# ...                    ...           ...            ...       ...    ...
# 7656   San Francisco 49ers          26.0           49.0      20.0  354.0
# 7657    Kansas City Chiefs          27.0           17.0      22.0  381.0
# 7658      Cleveland Browns          13.0           20.0      20.0  303.0
# 7659         Chicago Bears          18.0           35.0      22.0  389.0
# 7660         Detroit Lions          16.0           12.0      18.0  336.0
#
#      passyd rushyd   to 1st_downs_allowed totyd_allowed passyd_allowed  \
# 0       292    121    4                19           243            191
# 1     242.0   65.0    0              17.0         271.0          193.0
# 2     297.0   83.0  2.0              13.0         274.0          211.0
# 3       299    133    5                13           267            192
# 4     138.0  217.0    0              15.0         261.0          207.0
# ...     ...    ...  ...               ...           ...            ...
# 7656  287.0   67.0  3.0              28.0         455.0          316.0
# 7657  249.0  132.0    0              24.0         414.0          314.0
# 7658  246.0   57.0  3.0              22.0         379.0          254.0
# 7659  340.0   49.0  4.0              18.0         308.0          214.0
# 7660  255.0   81.0    0               9.0         171.0          175.0
#
#      rushyd_allowed to_forced off_exp_pts def_exp_pts sts_exp_pts  \
# 0                52         3       13.89       10.29       -3.96
# 1              78.0       3.0        6.08        8.28        1.98
# 2              63.0       1.0       -8.07       -3.65       -5.04
# 3                75         0       -7.49        8.41       -4.85
# 4              54.0       1.0        6.82       -5.38        1.66
# ...             ...       ...         ...         ...         ...
# 7656          139.0         0       -3.94      -27.02        4.06
# 7657          100.0       2.0       15.96       -8.31        1.16
# 7658          125.0       1.0      -11.86       -8.13       10.97
# 7659           94.0       2.0       -9.54       -6.07        0.65
# 7660           -4.0         0       -2.93       11.53        0.69
#
#                     away_t                home_t  day_of_week  year  month  \
# 0            Buffalo Bills      Los Angeles Rams            3  2022      9
# 1     New England Patriots        Miami Dolphins            6  2022      9
# 2         Baltimore Ravens         New York Jets            6  2022      9
# 3      Pittsburgh Steelers    Cincinnati Bengals            6  2022      9
# 4         Cleveland Browns     Carolina Panthers            6  2022      9
# ...                    ...                   ...          ...   ...    ...
# 7656   San Francisco 49ers  Los Angeles Chargers            6  1994      1
# 7657    Kansas City Chiefs        Miami Dolphins            5  1994     12
# 7658  New England Patriots      Cleveland Browns            6  1994      1
# 7659         Chicago Bears     Minnesota Vikings            6  1994      1
# 7660         Detroit Lions     Green Bay Packers            5  1994     12
#
#       hour                date ht_pts_scored ht_pts_allowed ht_1st_downs  \
# 0       20 2022-09-08 20:00:00            10             31           19
# 1       13 2022-09-11 13:00:00          20.0            7.0         18.0
# 2       13 2022-09-11 13:00:00           9.0           24.0         24.0
# 3       13 2022-09-11 13:00:00            20             23           32
# 4       13 2022-09-11 13:00:00          24.0           26.0         15.0
# ...    ...                 ...           ...            ...          ...
# 7656    18 1994-01-29 18:00:00          26.0           49.0         20.0
# 7657    16 1994-12-31 16:00:00          27.0           17.0         22.0
# 7658    13 1994-01-01 13:00:00          20.0           13.0         22.0
# 7659    16 1994-01-01 16:00:00          18.0           35.0         22.0
# 7660    13 1994-12-31 13:00:00          16.0           12.0         18.0
#
#      ht_totyd ht_passyd ht_rushyd ht_to ht_1st_downs_allowed ht_totyd_allowed  \
# 0         243       191        52     3                   23              413
# 1       307.0     242.0      65.0     0                 17.0            271.0
# 2       380.0     297.0      83.0   2.0                 13.0            274.0
# 3         432       299       133     5                   13              267
# 4       261.0     207.0      54.0   1.0                 23.0            355.0
# ...       ...       ...       ...   ...                  ...              ...
# 7656    354.0     287.0      67.0   3.0                 28.0            455.0
# 7657    381.0     249.0     132.0     0                 24.0            414.0
# 7658    379.0     254.0     125.0   1.0                 20.0            303.0
# 7659    389.0     340.0      49.0   4.0                 18.0            308.0
# 7660    336.0     255.0      81.0     0                  9.0            171.0
#
#      ht_passyd_allowed ht_rushyd_allowed ht_to_forced  home_team_wins
# 0                  292               121            4               0
# 1                193.0              78.0          3.0               1
# 2                211.0              63.0          1.0               0
# 3                  192                75            0               0
# 4                138.0             217.0            0               0
# ...                ...               ...          ...             ...
# 7656             316.0             139.0            0               0
# 7657             314.0             100.0          2.0               1
# 7658             246.0              57.0          3.0               0
# 7659             214.0              94.0          2.0               0
# 7660             175.0              -4.0            0               1
#
# [7661 rows x 44 columns]

# %%
df.dtypes
# Out:
# season                           int64
# team                            object
# week                            object
# day                              int64
# result                          object
# ot                               int64
# record                          object
# @                                int64
# opp                             object
# points_scored                   object
# points_allowed                  object
# 1st_downs                       object
# totyd                           object
# passyd                          object
# rushyd                          object
# to                              object
# 1st_downs_allowed               object
# totyd_allowed                   object
# passyd_allowed                  object
# rushyd_allowed                  object
# to_forced                       object
# off_exp_pts                     object
# def_exp_pts                     object
# sts_exp_pts                     object
# away_t                          object
# home_t                          object
# day_of_week                      int64
# year                             int64
# month                            int64
# hour                             int64
# date                    datetime64[ns]
# ht_pts_scored                   object
# ht_pts_allowed                  object
# ht_1st_downs                    object
# ht_totyd                        object
# ht_passyd                       object
# ht_rushyd                       object
# ht_to                           object
# ht_1st_downs_allowed            object
# ht_totyd_allowed                object
# ht_passyd_allowed               object
# ht_rushyd_allowed               object
# ht_to_forced                    object
# home_team_wins                   int64
# dtype: object

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df = df.drop(['record', 'team', 'result', '@', 'opp', 'points_scored', 'points_allowed', '1st_downs', 
              'totyd', 'passyd', 'rushyd', 'to', '1st_downs_allowed', 'totyd_allowed', 'passyd_allowed', 
              'rushyd_allowed', 'to_forced', 'off_exp_pts', 'def_exp_pts', 'sts_exp_pts', 'year'], axis=1)

# %%
df.dtypes
# Out:
# season                           int64
# week                            object
# day                              int64
# ot                               int64
# away_t                          object
# home_t                          object
# day_of_week                      int64
# month                            int64
# hour                             int64
# date                    datetime64[ns]
# ht_pts_scored                   object
# ht_pts_allowed                  object
# ht_1st_downs                    object
# ht_totyd                        object
# ht_passyd                       object
# ht_rushyd                       object
# ht_to                           object
# ht_1st_downs_allowed            object
# ht_totyd_allowed                object
# ht_passyd_allowed               object
# ht_rushyd_allowed               object
# ht_to_forced                    object
# home_team_wins                   int64
# dtype: object

# %% [markdown]
# ### Feature Engineering

# %%
# the goal is to obtain a new column that contains rolling_averages for a team over the last four games.
# should the end of a season reset the rolling percentage??? Yes
# creating a df that is organized at the team and season level
grouped_teams = df.groupby("home_t")

# %%
# viewing one instance
group_arz = grouped_teams.get_group("Arizona Cardinals")
group_arz
# Out:
#       season week  day  ot                away_t             home_t  \
# 8       2022    1   11   0    Kansas City Chiefs  Arizona Cardinals
# 43      2022   11   21   0   San Francisco 49ers  Arizona Cardinals
# 53      2022   12   27   0  Los Angeles Chargers  Arizona Cardinals
# 77      2022   14   12   0  New England Patriots  Arizona Cardinals
# 119     2022   16   25   1  Tampa Bay Buccaneers  Arizona Cardinals
# ...      ...  ...  ...  ..                   ...                ...
# 7527    1994   16   18   0    Cincinnati Bengals  Arizona Cardinals
# 7560    1994    2   11   0       New York Giants  Arizona Cardinals
# 7599    1994    5    2   0     Minnesota Vikings  Arizona Cardinals
# 7633    1994    8   23   0        Dallas Cowboys  Arizona Cardinals
# 7641    1994    9   30   1   Pittsburgh Steelers  Arizona Cardinals
#
#       day_of_week  month  hour                date ht_pts_scored  \
# 8               6      9    16 2022-09-11 16:00:00          21.0
# 43              7     11    20 2022-11-21 20:00:00          10.0
# 53              6     11    16 2022-11-27 16:00:00          24.0
# 77              7     12    20 2022-12-12 20:00:00          13.0
# 119             6     12    20 2022-12-25 20:00:00          16.0
# ...           ...    ...   ...                 ...           ...
# 7527            6     12    16 1994-12-18 16:00:00          28.0
# 7560            6      9    20 1994-09-11 20:00:00          17.0
# 7599            6     10    16 1994-10-02 16:00:00          17.0
# 7633            6     10    16 1994-10-23 16:00:00          21.0
# 7641            6     10    20 1994-10-30 20:00:00          20.0
#
#      ht_pts_allowed ht_1st_downs ht_totyd ht_passyd ht_rushyd ht_to  \
# 8              44.0         18.0    282.0     179.0     103.0     0
# 43             38.0         19.0    314.0     247.0      67.0   2.0
# 53             25.0         20.0    366.0     185.0     181.0   2.0
# 77             27.0         19.0    323.0     210.0     113.0   2.0
# 119            19.0         16.0    325.0     204.0     121.0   3.0
# ...             ...          ...      ...       ...       ...   ...
# 7527            7.0         24.0    364.0     212.0     152.0     0
# 7560           20.0         11.0    174.0     135.0      39.0   3.0
# 7599            7.0         21.0    309.0     200.0     109.0   2.0
# 7633           28.0         22.0    315.0     208.0     107.0     0
# 7641           17.0         16.0    335.0     236.0      99.0   1.0
#
#      ht_1st_downs_allowed ht_totyd_allowed ht_passyd_allowed  \
# 8                    33.0            488.0             360.0
# 43                   21.0            387.0             228.0
# 53                   22.0            311.0             246.0
# 77                   18.0            328.0             225.0
# 119                  21.0            396.0             281.0
# ...                   ...              ...               ...
# 7527                 12.0            189.0             125.0
# 7560                 19.0            206.0              88.0
# 7599                 19.0            358.0             340.0
# 7633                 14.0            312.0             237.0
# 7641                 12.0            317.0             232.0
#
#      ht_rushyd_allowed ht_to_forced  home_team_wins
# 8                128.0          1.0               0
# 43               159.0            0               0
# 53                65.0            0               0
# 77               103.0          1.0               0
# 119              115.0          2.0               0
# ...                ...          ...             ...
# 7527              64.0          3.0               0
# 7560             118.0          2.0               0
# 7599              18.0          4.0               1
# 7633              75.0            0               0
# 7641              85.0          3.0               0
#
# [237 rows x 23 columns]

# %% [markdown]
# def rolling_averages(group, cols, new_cols):
#     group = group.sort_values("date")
#     rolling_stats = group[cols].rolling(4).mean() # closed='left' inside rolling parameters
#     # the problem is that it is using the fourth games' info to predict the fourth game and beyond.
#     # closed='left' would solve this problem, but that requires datetime. How do I resolve this???
#     group[new_cols] = rolling_stats
#     group = group.dropna(subset=new_cols)
#     return group

# %%
def rolling_averages(group, cols, new_cols):
    """
    Compute rolling averages of the given columns for a pandas DataFrame grouped by some categorical variable.

    Parameters:
    group (pandas.DataFrame): The DataFrame to group by.
    cols (list of str): The names of the columns to compute rolling averages for.
    new_cols (list of str): The names of the new columns to create with the rolling averages.

    Returns:
    pandas.DataFrame: The original DataFrame with the new columns added, and rows with missing values dropped.
    """
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(4).mean() # Use the last 4 rows of each group to compute the rolling average.
    # Note that by default, rolling() uses a "right closed" window, meaning that the last value in the window is included.
    # We want to use a "left closed" window, meaning that the first value in the window is included, so we pass the parameter
    # closed='left' to rolling(). However, this requires that the 'date' column be of type datetime, so make sure to convert
    # it beforehand if it isn't already.
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols) # Drop rows with missing values in the new columns.
    return group

# %%
# creating a list of the columns I plan on finding the rolling averages for
cols = ["home_team_wins", "ht_pts_scored", "ht_pts_allowed",
        "ht_totyd", "ht_to", "ht_totyd_allowed", "ht_to_forced",
        "ht_passyd", "ht_rushyd", "ht_passyd_allowed", "ht_rushyd_allowed",
        "ht_1st_downs", "ht_1st_downs_allowed", "ot"]

new_cols = [f"{c}_rolling" for c in cols]

# %%
# first four weeks are being dropped because of na values from rolling(4)
# should we bring datetime back??
# testing the function on one group (arz)
rolling_averages(group_arz, cols, new_cols)
# Out:
#       season week  day  ot                 away_t             home_t  \
# 7641    1994    9   30   1    Pittsburgh Steelers  Arizona Cardinals
# 7478    1994   12   20   0    Philadelphia Eagles  Arizona Cardinals
# 7491    1994   13   27   1          Chicago Bears  Arizona Cardinals
# 7519    1994   15   11   0  Washington Commanders  Arizona Cardinals
# 7527    1994   16   18   0     Cincinnati Bengals  Arizona Cardinals
# ...      ...  ...  ...  ..                    ...                ...
# 271     2022    9    6   0       Seattle Seahawks  Arizona Cardinals
# 43      2022   11   21   0    San Francisco 49ers  Arizona Cardinals
# 53      2022   12   27   0   Los Angeles Chargers  Arizona Cardinals
# 77      2022   14   12   0   New England Patriots  Arizona Cardinals
# 119     2022   16   25   1   Tampa Bay Buccaneers  Arizona Cardinals
#
#       day_of_week  month  hour                date ht_pts_scored  \
# 7641            6     10    20 1994-10-30 20:00:00          20.0
# 7478            6     11    16 1994-11-20 16:00:00          12.0
# 7491            6     11    16 1994-11-27 16:00:00          16.0
# 7519            6     12    16 1994-12-11 16:00:00          17.0
# 7527            6     12    16 1994-12-18 16:00:00          28.0
# ...           ...    ...   ...                 ...           ...
# 271             6     11    16 2022-11-06 16:00:00          21.0
# 43              7     11    20 2022-11-21 20:00:00          10.0
# 53              6     11    16 2022-11-27 16:00:00          24.0
# 77              7     12    20 2022-12-12 20:00:00          13.0
# 119             6     12    20 2022-12-25 20:00:00          16.0
#
#      ht_pts_allowed ht_1st_downs ht_totyd ht_passyd ht_rushyd ht_to  \
# 7641           17.0         16.0    335.0     236.0      99.0   1.0
# 7478            6.0         16.0    281.0     123.0     158.0   1.0
# 7491           19.0         15.0    244.0     177.0      67.0   1.0
# 7519           15.0         14.0    278.0     194.0      84.0   1.0
# 7527            7.0         24.0    364.0     212.0     152.0     0
# ...             ...          ...      ...       ...       ...   ...
# 271            31.0         15.0    262.0     140.0     122.0   1.0
# 43             38.0         19.0    314.0     247.0      67.0   2.0
# 53             25.0         20.0    366.0     185.0     181.0   2.0
# 77             27.0         19.0    323.0     210.0     113.0   2.0
# 119            19.0         16.0    325.0     204.0     121.0   3.0
#
#      ht_1st_downs_allowed ht_totyd_allowed ht_passyd_allowed  \
# 7641                 12.0            317.0             232.0
# 7478                 14.0            185.0             110.0
# 7491                 20.0            318.0             186.0
# 7519                 19.0            406.0             283.0
# 7527                 12.0            189.0             125.0
# ...                   ...              ...               ...
# 271                  27.0            421.0             263.0
# 43                   21.0            387.0             228.0
# 53                   22.0            311.0             246.0
# 77                   18.0            328.0             225.0
# 119                  21.0            396.0             281.0
#
#      ht_rushyd_allowed ht_to_forced  home_team_wins  home_team_wins_rolling  \
# 7641              85.0          3.0               0                    0.25
# 7478              75.0          2.0               1                    0.50
# 7491             132.0          2.0               0                    0.25
# 7519             123.0          2.0               1                    0.50
# 7527              64.0          3.0               0                    0.50
# ...                ...          ...             ...                     ...
# 271              158.0          1.0               0                    0.00
# 43               159.0            0               0                    0.00
# 53                65.0            0               0                    0.00
# 77               103.0          1.0               0                    0.00
# 119              115.0          2.0               0                    0.00
#
#       ht_pts_scored_rolling  ht_pts_allowed_rolling  ht_totyd_rolling  \
# 7641                  18.75                   18.00            283.25
# 7478                  17.50                   14.50            310.00
# 7491                  17.25                   17.50            293.75
# 7519                  16.25                   14.25            284.50
# 7527                  18.25                   11.75            291.75
# ...                     ...                     ...               ...
# 271                   23.00                   26.25            329.00
# 43                    22.50                   30.75            316.25
# 53                    24.25                   32.00            317.00
# 77                    17.00                   30.25            316.25
# 119                   15.75                   27.25            332.00
#
#       ht_to_rolling  ht_totyd_allowed_rolling  ht_to_forced_rolling  \
# 7641           1.50                    298.25                  2.25
# 7478           1.00                    293.00                  2.25
# 7491           0.75                    283.00                  1.75
# 7519           1.00                    306.50                  2.25
# 7527           0.75                    274.50                  2.25
# ...             ...                       ...                   ...
# 271            0.50                    402.75                  1.25
# 43             1.00                    414.75                  1.00
# 53             1.25                    403.25                  1.00
# 77             1.75                    361.75                  0.50
# 119            2.25                    355.50                  0.75
#
#       ht_passyd_rolling  ht_rushyd_rolling  ht_passyd_allowed_rolling  \
# 7641             194.75              88.50                     224.25
# 7478             191.75             118.25                     229.75
# 7491             186.00             107.75                     191.25
# 7519             182.50             102.00                     202.75
# 7527             176.50             115.25                     176.00
# ...                 ...                ...                        ...
# 271              215.75             113.25                     282.25
# 43               203.75             112.50                     279.50
# 53               190.25             126.75                     286.50
# 77               195.50             120.75                     240.50
# 119              211.50             120.50                     245.00
#
#       ht_rushyd_allowed_rolling  ht_1st_downs_rolling  \
# 7641                      74.00                 17.50
# 7478                      63.25                 18.75
# 7491                      91.75                 17.25
# 7519                     103.75                 15.25
# 7527                      98.50                 17.25
# ...                         ...                   ...
# 271                      120.50                 20.50
# 43                       135.25                 19.50
# 53                       116.75                 18.75
# 77                       121.25                 18.25
# 119                      110.50                 18.50
#
#       ht_1st_downs_allowed_rolling  ot_rolling
# 7641                         16.00        0.25
# 7478                         14.75        0.25
# 7491                         15.00        0.50
# 7519                         16.25        0.50
# 7527                         16.25        0.25
# ...                            ...         ...
# 271                          22.75        0.00
# 43                           24.25        0.00
# 53                           23.75        0.00
# 77                           22.00        0.00
# 119                          20.50        0.25
#
# [234 rows x 37 columns]

# %%
#apply the new rolling_averages columns to each group
df_rolling = df.groupby(["season", "week"]).apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# <ipython-input-79-00a92933bdc0>:14: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['ht_1st_downs', 'ht_1st_downs_allowed', 'ht_passyd',
#        'ht_passyd_allowed', 'ht_pts_allowed', 'ht_pts_scored', 'ht_rushyd',
#        'ht_rushyd_allowed', 'ht_to', 'ht_to_forced', 'ht_totyd',
#        'ht_totyd_allowed'],
#       dtype='object')
#   rolling_stats = group[cols].rolling(4).mean() # Use the last 4 rows of each group to compute the rolling average.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-34acf6b9f28d> in <module>
#       1 #apply the new rolling_averages columns to each group
# ----> 2 df_rolling = df.groupby(["season", "week"]).apply(lambda x: rolling_averages(x, cols, new_cols))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1556         with option_context("mode.chained_assignment", None):
#    1557             try:
# -> 1558                 result = self._python_apply_general(f, self._selected_obj)
#    1559             except TypeError:
#    1560                 # gh-20949
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1608             data after applying f
#    1609         """
# -> 1610         values, mutated = self.grouper.apply(f, data, self.axis)
#    1611         if not_indexed_same is None:
#    1612             not_indexed_same = mutated or self.mutated
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     837             # group might be modified
#     838             group_axes = group.axes
# --> 839             res = f(group)
#     840             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841                 mutated = True
#
# <ipython-input-82-34acf6b9f28d> in <lambda>(x)
#       1 #apply the new rolling_averages columns to each group
# ----> 2 df_rolling = df.groupby(["season", "week"]).apply(lambda x: rolling_averages(x, cols, new_cols))
#
# <ipython-input-79-00a92933bdc0> in rolling_averages(group, cols, new_cols)
#      17     # closed='left' to rolling(). However, this requires that the 'date' column be of type datetime, so make sure to convert
#      18     # it beforehand if it isn't already.
# ---> 19     group[new_cols] = rolling_stats
#      20     group = group.dropna(subset=new_cols) # Drop rows with missing values in the new columns.
#      21     return group
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3963             self._setitem_frame(key, value)
#    3964         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3965             self._setitem_array(key, value)
#    3966         elif isinstance(value, DataFrame):
#    3967             self._set_item_frame_value(key, value)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4005
#    4006             if isinstance(value, DataFrame):
# -> 4007                 check_key_length(self.columns, key, value)
#    4008                 for k1, k2 in zip(key, value.columns):
#    4009                     self[k1] = value[k2]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexers/utils.py in check_key_length(columns, key, value)
#     399     if columns.is_unique:
#     400         if len(value.columns) != len(key):
# --> 401             raise ValueError("Columns must be same length as key")
#     402     else:
#     403         # Missing keys in columns are represented as -1
#
# ValueError: Columns must be same length as key

# %%
df_rolling
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-eb944ee0fe0f> in <module>
# ----> 1 df_rolling
#
# NameError: name 'df_rolling' is not defined

# %%
# dropping extra index levels
df_rolling = df_rolling.droplevel('season')
df_rolling = df_rolling.droplevel('week')
df_rolling

# %%
df_rolling.dtypes

# %%
from sklearn.preprocessing import OneHotEncoder

#creating instance of one-hot-encoder
encoder = OneHotEncoder(handle_unknown='ignore')

#perform one-hot encoding on 'team' column 
encoder_df = pd.DataFrame(encoder.fit_transform(df_rolling[['away_t', 'home_t']]).toarray())

#merge one-hot encoded columns back with original DataFrame
a_df = df_rolling.join(encoder_df)

#view final df
a_df

#### Getting "NaN" values because the index doesnt match (i think)

# %%
df_rolling

# %%
# using pandas to convert the prepared dataframe into a csv file that is model ready.
df_rolling.to_csv("Data/transformed.csv", index=False)
