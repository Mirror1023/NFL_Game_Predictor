# %% [markdown]
# # 02 Data Prep

# %%
# common imports
import requests
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sys
from datetime import datetime

sys.executable
# Out:
# '/opt/anaconda3/bin/python'

# %%
# will display all the columns in the df now
pd.set_option('display.max_columns', 500)

# %%
sys.path
# Out:
# ['/Users/mirror/Desktop/GitHub/NFL_Game_Predictor',
#  '/opt/anaconda3/lib/python38.zip',
#  '/opt/anaconda3/lib/python3.8',
#  '/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/Users/mirror/.local/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/mirror/.ipython']

# %%
# Importing data from csv file
# avoid using hard coded paths like the next two lines
# path = "/Users/mirror/Desktop/GitHub/nfl_game_predictor/data/scraped_data.csv"
# df = pd.read_csv(path) # instead, use this

from src.config import DATA_DIR
path = DATA_DIR / 'scraped_data.csv'
df = pd.read_csv(path)

df.head(30)
# Out:
#     season team week  day          date       time result   ot record  \
# 0     2022  BUF    1  Thu   September 8  8:20PM ET      W  NaN    1-0
# 1     2022  BUF    2  Mon  September 19  7:15PM ET      W  NaN    2-0
# 2     2022  BUF    3  Sun  September 25  1:00PM ET      L  NaN    2-1
# 3     2022  BUF    4  Sun     October 2  1:00PM ET      W  NaN    3-1
# 4     2022  BUF    5  Sun     October 9  1:00PM ET      W  NaN    4-1
# 5     2022  BUF    6  Sun    October 16  4:25PM ET      W  NaN    5-1
# 6     2022  BUF    8  Sun    October 30  8:20PM ET      W  NaN    6-1
# 7     2022  NYJ    1  Sun  September 11  1:00PM ET      L  NaN    0-1
# 8     2022  NYJ    2  Sun  September 18  1:00PM ET      W  NaN    1-1
# 9     2022  NYJ    3  Sun  September 25  1:00PM ET      L  NaN    1-2
# 10    2022  NYJ    4  Sun     October 2  1:00PM ET      W  NaN    2-2
# 11    2022  NYJ    5  Sun     October 9  1:00PM ET      W  NaN    3-2
# 12    2022  NYJ    6  Sun    October 16  1:00PM ET      W  NaN    4-2
# 13    2022  NYJ    7  Sun    October 23  4:05PM ET      W  NaN    5-2
# 14    2022  NYJ    8  Sun    October 30  1:00PM ET      L  NaN    5-3
# 15    2022  MIA    1  Sun  September 11  1:00PM ET      W  NaN    1-0
# 16    2022  MIA    2  Sun  September 18  1:00PM ET      W  NaN    2-0
# 17    2022  MIA    3  Sun  September 25  1:00PM ET      W  NaN    3-0
# 18    2022  MIA    4  Thu  September 29  8:15PM ET      L  NaN    3-1
# 19    2022  MIA    5  Sun     October 9  1:00PM ET      L  NaN    3-2
# 20    2022  MIA    6  Sun    October 16  1:00PM ET      L  NaN    3-3
# 21    2022  MIA    7  Sun    October 23  8:20PM ET      W  NaN    4-3
# 22    2022  MIA    8  Sun    October 30  1:00PM ET      W  NaN    5-3
# 23    2022   NE    1  Sun  September 11  1:00PM ET      L  NaN    0-1
# 24    2022   NE    2  Sun  September 18  1:00PM ET      W  NaN    1-1
# 25    2022   NE    3  Sun  September 25  1:00PM ET      L  NaN    1-2
# 26    2022   NE    4  Sun     October 2  4:25PM ET      L   OT    1-3
# 27    2022   NE    5  Sun     October 9  1:00PM ET      W  NaN    2-3
# 28    2022   NE    6  Sun    October 16  1:00PM ET      W  NaN    3-3
# 29    2022   NE    7  Mon    October 24  8:15PM ET      L  NaN    3-4
#
#    home_team                   opp  points_scored  points_allowed  1st_downs  \
# 0          @      Los Angeles Rams           31.0            10.0       23.0
# 1        NaN      Tennessee Titans           41.0             7.0       23.0
# 2          @        Miami Dolphins           19.0            21.0       31.0
# 3          @      Baltimore Ravens           23.0            20.0       22.0
# 4        NaN   Pittsburgh Steelers           38.0             3.0       21.0
# 5          @    Kansas City Chiefs           24.0            20.0       26.0
# 6        NaN     Green Bay Packers           27.0            17.0       20.0
# 7        NaN      Baltimore Ravens            9.0            24.0       24.0
# 8          @      Cleveland Browns           31.0            30.0       20.0
# 9        NaN    Cincinnati Bengals           12.0            27.0       19.0
# 10         @   Pittsburgh Steelers           24.0            20.0       19.0
# 11       NaN        Miami Dolphins           40.0            17.0       21.0
# 12         @     Green Bay Packers           27.0            10.0       14.0
# 13         @        Denver Broncos           16.0             9.0       10.0
# 14       NaN  New England Patriots           17.0            22.0       17.0
# 15       NaN  New England Patriots           20.0             7.0       18.0
# 16         @      Baltimore Ravens           42.0            38.0       27.0
# 17       NaN         Buffalo Bills           21.0            19.0       15.0
# 18         @    Cincinnati Bengals           15.0            27.0       20.0
# 19         @         New York Jets           17.0            40.0       19.0
# 20       NaN     Minnesota Vikings           16.0            24.0       23.0
# 21       NaN   Pittsburgh Steelers           16.0            10.0       17.0
# 22         @         Detroit Lions           31.0            27.0       27.0
# 23         @        Miami Dolphins            7.0            20.0       17.0
# 24         @   Pittsburgh Steelers           17.0            14.0       18.0
# 25       NaN      Baltimore Ravens           26.0            37.0       22.0
# 26         @     Green Bay Packers           24.0            27.0       17.0
# 27       NaN         Detroit Lions           29.0             0.0       22.0
# 28         @      Cleveland Browns           38.0            15.0       20.0
# 29       NaN         Chicago Bears           14.0            33.0       12.0
#
#     totyd  passyd  rushyd   to  1st_downs_allowed  totyd_allowed  \
# 0   413.0   292.0   121.0  4.0               19.0          243.0
# 1   414.0   313.0   101.0  NaN               12.0          187.0
# 2   497.0   382.0   115.0  1.0               15.0          212.0
# 3   326.0   201.0   125.0  2.0               22.0          296.0
# 4   552.0   432.0   120.0  2.0               23.0          364.0
# 5   443.0   318.0   125.0  1.0               23.0          387.0
# 6   369.0   216.0   153.0  2.0               21.0          398.0
# 7   380.0   297.0    83.0  2.0               13.0          274.0
# 8   402.0   309.0    93.0  1.0               29.0          405.0
# 9   328.0   252.0    76.0  4.0               20.0          330.0
# 10  348.0   250.0    98.0  2.0               20.0          297.0
# 11  322.0   187.0   135.0  NaN               19.0          295.0
# 12  278.0    99.0   179.0  NaN               15.0          278.0
# 13  260.0   105.0   155.0  NaN               21.0          324.0
# 14  387.0   336.0    51.0  3.0               19.0          288.0
# 15  307.0   242.0    65.0  NaN               17.0          271.0
# 16  547.0   461.0    86.0  2.0               23.0          473.0
# 17  212.0   171.0    41.0  NaN               31.0          497.0
# 18  378.0   293.0    85.0  2.0               16.0          371.0
# 19  295.0   158.0   137.0  2.0               21.0          322.0
# 20  458.0   385.0    73.0  3.0               11.0          234.0
# 21  372.0   261.0   111.0  NaN               19.0          341.0
# 22  476.0   369.0   107.0  1.0               22.0          393.0
# 23  271.0   193.0    78.0  3.0               18.0          307.0
# 24  376.0   252.0   124.0  1.0               16.0          243.0
# 25  447.0   302.0   145.0  4.0               19.0          394.0
# 26  271.0   104.0   167.0  1.0               24.0          443.0
# 27  364.0   188.0   176.0  1.0               17.0          312.0
# 28  399.0   301.0    98.0  1.0               16.0          328.0
# 29  260.0   190.0    70.0  4.0               24.0          390.0
#
#     passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
# 0            191.0            52.0        3.0        13.89        10.29
# 1            107.0            80.0        4.0        17.69        18.01
# 2            171.0            41.0        NaN        15.88        -7.45
# 3            134.0           162.0        2.0         2.10         2.66
# 4            310.0            54.0        2.0        20.66         9.42
# 5            319.0            68.0        2.0        11.13        -6.45
# 6            190.0           208.0        1.0        12.79        -5.55
# 7            211.0            63.0        1.0        -8.07        -3.65
# 8            221.0           184.0        1.0        15.19       -17.92
# 9            261.0            69.0        1.0       -16.45        -3.99
# 10           178.0           119.0        4.0        -1.46         2.55
# 11           158.0           137.0        2.0        11.86         6.15
# 12           218.0            60.0        1.0        -2.59        16.24
# 13           219.0           105.0        1.0        -8.14         8.53
# 14           161.0           127.0        1.0        -2.30         9.31
# 15           193.0            78.0        3.0         6.08         8.28
# 16           318.0           155.0        NaN        32.00       -20.31
# 17           382.0           115.0        1.0         7.45       -15.88
# 18           304.0            67.0        NaN         0.48        -9.11
# 19           187.0           135.0        NaN        -6.15       -11.86
# 20           156.0            78.0        NaN        -8.38         4.43
# 21           246.0            95.0        3.0         0.04         6.72
# 22           311.0            82.0        NaN        25.47       -19.14
# 23           242.0            65.0        NaN        -8.28        -6.08
# 24           152.0            91.0        2.0         6.14         3.44
# 25           206.0           188.0        2.0         3.50       -11.67
# 26           244.0           199.0        2.0        -2.00        -5.17
# 27           211.0           101.0        2.0        10.08        22.04
# 28           258.0            70.0        4.0        11.30        12.35
# 29           147.0           243.0        1.0       -10.97        -8.77
#
#     sts_exp_pts
# 0         -3.96
# 1          1.55
# 2         -4.86
# 3         -1.69
# 4          3.54
# 5          0.56
# 6          4.01
# 7         -5.04
# 8          5.38
# 9          6.98
# 10         2.91
# 11         3.66
# 12         4.32
# 13         8.12
# 14       -12.01
# 15         1.98
# 16        -7.09
# 17         4.86
# 18        -3.73
# 19        -3.66
# 20        -4.75
# 21        -2.49
# 22        -0.59
# 23        -1.98
# 24        -3.25
# 25        -3.18
# 26         2.64
# 27        -3.38
# 28        -0.09
# 29        -0.11

# %% [markdown]
# ### Quick Exploration

# %%
df.shape
# Out:
# (15000, 26)

# %%
df.dtypes
# Out:
# season                 int64
# team                  object
# week                  object
# day                   object
# date                  object
# time                  object
# result                object
# ot                    object
# record                object
# home_team             object
# opp                   object
# points_scored        float64
# points_allowed       float64
# 1st_downs            float64
# totyd                float64
# passyd               float64
# rushyd               float64
# to                   float64
# 1st_downs_allowed    float64
# totyd_allowed        float64
# passyd_allowed       float64
# rushyd_allowed       float64
# to_forced            float64
# off_exp_pts          float64
# def_exp_pts          float64
# sts_exp_pts          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# season                   0
# team                     0
# week                     0
# day                      0
# date                     0
# time                     0
# result                   0
# ot                   14078
# record                   0
# home_team             7472
# opp                      0
# points_scored            0
# points_allowed           0
# 1st_downs                0
# totyd                    0
# passyd                   2
# rushyd                   0
# to                    3287
# 1st_downs_allowed        0
# totyd_allowed            0
# passyd_allowed           2
# rushyd_allowed           0
# to_forced             3287
# off_exp_pts              0
# def_exp_pts              0
# sts_exp_pts              0
# dtype: int64

# %%
df['ot'].isnull().sum()
# Out:
# 14078

# %%
# discovering how many times an opponent played a game
df.opp.value_counts()
# Out:
# New England Patriots        506
# Green Bay Packers           498
# Pittsburgh Steelers         493
# Indianapolis Colts          489
# Philadelphia Eagles         487
# Seattle Seahawks            485
# San Francisco 49ers         484
# Denver Broncos              480
# Kansas City Chiefs          478
# Minnesota Vikings           477
# Dallas Cowboys              477
# New Orleans Saints          476
# Atlanta Falcons             475
# New York Giants             474
# Tampa Bay Buccaneers        474
# New York Jets               471
# Miami Dolphins              470
# Arizona Cardinals           469
# Chicago Bears               468
# Buffalo Bills               468
# Cincinnati Bengals          468
# Detroit Lions               463
# Carolina Panthers           458
# Jacksonville Jaguars        455
# Baltimore Ravens            452
# Washington Redskins         423
# Cleveland Browns            414
# Oakland Raiders             408
# Tennessee Titans            394
# San Diego Chargers          382
# St. Louis Rams              346
# Houston Texans              339
# Los Angeles Rams            130
# Los Angeles Chargers         90
# Houston Oilers               48
# Las Vegas Raiders            41
# Washington Football Team     34
# Tennessee Oilers             32
# Los Angeles Raiders          16
# Washington Commanders         8
# Name: opp, dtype: int64

# %%
# # importing a new library that was recommended to me by my mentor
# import sweetviz as sv

# df_report = sv.analyze(df)
# df_report.show_html()
# #df_report.show_notebook()

# %%
# compares two dataframes via sweetviz
#df_comp = sv.compare(df)

# %%
# another way to get great insights is to use the comparison functionality to split your dataset into 2 sub-populations.
#df_comp_intra = sv.compare_intra(df)

# %% [markdown]
# ### Initial Data Cleansing

# %%
# there are only supposed to be 32 teams in the NFL. some teams have changed their name and/or location.
len(df.opp.unique())
# Out:
# 40

# %%
# some teams have changed their name and/or location, which created another opponent.
# manually replacing team names.
df.loc[df["opp"] == "Washington Redskins", "opp"] = "Washington Commanders"
df.loc[df["opp"] == "Washington Football Team", "opp"] = "Washington Commanders"
df.loc[df["opp"] == "Oakland Raiders", "opp"] = "Las Vegas Raiders"
df.loc[df["opp"] == "Los Angeles Raiders", "opp"] = "Las Vegas Raiders"
df.loc[df["opp"] == "Houston Oilers", "opp"] = "Tennessee Titans"
df.loc[df["opp"] == "Tennessee Oilers", "opp"] = "Tennessee Titans"
df.loc[df["opp"] == "San Diego Chargers", "opp"] = "Los Angeles Chargers"
df.loc[df["opp"] == "St. Louis Rams", "opp"] = "Los Angeles Rams"

# %%
# verifying that there are only 32 teams in the df.opp column now.
len(df.opp.unique())
# Out:
# 32

# %%
# first sort the df by season and week
df = df.sort_values(by=['season', 'week'], ascending=[False, True])

# %%
# right now, we two records for each game played because we scraped the data for each team's season
# we need to reduce the df to only have one record for each game played
df.head(33)
# Out:
#      season team week  day          date       time result   ot record  \
# 0      2022  BUF    1  Thu   September 8  8:20PM ET      W  NaN    1-0
# 7      2022  NYJ    1  Sun  September 11  1:00PM ET      L  NaN    0-1
# 15     2022  MIA    1  Sun  September 11  1:00PM ET      W  NaN    1-0
# 23     2022   NE    1  Sun  September 11  1:00PM ET      L  NaN    0-1
# 31     2022  BAL    1  Sun  September 11  1:00PM ET      W  NaN    1-0
# 39     2022  CIN    1  Sun  September 11  1:00PM ET      L   OT    0-1
# 47     2022  CLE    1  Sun  September 11  1:00PM ET      W  NaN    1-0
# 55     2022  PIT    1  Sun  September 11  1:00PM ET      W   OT    1-0
# 63     2022  TEN    1  Sun  September 11  4:25PM ET      L  NaN    0-1
# 70     2022  IND    1  Sun  September 11  1:00PM ET      T   OT  0-0-1
# 78     2022  JAX    1  Sun  September 11  1:00PM ET      L  NaN    0-1
#
# 131           195.0           152.0        1.0       -19.40        -0.55
# 139           266.0            93.0        1.0         3.72        -5.97
# 147           260.0           123.0        1.0         9.54        -3.64
# 155           227.0           111.0        2.0         9.99         1.89
# 162           269.0           126.0        NaN        -1.89        -9.99
# 170           155.0           176.0        2.0         0.67        11.26
# 178           239.0           216.0        NaN        15.67       -21.15
# 185           234.0           151.0        1.0         7.50        -4.62
# 193           173.0            71.0        1.0         0.55        19.40
# 201           215.0           201.0        2.0         4.62        -7.50
# 209           138.0           217.0        NaN         5.38        -6.82
# 217           330.0           103.0        2.0         4.10        -9.94
# 225           105.0            99.0        1.0       -11.26        -0.67
# 233           292.0           121.0        4.0       -10.29       -13.89
# 240           360.0           128.0        1.0         2.29       -33.41
# 1             107.0            80.0        4.0        17.69        18.01
#
#      sts_exp_pts
# 0          -3.96
# 7          -5.04
# 15          1.98
# 23         -1.98
# 31          5.04
# 39         -4.85
# 47          1.66
# 55          4.85
# 63         -2.44
# 70         -9.43
# 78         -0.26
# 86          9.43
# 94         -6.88
# 101        -1.95
# 108        -6.84
# 116         1.95
# 123        -0.78
# 131         2.24
# 139         2.44
# 147         0.26
# 155         1.12
# 162        -1.12
# 170        -0.42
# 178         0.78
# 185         0.51
# 193        -2.24
# 201        -0.51
# 209        -1.66
# 217         6.84
# 225         0.42
# 233         3.96
# 240         6.88
# 1           1.55

# %%
df
# Out:
#        season team       week  day          date        time result   ot  \
# 0        2022  BUF          1  Thu   September 8   8:20PM ET      W  NaN
# 7        2022  NYJ          1  Sun  September 11   1:00PM ET      L  NaN
# 15       2022  MIA          1  Sun  September 11   1:00PM ET      W  NaN
# 23       2022   NE          1  Sun  September 11   1:00PM ET      L  NaN
# 31       2022  BAL          1  Sun  September 11   1:00PM ET      W  NaN
# ...       ...  ...        ...  ...           ...         ...    ...  ...
# 14716    1994   KC  Wild Card  Sat   December 31   4:00PM ET      L  NaN
# 14863    1994  MIN  Wild Card  Sun     January 1   4:00PM ET      L  NaN
# 14880    1994   GB  Wild Card  Sat   December 31  12:30PM ET      W  NaN
# 14898    1994  DET  Wild Card  Sat   December 31  12:30PM ET      L  NaN
# 14915    1994  CHI  Wild Card  Sun     January 1   4:00PM ET      W  NaN
#
#       record home_team                   opp  points_scored  points_allowed  \
# 0        1-0         @      Los Angeles Rams           31.0            10.0
# 7        0-1       NaN      Baltimore Ravens            9.0            24.0
# 15       1-0       NaN  New England Patriots           20.0             7.0
# 23       0-1         @        Miami Dolphins            7.0            20.0
# 31       1-0         @         New York Jets           24.0             9.0
# ...      ...       ...                   ...            ...             ...
# 14716    9-8         @        Miami Dolphins           17.0            27.0
# 14863   10-7       NaN         Chicago Bears           18.0            35.0
# 14880   10-7       NaN         Detroit Lions           16.0            12.0
# 14898    9-8         @     Green Bay Packers           12.0            16.0
# 14915   10-7         @     Minnesota Vikings           35.0            18.0
#
#        1st_downs  totyd  passyd  rushyd   to  1st_downs_allowed  \
# 0           23.0  413.0   292.0   121.0  4.0               19.0
# 7           24.0  380.0   297.0    83.0  2.0               13.0
# 15          18.0  307.0   242.0    65.0  NaN               17.0
# 23          17.0  271.0   193.0    78.0  3.0               18.0
# 31          13.0  274.0   211.0    63.0  1.0               24.0
# ...          ...    ...     ...     ...  ...                ...
# 14716       24.0  414.0   314.0   100.0  2.0               22.0
# 14863       22.0  389.0   340.0    49.0  4.0               18.0
# 14880       18.0  336.0   255.0    81.0  NaN                9.0
# 14898        9.0  171.0   175.0    -4.0  NaN               18.0
# 14915       18.0  308.0   214.0    94.0  2.0               22.0
#
#        totyd_allowed  passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  \
# 0              243.0           191.0            52.0        3.0        13.89
# 7              274.0           211.0            63.0        1.0        -8.07
# 15             271.0           193.0            78.0        3.0         6.08
# 23             307.0           242.0            65.0        NaN        -8.28
# 31             380.0           297.0            83.0        2.0         3.65
# ...              ...             ...             ...        ...          ...
# 14716          381.0           249.0           132.0        NaN         8.31
# 14863          308.0           214.0            94.0        2.0        -9.54
# 14880          171.0           175.0            -4.0        NaN        -2.93
# 14898          336.0           255.0            81.0        NaN       -11.53
# 14915          389.0           340.0            49.0        4.0         6.07
#
#        def_exp_pts  sts_exp_pts
# 0            10.29        -3.96
# 7            -3.65        -5.04
# 15            8.28         1.98
# 23           -6.08        -1.98
# 31            8.07         5.04
# ...            ...          ...
# 14716       -15.96        -1.16
# 14863        -6.07         0.65
# 14880        11.53         0.69
# 14898         2.93        -0.69
# 14915         9.54        -0.65
#
# [15000 rows x 26 columns]

# %%
# Team name was abbreviated, making it match to opp name
z = set(df['team'].values.tolist())
y = set(df['opp'].values.tolist())
z = list(z)
z.sort()
y = list(y)
y.sort()

# %%
len(y)
# Out:
# 32

# %%
y
# Out:
# ['Arizona Cardinals',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'Jacksonville Jaguars',
#  'Kansas City Chiefs',
#  'Las Vegas Raiders',
#  'Los Angeles Chargers',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Tennessee Titans',
#  'Washington Commanders']

# %%
# we must reorder a couple of teams in z so that it matches y
z
# Out:
# ['ARZ',
#  'ATL',
#  'BAL',
#  'BUF',
#  'CAR',
#  'CHI',
#  'CIN',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GB',
#  'HOU',
#  'IND',
#  'JAX',
#  'KC',
#  'LAC',
#  'LAR',
#  'LV',
#  'MIA',
#  'MIN',
#  'NE',
#  'NO',
#  'NYG',
#  'NYJ',
#  'PHI',
#  'PIT',
#  'SEA',
#  'SF',
#  'TB',
#  'TEN',
#  'WAS']

# %%
z = z[0:16] + z[18:19] + z[16:17] + z[17:18] + z[19:-5] + z[-4:-3] + z[-5:-4] + z[-3:]
z
# Out:
# ['ARZ',
#  'ATL',
#  'BAL',
#  'BUF',
#  'CAR',
#  'CHI',
#  'CIN',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GB',
#  'HOU',
#  'IND',
#  'JAX',
#  'KC',
#  'LV',
#  'LAC',
#  'LAR',
#  'MIA',
#  'MIN',
#  'NE',
#  'NO',
#  'NYG',
#  'NYJ',
#  'PHI',
#  'PIT',
#  'SF',
#  'SEA',
#  'TB',
#  'TEN',
#  'WAS']

# %%
len(set(z))
# Out:
# 32

# %%
# creating dictionary with the two lists (z & y)
team_dict = dict(zip(z, y))
len(team_dict)
# Out:
# 32

# %%
# using the manually created team_dictionary to replace the team names.
df = df.replace({"team": team_dict})

# %%
df
# Out:
#        season                  team       week  day          date        time  \
# 0        2022         Buffalo Bills          1  Thu   September 8   8:20PM ET
# 7        2022         New York Jets          1  Sun  September 11   1:00PM ET
# 15       2022        Miami Dolphins          1  Sun  September 11   1:00PM ET
# 23       2022  New England Patriots          1  Sun  September 11   1:00PM ET
# 31       2022      Baltimore Ravens          1  Sun  September 11   1:00PM ET
# ...       ...                   ...        ...  ...           ...         ...
# 14716    1994    Kansas City Chiefs  Wild Card  Sat   December 31   4:00PM ET
# 14863    1994     Minnesota Vikings  Wild Card  Sun     January 1   4:00PM ET
# 14880    1994     Green Bay Packers  Wild Card  Sat   December 31  12:30PM ET
# 14898    1994         Detroit Lions  Wild Card  Sat   December 31  12:30PM ET
# 14915    1994         Chicago Bears  Wild Card  Sun     January 1   4:00PM ET
#
#       result   ot record home_team                   opp  points_scored  \
# 0          W  NaN    1-0         @      Los Angeles Rams           31.0
# 7          L  NaN    0-1       NaN      Baltimore Ravens            9.0
# 15         W  NaN    1-0       NaN  New England Patriots           20.0
# 23         L  NaN    0-1         @        Miami Dolphins            7.0
# 31         W  NaN    1-0         @         New York Jets           24.0
# ...      ...  ...    ...       ...                   ...            ...
# 14716      L  NaN    9-8         @        Miami Dolphins           17.0
# 14863      L  NaN   10-7       NaN         Chicago Bears           18.0
# 14880      W  NaN   10-7       NaN         Detroit Lions           16.0
# 14898      L  NaN    9-8         @     Green Bay Packers           12.0
# 14915      W  NaN   10-7         @     Minnesota Vikings           35.0
#
#        points_allowed  1st_downs  totyd  passyd  rushyd   to  \
# 0                10.0       23.0  413.0   292.0   121.0  4.0
# 7                24.0       24.0  380.0   297.0    83.0  2.0
# 15                7.0       18.0  307.0   242.0    65.0  NaN
# 23               20.0       17.0  271.0   193.0    78.0  3.0
# 31                9.0       13.0  274.0   211.0    63.0  1.0
# ...               ...        ...    ...     ...     ...  ...
# 14716            27.0       24.0  414.0   314.0   100.0  2.0
# 14863            35.0       22.0  389.0   340.0    49.0  4.0
# 14880            12.0       18.0  336.0   255.0    81.0  NaN
# 14898            16.0        9.0  171.0   175.0    -4.0  NaN
# 14915            18.0       18.0  308.0   214.0    94.0  2.0
#
#        1st_downs_allowed  totyd_allowed  passyd_allowed  rushyd_allowed  \
# 0                   19.0          243.0           191.0            52.0
# 7                   13.0          274.0           211.0            63.0
# 15                  17.0          271.0           193.0            78.0
# 23                  18.0          307.0           242.0            65.0
# 31                  24.0          380.0           297.0            83.0
# ...                  ...            ...             ...             ...
# 14716               22.0          381.0           249.0           132.0
# 14863               18.0          308.0           214.0            94.0
# 14880                9.0          171.0           175.0            -4.0
# 14898               18.0          336.0           255.0            81.0
# 14915               22.0          389.0           340.0            49.0
#
#        to_forced  off_exp_pts  def_exp_pts  sts_exp_pts
# 0            3.0        13.89        10.29        -3.96
# 7            1.0        -8.07        -3.65        -5.04
# 15           3.0         6.08         8.28         1.98
# 23           NaN        -8.28        -6.08        -1.98
# 31           2.0         3.65         8.07         5.04
# ...          ...          ...          ...          ...
# 14716        NaN         8.31       -15.96        -1.16
# 14863        2.0        -9.54        -6.07         0.65
# 14880        NaN        -2.93        11.53         0.69
# 14898        NaN       -11.53         2.93        -0.69
# 14915        4.0         6.07         9.54        -0.65
#
# [15000 rows x 26 columns]

# %%
# create home team and away team columns
h = []
a = [] 
count = 0

afc = ['Baltimore Ravens', 'Buffalo Bills', 'Cincinnati Bengals', 'Cleveland Browns', 'Denver Broncos', 'Houston Texans', 
       'Indianapolis Colts', 'Jacksonville Jaguars', 'Kansas City Chiefs', 'Las Vegas Raiders','Los Angeles Chargers', 
       'Miami Dolphins', 'New England Patriots', 'New York Jets', 'Pittsburgh Steelers', 'Tennessee Titans']

nfc = ['Arizona Cardinals', 'Atlanta Falcons', 'Carolina Panthers', 'Chicago Bears', 'Dallas Cowboys', 'Detroit Lions',
       'Green Bay Packers', 'Los Angeles Rams', 'Minnesota Vikings', 'New Orleans Saints', 'New York Giants',
       'Philadelphia Eagles', 'San Francisco 49ers', 'Seattle Seahawks', 'Tampa Bay Buccaneers', 'Washington Commanders']

for i in df['home_team']:
    if '@' in str(i):
        h.append(df['opp'].iloc[count])
        a.append(df['team'].iloc[count])
    elif 'N' in str(i): # this entire elif block is to compensate for games in a neutral 'N' stadium specifically for SuperBowls.
        if int(df['season'].iloc[count])%2 == 0:
            if df['team'].iloc[count] in afc:
                h.append(df['team'].iloc[count])
                a.append(df['opp'].iloc[count])
            else: 
                h.append(df['opp'].iloc[count])
                a.append(df['team'].iloc[count])
        else:
            if df['team'].iloc[count] in nfc:
                h.append(df['team'].iloc[count])
                a.append(df['opp'].iloc[count])
            else:
                h.append(df['opp'].iloc[count])
                a.append(df['team'].iloc[count])
    else:
        h.append(df['team'].iloc[count])
        a.append(df['opp'].iloc[count])
    count += 1
        
df = df.assign(away_t = a)
df = df.assign(home_t = h)

# %%
# we have two rows of data for each game so we will reduce it to one row for each game
df = df.drop_duplicates(subset=['season', 'week', 'home_t', 'away_t'])

# %%
# reset index
df = df.reset_index(drop=True)

# %%
df = df.sort_values(by=['season', 'week'], ascending=[False, True])
# thinks season and week columns are string datatypes

# %%
df
# Out:
#       season                  team       week  day          date        time  \
# 0       2022         Buffalo Bills          1  Thu   September 8   8:20PM ET
# 1       2022         New York Jets          1  Sun  September 11   1:00PM ET
# 2       2022        Miami Dolphins          1  Sun  September 11   1:00PM ET
# 3       2022    Cincinnati Bengals          1  Sun  September 11   1:00PM ET
# 4       2022      Cleveland Browns          1  Sun  September 11   1:00PM ET
# ...      ...                   ...        ...  ...           ...         ...
# 7495    1994  Los Angeles Chargers  SuperBowl  Sun    January 29   6:00PM ET
# 7496    1994        Miami Dolphins  Wild Card  Sat   December 31   4:00PM ET
# 7497    1994  New England Patriots  Wild Card  Sun     January 1  12:30PM ET
# 7498    1994     Minnesota Vikings  Wild Card  Sun     January 1   4:00PM ET
# 7499    1994     Green Bay Packers  Wild Card  Sat   December 31  12:30PM ET
#
#      result   ot record home_team                   opp  points_scored  \
# 0         W  NaN    1-0         @      Los Angeles Rams           31.0
# 1         L  NaN    0-1       NaN      Baltimore Ravens            9.0
# 2         W  NaN    1-0       NaN  New England Patriots           20.0
# 3         L   OT    0-1       NaN   Pittsburgh Steelers           20.0
# 4         W  NaN    1-0         @     Carolina Panthers           26.0
# ...     ...  ...    ...       ...                   ...            ...
# 7495      L  NaN   13-6         N   San Francisco 49ers           26.0
# 7496      W  NaN   11-6       NaN    Kansas City Chiefs           27.0
# 7497      L  NaN   10-7         @      Cleveland Browns           13.0
# 7498      L  NaN   10-7       NaN         Chicago Bears           18.0
# 7499      W  NaN   10-7       NaN         Detroit Lions           16.0
#
#       points_allowed  1st_downs  totyd  passyd  rushyd   to  \
# 0               10.0       23.0  413.0   292.0   121.0  4.0
# 1               24.0       24.0  380.0   297.0    83.0  2.0
# 2                7.0       18.0  307.0   242.0    65.0  NaN
# 3               23.0       32.0  432.0   299.0   133.0  5.0
# 4               24.0       23.0  355.0   138.0   217.0  NaN
# ...              ...        ...    ...     ...     ...  ...
# 7495            49.0       20.0  354.0   287.0    67.0  3.0
# 7496            17.0       22.0  381.0   249.0   132.0  NaN
# 7497            20.0       20.0  303.0   246.0    57.0  3.0
# 7498            35.0       22.0  389.0   340.0    49.0  4.0
# 7499            12.0       18.0  336.0   255.0    81.0  NaN
#
#       1st_downs_allowed  totyd_allowed  passyd_allowed  rushyd_allowed  \
# 0                  19.0          243.0           191.0            52.0
# 1                  13.0          274.0           211.0            63.0
# 2                  17.0          271.0           193.0            78.0
# 3                  13.0          267.0           192.0            75.0
# 4                  15.0          261.0           207.0            54.0
# ...                 ...            ...             ...             ...
# 7495               28.0          455.0           316.0           139.0
# 7496               24.0          414.0           314.0           100.0
# 7497               22.0          379.0           254.0           125.0
# 7498               18.0          308.0           214.0            94.0
# 7499                9.0          171.0           175.0            -4.0
#
#       to_forced  off_exp_pts  def_exp_pts  sts_exp_pts                away_t  \
# 0           3.0        13.89        10.29        -3.96         Buffalo Bills
# 1           1.0        -8.07        -3.65        -5.04      Baltimore Ravens
# 2           3.0         6.08         8.28         1.98  New England Patriots
# 3           NaN        -7.49         8.41        -4.85   Pittsburgh Steelers
# 4           1.0         6.82        -5.38         1.66      Cleveland Browns
# ...         ...          ...          ...          ...                   ...
# 7495        NaN        -3.94       -27.02         4.06   San Francisco 49ers
# 7496        2.0        15.96        -8.31         1.16    Kansas City Chiefs
# 7497        1.0       -11.86        -8.13        10.97  New England Patriots
# 7498        2.0        -9.54        -6.07         0.65         Chicago Bears
# 7499        NaN        -2.93        11.53         0.69         Detroit Lions
#
#                     home_t
# 0         Los Angeles Rams
# 1            New York Jets
# 2           Miami Dolphins
# 3       Cincinnati Bengals
# 4        Carolina Panthers
# ...                    ...
# 7495  Los Angeles Chargers
# 7496        Miami Dolphins
# 7497      Cleveland Browns
# 7498     Minnesota Vikings
# 7499     Green Bay Packers
#
# [7500 rows x 28 columns]

# %%
df.tail(50)
# Out:
#       season                  team          week  day         date  \
# 7450    1994     Green Bay Packers             6  Sun    October 9
# 7451    1994         Detroit Lions             6  Sun    October 9
# 7452    1994         Chicago Bears             6  Sun    October 9
# 7453    1994  Tampa Bay Buccaneers             6  Sun    October 9
# 7454    1994        Miami Dolphins             7  Sun   October 16
# 7455    1994  New England Patriots             7  Sun   October 16
# 7456    1994    Indianapolis Colts             7  Sun   October 16
# 7457    1994   Pittsburgh Steelers             7  Sun   October 16
# 7458    1994      Cleveland Browns             7  Thu   October 13
# 7459    1994  Los Angeles Chargers             7  Sun   October 16
# 7460    1994    Kansas City Chiefs             7  Mon   October 17
# 7463        5.0       -20.42        30.17        -2.17      Arizona Cardinals
# 7464        6.0         4.16        34.38         4.54    San Francisco 49ers
# 7465        NaN        -1.26       -12.43        -1.27  Washington Commanders
# 7466        3.0       -27.25        28.25         0.14    Pittsburgh Steelers
# 7467        1.0        -8.78        16.23        22.64     Cincinnati Bengals
# 7468        2.0       -17.25         5.52        -2.98       Tennessee Titans
# 7469        3.0       -17.05        14.26        -0.12         Denver Broncos
# 7470        2.0        16.95        -0.26        -1.67       Seattle Seahawks
# 7471        2.0         1.44         1.86         4.10        Atlanta Falcons
# 7472        NaN        10.71        -3.98        -3.24         Dallas Cowboys
# 7473        2.0       -22.19        34.26        -3.95      Green Bay Packers
# 7474        4.0       -17.35        10.02         5.27          Chicago Bears
# 7475        1.0        -3.33       -24.24        -1.83   Tampa Bay Buccaneers
# 7476        3.0        -6.28        13.61       -10.30       Los Angeles Rams
# 7477        3.0        -5.64        27.59         1.87         Miami Dolphins
# 7478        1.0        -0.71        14.87        -7.33          New York Jets
# 7479        5.0         9.49        23.88         4.11     Kansas City Chiefs
# 7480        1.0        -6.86        -2.29         3.33    Pittsburgh Steelers
# 7481        2.0        -2.40        -6.66         2.08       Cleveland Browns
# 7482        2.0         0.30         1.58         3.82         Dallas Cowboys
# 7483        4.0        -5.92        42.91       -20.91       Tennessee Titans
# 7484        2.0         5.91        15.49         3.99       Seattle Seahawks
# 7485        3.0        -0.70       -11.16         4.34          Detroit Lions
# 7486        3.0         5.55         0.25       -10.57    Philadelphia Eagles
# 7487        5.0         5.32        16.03         9.45      Minnesota Vikings
# 7488        5.0         3.96        25.96        -5.90      Green Bay Packers
# 7489        1.0         2.66        -0.91        -0.81   Los Angeles Chargers
# 7490        1.0         2.21       -10.92        -4.23         Dallas Cowboys
# 7491        3.0         9.78        -9.16        -3.54         Miami Dolphins
# 7492        2.0         8.48        13.86        -2.06       Cleveland Browns
# 7493        1.0        11.52         7.11         0.15      Green Bay Packers
# 7494        1.0        -7.73       -18.15         1.38          Chicago Bears
# 7495        NaN        -3.94       -27.02         4.06    San Francisco 49ers
# 7496        2.0        15.96        -8.31         1.16     Kansas City Chiefs
# 7497        1.0       -11.86        -8.13        10.97   New England Patriots
# 7498        2.0        -9.54        -6.07         0.65          Chicago Bears
# 7499        NaN        -2.93        11.53         0.69          Detroit Lions
#
#                      home_t
# 7450      Green Bay Packers
# 7451          Detroit Lions
# 7452          Chicago Bears
# 7453        Atlanta Falcons
# 7454         Miami Dolphins
# 7455          New York Jets
# 7456          Buffalo Bills
# 7457    Pittsburgh Steelers
# 7458       Tennessee Titans
# 7459     New Orleans Saints
# 7460         Denver Broncos
# 7461         Dallas Cowboys
# 7462       Los Angeles Rams
# 7463  Washington Commanders
# 7464        Atlanta Falcons
# 7465     Indianapolis Colts
# 7466        New York Giants
# 7467       Cleveland Browns
# 7468    Philadelphia Eagles
# 7469   Los Angeles Chargers
# 7470     Kansas City Chiefs
# 7471      Las Vegas Raiders
# 7472      Arizona Cardinals
# 6758    1997        Denver Broncos  SuperBowl  Sun   January 25  6:30PM ET
# 7009    1996  New England Patriots  SuperBowl  Sun   January 26  6:30PM ET
# 7260    1995   Pittsburgh Steelers  SuperBowl  Sun   January 28  6:33PM ET
# 7495    1994  Los Angeles Chargers  SuperBowl  Sun   January 29  6:00PM ET
#
#      result   ot record home_team                   opp  points_scored  \
# 402       L  NaN   13-8         N      Los Angeles Rams           20.0
# 671       L  NaN   16-3         N  Tampa Bay Buccaneers            9.0
# 940       W  NaN   15-4         N   San Francisco 49ers           31.0
# 1207      W  NaN   14-5         N      Los Angeles Rams           13.0
# 1474      L  NaN   15-4         N   Philadelphia Eagles           33.0
# 1741      W   OT   17-2         N       Atlanta Falcons           34.0
# 2008      W  NaN   15-4         N     Carolina Panthers           24.0
# 2275      W  NaN   15-4         N      Seattle Seahawks           28.0
# 2542      L  NaN   15-4         N      Seattle Seahawks            8.0
# 2809      W  NaN   14-6         N   San Francisco 49ers           34.0
# 3076      L  NaN   15-4         N       New York Giants           17.0
# 3343      L  NaN   14-5         N     Green Bay Packers           25.0
# 3610      L  NaN   16-3         N    New Orleans Saints           17.0
# 3877      W  NaN   15-4         N     Arizona Cardinals           27.0
# 4144      L  NaN   18-1         N       New York Giants           14.0
# 4411      W  NaN   16-4         N         Chicago Bears           29.0
# 4678      W  NaN   15-5         N      Seattle Seahawks           21.0
# 4945      W  NaN   17-2         N   Philadelphia Eagles           24.0
# 5212      W  NaN   17-2         N     Carolina Panthers           32.0
# 5479      L  NaN   13-6         N  Tampa Bay Buccaneers           21.0
# 5738      W  NaN   14-5         N      Los Angeles Rams           20.0
# 5997      W  NaN   16-4         N       New York Giants           34.0
# 6256      L  NaN   16-4         N      Los Angeles Rams           16.0
# 6507      W  NaN   17-2         N       Atlanta Falcons           34.0
# 6758      W  NaN   16-4         N     Green Bay Packers           31.0
# 7009      L  NaN   13-6         N     Green Bay Packers           21.0
# 7260      L  NaN   13-6         N        Dallas Cowboys           17.0
# 7495      L  NaN   13-6         N   San Francisco 49ers           26.0
#
#       points_allowed  1st_downs  totyd  passyd  rushyd   to  \
# 402             23.0       15.0  305.0   226.0    79.0  NaN
# 671             31.0       22.0  350.0   243.0   107.0  2.0
# 940             20.0       26.0  397.0   268.0   129.0  2.0
# 1207             3.0       22.0  407.0   253.0   154.0  1.0
# 1474            41.0       29.0  613.0   500.0   113.0  1.0
# 1741            28.0       37.0  546.0   442.0   104.0  2.0
# 2008            10.0       11.0  194.0   104.0    90.0  2.0
# 2275            24.0       25.0  377.0   320.0    57.0  2.0
# 2542            43.0       18.0  306.0   279.0    27.0  4.0
# 2809            31.0       21.0  367.0   274.0    93.0  1.0
# 3076            21.0       21.0  349.0   266.0    83.0  1.0
# 3343            31.0       19.0  387.0   261.0   126.0  3.0
# 3610            31.0       23.0  432.0   333.0    99.0  1.0
# 3877            23.0       20.0  292.0   234.0    58.0  1.0
# 4144            17.0       22.0  274.0   229.0    45.0  1.0
# 4411            17.0       24.0  430.0   239.0   191.0  3.0
# 4945        4.0         2.42        -2.04         2.93   Philadelphia Eagles
# 5212        1.0        17.23        -6.11        -7.78  New England Patriots
# 5479        1.0       -36.42        -4.38         9.42  Tampa Bay Buccaneers
# 5738        3.0        -2.76         2.27         3.96  New England Patriots
# 5997        5.0        -9.78        34.16         0.70       New York Giants
# 6256        NaN        13.14       -13.42        -1.52      Tennessee Titans
# 6507        4.0        13.73        14.96        -9.82       Atlanta Falcons
# 6758        3.0         4.51        -3.91         7.71        Denver Broncos
# 7009        NaN       -13.48         2.10        -4.54     Green Bay Packers
# 7260        NaN       -12.15        -3.32         0.20   Pittsburgh Steelers
# 7495        NaN        -3.94       -27.02         4.06   San Francisco 49ers
#
#                     home_t
# 402       Los Angeles Rams
# 671     Kansas City Chiefs
# 940    San Francisco 49ers
# 1207  New England Patriots
# 1474   Philadelphia Eagles
# 1741  New England Patriots
# 2008     Carolina Panthers
# 2275  New England Patriots
# 2542      Seattle Seahawks
# 2809      Baltimore Ravens
# 3076       New York Giants
# 3343   Pittsburgh Steelers
# 3610    New Orleans Saints
# 3877   Pittsburgh Steelers
# 4144       New York Giants
# 4411    Indianapolis Colts
# 4678      Seattle Seahawks
# 4945  New England Patriots
# 5212     Carolina Panthers
# 5479     Las Vegas Raiders
# 5738      Los Angeles Rams
# 5997      Baltimore Ravens
# 6256      Los Angeles Rams
# 6507        Denver Broncos
# 6758     Green Bay Packers
# 7009  New England Patriots
# 7260        Dallas Cowboys
# 7495  Los Angeles Chargers

# %% [markdown]
# ### Converting Missing Values and Categorical Data Types

# %%
df.isnull().sum()
# Out:
# season                  0
# team                    0
# week                    0
# day                     0
# date                    0
# time                    0
# result                  0
# ot                   7039
# record                  0
# home_team            3763
# opp                     0
# points_scored           0
# points_allowed          0
# 1st_downs               0
# totyd                   0
# passyd                  1
# rushyd                  0
# to                   1818
# 1st_downs_allowed       0
# totyd_allowed           0
# passyd_allowed          1
# rushyd_allowed          0
# to_forced            1469
# off_exp_pts             0
# def_exp_pts             0
# sts_exp_pts             0
# away_t                  0
# home_t                  0
# dtype: int64

# %%
df.dtypes
# Out:
# season                 int64
# team                  object
# week                  object
# day                   object
# date                  object
# time                  object
# result                object
# ot                    object
# record                object
# home_team             object
# opp                   object
# points_scored        float64
# points_allowed       float64
# 1st_downs            float64
# totyd                float64
# passyd               float64
# rushyd               float64
# to                   float64
# 1st_downs_allowed    float64
# totyd_allowed        float64
# passyd_allowed       float64
# rushyd_allowed       float64
# to_forced            float64
# off_exp_pts          float64
# def_exp_pts          float64
# sts_exp_pts          float64
# away_t                object
# home_t                object
# dtype: object

# %%
# convert NaN values for columns "ot" (overtime), "to" (turnovers), and "to_forced" to the integer 0.
df['ot'] = df['ot'].fillna(0)
df['to'] = df['to'].fillna(0)
df['to_forced'] = df['to_forced'].fillna(0)

# %%
# convert misc values for columns "home/away" (home team?) and "ot" (overtime) to a binary integer
df.loc[df["home_team"] == "@", "home_team"] = 0
df.loc[df["home_team"] == "N", "home_team"] = 0
df.loc[df["ot"] == "OT", "ot"] = 1

# %%
# changing the data types for some of the object columns
df[["ot"]] = df[["ot"]].apply(pd.to_numeric)

# %%
# convert NaN values for columns "home/away" (home team?) to the integer 1.
df['home_team'] = df['home_team'].fillna(1)

# %%
# checking how many rows still have missing values in them
df[df.isnull().any(axis=1)]
# Out:
#       season               team week  day         date       time result ot  \
# 3476    2009      New York Jets   17  Sun    January 3  8:31PM ET      W  0
# 5085    2003  Las Vegas Raiders   17  Sun  December 28  4:15PM ET      L  0
#
#      record  home_team                   opp  points_scored  points_allowed  \
# 3476    9-7          1    Cincinnati Bengals           37.0             0.0
# 5085   4-12          0  Los Angeles Chargers           14.0            21.0
#
#       1st_downs  totyd  passyd  rushyd   to  1st_downs_allowed  totyd_allowed  \
# 3476       21.0  320.0    63.0   257.0  0.0                5.0           72.0
# 5085        9.0  141.0     NaN   141.0  1.0               20.0          337.0
#
#       passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
# 3476             NaN            72.0        3.0        10.82        33.61
# 5085            74.0           263.0        0.0       -25.91        -1.64
#
#       sts_exp_pts              away_t                home_t
# 3476        -6.11  Cincinnati Bengals         New York Jets
# 5085        16.75   Las Vegas Raiders  Los Angeles Chargers

# %%
# converting the last four missing values to zero. The net passing yards equaled zero due to sacks.
df['passyd'] = df['passyd'].fillna(0)
df['passyd_allowed'] = df['passyd_allowed'].fillna(0)

# %%
# verifying the data types in the df
df.dtypes
# Out:
# season                 int64
# team                  object
# week                  object
# day                   object
# date                  object
# time                  object
# result                object
# ot                    object
# record                object
# home_team              int64
# opp                   object
# points_scored        float64
# points_allowed       float64
# 1st_downs            float64
# totyd                float64
# passyd               float64
# rushyd               float64
# to                   float64
# 1st_downs_allowed    float64
# totyd_allowed        float64
# passyd_allowed       float64
# rushyd_allowed       float64
# to_forced            float64
# off_exp_pts          float64
# def_exp_pts          float64
# sts_exp_pts          float64
# away_t                object
# home_t                object
# dtype: object

# %%
# checking how many rows still have missing values in them
len(df[df.isnull().any(axis=1)])
# Out:
# 0

# %% [markdown]
# ### Converting Date and Time columns

# %%
# "day" of the week needs to be converted into an integer.
day_dict = {"Tue":1, "Wed":2, "Thu":3, "Fri":4, "Sat":5, "Sun":6, "Mon":7}

# using the manually created day_dictionary to replace the day of the week.
df = df.replace({"day_of_week": day_dict})

# %%
df['year'] = df['season']

# %%
# date need to be converted into a numerical value (month and day_of_month)
c = []
v = []
for i in df['date']:
    c.append((i.split(' ')[0]))
    v.append(int(i.split(' ')[1]))
df = df.assign(month = c)
df = df.assign(day = v)

# %%
# "month of the year needs to be converted into an integer. NFL games start in August (preseason) and end in February (super bowl).
month_dict = {"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, 
            "July":7, "August":8, "September":9, "October":10, "November":11, "December":12}

# using the manually created day_dictionary to replace the day of the week.
df = df.replace({"month": month_dict})

# %%
# we can drop the date column after converting it
df = df.drop('date', axis=1)

# %%
# time needs to be converted into a numerical value
b = []
for i in df['time']:
    if 'PM' in i:
        b.append(int(i[0]) + 12)
    else:
        b.append(int(i[0]))
df = df.assign(hour = b)

# %%
# we can drop the time column after converting it
df = df.drop('time', axis=1)

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# %%
df
# Out:
#       season                  team       week  day result ot record  \
# 0       2022         Buffalo Bills          1    8      W  0    1-0
# 1       2022         New York Jets          1   11      L  0    0-1
# 2       2022        Miami Dolphins          1   11      W  0    1-0
# 3       2022    Cincinnati Bengals          1   11      L  1    0-1
# 4       2022      Cleveland Browns          1   11      W  0    1-0
# ...      ...                   ...        ...  ...    ... ..    ...
# 7495    1994  Los Angeles Chargers  SuperBowl   29      L  0   13-6
# 7496    1994        Miami Dolphins  Wild Card   31      W  0   11-6
# 7497    1994  New England Patriots  Wild Card    1      L  0   10-7
# 4       13 2022-09-11 13:00:00           24.0            26.0          15.0
# ...    ...                 ...            ...             ...           ...
# 7495    18 1994-01-29 18:00:00           26.0            49.0          20.0
# 7496    16 1994-12-31 16:00:00           27.0            17.0          22.0
# 7497    13 1994-01-01 13:00:00           20.0            13.0          22.0
# 7498    16 1994-01-01 16:00:00           18.0            35.0          22.0
# 7499    13 1994-12-31 13:00:00           16.0            12.0          18.0
#
#       ht_1st_downs_allowed  ht_totyd  ht_totyd_allowed
# 0                     23.0     243.0             413.0
# 1                     13.0     380.0             274.0
# 2                     17.0     307.0             271.0
# 3                     13.0     432.0             267.0
# 4                     23.0     261.0             355.0
# ...                    ...       ...               ...
# 7495                  28.0     354.0             455.0
# 7496                  24.0     381.0             414.0
# 7497                  20.0     379.0             303.0
# 7498                  18.0     389.0             308.0
# 7499                   9.0     336.0             171.0
#
# [7500 rows x 36 columns]

# %%
# verifying the data types in the df
df.dtypes
# Out:
# season                           int64
# team                            object
# week                            object
# day                              int64
# result                          object
# ot                              object
# record                          object
# home_team                        int64
# opp                             object
# points_scored                  float64
# points_allowed                 float64
# 1st_downs                      float64
# totyd                          float64
# passyd                         float64
# rushyd                         float64
# to                             float64
# 1st_downs_allowed              float64
# totyd_allowed                  float64
# passyd_allowed                 float64
# rushyd_allowed                 float64
# to_forced                      float64
# off_exp_pts                    float64
# def_exp_pts                    float64
# sts_exp_pts                    float64
# away_t                          object
# home_t                          object
# year                             int64
# month                            int64
# hour                             int64
# date                    datetime64[ns]
# ht_pts_scored                  float64
# ht_pts_allowed                 float64
# ht_1st_downs                   float64
# ht_1st_downs_allowed           float64
# ht_totyd                       float64
# ht_totyd_allowed               float64
# dtype: object

# %%
# we now have to create columns so that it is home_team_pts_scored, home_team_pts_allowed, etc.
ht_pts_scored = []
ht_pts_allowed = [] 
ht_1st_downs = []
ht_1st_downs_allowed = []
ht_totyd = []
ht_passyd = []
ht_rushyd = [] 
ht_to = []
ht_totyd_allowed = []
ht_passyd_allowed = []
ht_rushyd_allowed = []
ht_to_forced = []

counter = 0

for i in df['team']:
    if df['team'].iloc[counter] == df['home_t'].iloc[counter]:
        ht_pts_scored.append(df['points_scored'].iloc[counter])
        ht_pts_allowed.append(df['points_allowed'].iloc[counter])
        ht_1st_downs.append(df['1st_downs'].iloc[counter])
        ht_1st_downs_allowed.append(df['1st_downs_allowed'].iloc[counter])
        ht_totyd.append(df['totyd'].iloc[counter])
        ht_totyd_allowed.append(df['totyd_allowed'].iloc[counter])
        ht_passyd.append(df['passyd'].iloc[counter])
        ht_passyd_allowed.append(df['passyd_allowed'].iloc[counter])
        ht_rushyd.append(df['rushyd'].iloc[counter])
        ht_rushyd_allowed.append(df['rushyd_allowed'].iloc[counter])
        ht_to.append(df['to'].iloc[counter])
        ht_to_forced.append(df['to_forced'].iloc[counter])
    else:
        ht_pts_scored.append(df['points_allowed'].iloc[counter])
        ht_pts_allowed.append(df['points_scored'].iloc[counter])
        ht_1st_downs.append(df['1st_downs_allowed'].iloc[counter])
        ht_1st_downs_allowed.append(df['1st_downs'].iloc[counter])
        ht_totyd.append(df['totyd_allowed'].iloc[counter])
        ht_totyd_allowed.append(df['totyd'].iloc[counter])
        ht_passyd.append(df['passyd_allowed'].iloc[counter])
        ht_passyd_allowed.append(df['passyd'].iloc[counter])
        ht_rushyd.append(df['rushyd_allowed'].iloc[counter])
        ht_rushyd_allowed.append(df['rushyd'].iloc[counter])
        ht_to.append(df['to_forced'].iloc[counter])
        ht_to_forced.append(df['to'].iloc[counter])
    counter += 1

# %%
ht_pts_scored[:5]
# Out:
# [10.0, 9.0, 20.0, 20.0, 24.0]

# %%
df = df.assign(ht_pts_scored = ht_pts_scored)
df = df.assign(ht_pts_allowed = ht_pts_allowed)
df = df.assign(ht_1st_downs = ht_1st_downs)
df = df.assign(ht_totyd = ht_totyd)
df = df.assign(ht_passyd = ht_passyd)
df = df.assign(ht_rushyd = ht_rushyd)
df = df.assign(ht_to = ht_to)
df = df.assign(ht_1st_downs_allowed = ht_1st_downs_allowed)
df = df.assign(ht_totyd_allowed = ht_totyd_allowed)
df = df.assign(ht_passyd_allowed = ht_passyd_allowed)
df = df.assign(ht_rushyd_allowed = ht_rushyd_allowed)
df = df.assign(ht_to_forced = ht_to_forced)

# %%
df
# Out:
#       season                  team       week  day result ot record  \
# 0       2022         Buffalo Bills          1    8      W  0    1-0
# 1       2022         New York Jets          1   11      L  0    0-1
# 2       2022        Miami Dolphins          1   11      W  0    1-0
# 3       2022    Cincinnati Bengals          1   11      L  1    0-1
# 4       2022      Cleveland Browns          1   11      W  0    1-0
# ...      ...                   ...        ...  ...    ... ..    ...
# 7495    1994  Los Angeles Chargers  SuperBowl   29      L  0   13-6
# 7496    1994        Miami Dolphins  Wild Card   31      W  0   11-6
# 7497    1994  New England Patriots  Wild Card    1      L  0   10-7
# 7498    1994     Minnesota Vikings  Wild Card    1      L  0   10-7
# 7499    1994     Green Bay Packers  Wild Card   31      W  0   10-7
#
#       home_team                   opp  points_scored  points_allowed  \
# 0             0      Los Angeles Rams           31.0            10.0
# 1             1      Baltimore Ravens            9.0            24.0
# 2             1  New England Patriots           20.0             7.0
# 3             1   Pittsburgh Steelers           20.0            23.0
# 4             0     Carolina Panthers           26.0            24.0
# ...         ...                   ...            ...             ...
# 7495          0   San Francisco 49ers           26.0            49.0
# 7496          1    Kansas City Chiefs           27.0            17.0
# 7497          0      Cleveland Browns           13.0            20.0
# 7498          1         Chicago Bears           18.0            35.0
# 7499          1         Detroit Lions           16.0            12.0
#
#       1st_downs  totyd  passyd  rushyd   to  1st_downs_allowed  totyd_allowed  \
# 0          23.0  413.0   292.0   121.0  4.0               19.0          243.0
# 1          24.0  380.0   297.0    83.0  2.0               13.0          274.0
# 2          18.0  307.0   242.0    65.0  0.0               17.0          271.0
# 3          32.0  432.0   299.0   133.0  5.0               13.0          267.0
# 4          23.0  355.0   138.0   217.0  0.0               15.0          261.0
# ...         ...    ...     ...     ...  ...                ...            ...
# 7495       20.0  354.0   287.0    67.0  3.0               28.0          455.0
# 7496       22.0  381.0   249.0   132.0  0.0               24.0          414.0
# 7497       20.0  303.0   246.0    57.0  3.0               22.0          379.0
# 7498       22.0  389.0   340.0    49.0  4.0               18.0          308.0
# 7499       18.0  336.0   255.0    81.0  0.0                9.0          171.0
#
#       passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
#
# 0       3.0              292.0              121.0           4.0
# 1       2.0              211.0               63.0           1.0
# 2       0.0              193.0               78.0           3.0
# 3       5.0              192.0               75.0           0.0
# 4       1.0              138.0              217.0           0.0
# ...     ...                ...                ...           ...
# 7495    3.0              316.0              139.0           0.0
# 7496    0.0              314.0              100.0           2.0
# 7497    1.0              246.0               57.0           3.0
# 7498    4.0              214.0               94.0           2.0
# 7499    0.0              175.0               -4.0           0.0
#
# [7500 rows x 42 columns]

# %%
# we probably need to develop 'home_team_record' and 'away_team_record' columns, but it might be too difficult to engineer

# %% [markdown]
# ### Creating the Target feature

# %%
# we have to create a target feature 'home_team_wins', where 0 = home team did not win, 1 = home team won
ht_wins = []
counter = 0

for i in df['result']:
    if df['team'].iloc[counter] == df['home_t'].iloc[counter]:
        if i == 'W':
            ht_wins.append(1)
        else:
            ht_wins.append(0)
        counter += 1
    else:
        if i == 'W':
            ht_wins.append(0)
        else:
            ht_wins.append(1)
        counter += 1

# %%
df = df.assign(ht_wins = ht_wins)

# %%
df
# Out:
#       season                  team       week  day result ot record  \
# 0       2022         Buffalo Bills          1    8      W  0    1-0
# 1       2022         New York Jets          1   11      L  0    0-1
# 2       2022        Miami Dolphins          1   11      W  0    1-0
# 3       2022    Cincinnati Bengals          1   11      L  1    0-1
# 4       2022      Cleveland Browns          1   11      W  0    1-0
# ...      ...                   ...        ...  ...    ... ..    ...
# 7495    1994  Los Angeles Chargers  SuperBowl   29      L  0   13-6
# 7496    1994        Miami Dolphins  Wild Card   31      W  0   11-6
# 7497    1994  New England Patriots  Wild Card    1      L  0   10-7
# 7498    1994     Minnesota Vikings  Wild Card    1      L  0   10-7
# 7499    1994     Green Bay Packers  Wild Card   31      W  0   10-7
#
#       home_team                   opp  points_scored  points_allowed  \
# 0             0      Los Angeles Rams           31.0            10.0
# 1             1      Baltimore Ravens            9.0            24.0
# 2             1  New England Patriots           20.0             7.0
# 3             1   Pittsburgh Steelers           20.0            23.0
# 4             0     Carolina Panthers           26.0            24.0
# ...         ...                   ...            ...             ...
# 7495          0   San Francisco 49ers           26.0            49.0
# 7496          1    Kansas City Chiefs           27.0            17.0
# 7497          0      Cleveland Browns           13.0            20.0
# 7498          1         Chicago Bears           18.0            35.0
# 7499          1         Detroit Lions           16.0            12.0
#
#       1st_downs  totyd  passyd  rushyd   to  1st_downs_allowed  totyd_allowed  \
# 0          23.0  413.0   292.0   121.0  4.0               19.0          243.0
# 1          24.0  380.0   297.0    83.0  2.0               13.0          274.0
# 2          18.0  307.0   242.0    65.0  0.0               17.0          271.0
# 3          32.0  432.0   299.0   133.0  5.0               13.0          267.0
# 4          23.0  355.0   138.0   217.0  0.0               15.0          261.0
# ...         ...    ...     ...     ...  ...                ...            ...
# 7495       20.0  354.0   287.0    67.0  3.0               28.0          455.0
# 7496       22.0  381.0   249.0   132.0  0.0               24.0          414.0
# 7497       20.0  303.0   246.0    57.0  3.0               22.0          379.0
# 7498       22.0  389.0   340.0    49.0  4.0               18.0          308.0
# 7499       18.0  336.0   255.0    81.0  0.0                9.0          171.0
#
#       passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
#
# ...     ...                ...                ...           ...      ...
# 7495    3.0              316.0              139.0           0.0        0
# 7496    0.0              314.0              100.0           2.0        1
# 7497    1.0              246.0               57.0           3.0        1
# 7498    4.0              214.0               94.0           2.0        0
# 7499    0.0              175.0               -4.0           0.0        1
#
# [7500 rows x 43 columns]

# %%
df.dtypes
# Out:
# season                           int64
# week                            object
# day                              int64
# ot                               int64
# away_t                          object
# home_t                          object
# year                             int64
# month                            int64
# hour                             int64
# date                    datetime64[ns]
# ht_pts_scored                  float64
# ht_pts_allowed                 float64
# ht_1st_downs                   float64
# ht_1st_downs_allowed           float64
# ht_totyd                       float64
# ht_totyd_allowed               float64
# ht_passyd                      float64
# ht_rushyd                      float64
# ht_to                          float64
# ht_passyd_allowed              float64
# ht_rushyd_allowed              float64
# ht_to_forced                   float64
# ht_wins                          int64
# dtype: object

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df = df.drop(['record', 'team', 'result', 'home_team', 'opp', 'points_scored', 'points_allowed', '1st_downs', 
              'totyd', 'passyd', 'rushyd', 'to', '1st_downs_allowed', 'totyd_allowed', 'passyd_allowed', 
              'rushyd_allowed', 'to_forced', 'off_exp_pts', 'def_exp_pts', 'sts_exp_pts', 'year'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-614c1494ae52> in <module>
# ----> 1 df = df.drop(['record', 'team', 'result', 'home_team', 'opp', 'points_scored', 'points_allowed', '1st_downs',
#       2               'totyd', 'passyd', 'rushyd', 'to', '1st_downs_allowed', 'totyd_allowed', 'passyd_allowed',
#       3               'rushyd_allowed', 'to_forced', 'off_exp_pts', 'def_exp_pts', 'sts_exp_pts', 'year'], axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5386                 weight  1.0     0.8
#    5387         """
# -> 5388         return super().drop(
#    5389             labels=labels,
#    5390             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6973         if mask.any():
#    6974             if errors != "ignore":
# -> 6975                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6976             indexer = indexer[~mask]
#    6977         return self.delete(indexer)
#
# KeyError: "['record', 'team', 'result', 'home_team', 'opp', 'points_scored', 'points_allowed', '1st_downs', 'totyd', 'passyd', 'rushyd', 'to', '1st_downs_allowed', 'totyd_allowed', 'passyd_allowed', 'rushyd_allowed', 'to_forced', 'off_exp_pts', 'def_exp_pts', 'sts_exp_pts'] not found in axis"

# %%
df.dtypes
# Out:
# season                           int64
# week                            object
# day                              int64
# ot                               int64
# away_t                          object
# home_t                          object
# year                             int64
# month                            int64
# hour                             int64
# date                    datetime64[ns]
# ht_pts_scored                  float64
# ht_pts_allowed                 float64
# ht_1st_downs                   float64
# ht_1st_downs_allowed           float64
# ht_totyd                       float64
# ht_totyd_allowed               float64
# ht_passyd                      float64
# ht_rushyd                      float64
# ht_to                          float64
# ht_passyd_allowed              float64
# ht_rushyd_allowed              float64
# ht_to_forced                   float64
# ht_wins                          int64
# dtype: object

# %% [markdown]
# ### Feature Engineering

# %%
# the goal is to obtain a new column that contains rolling_averages for a team over the last four games.
# should the end of a season reset the rolling percentage??? Yes
# creating a df that is organized at the team and season level
grouped_teams = df.groupby("home_t")

# %%
# viewing one instance
group_arz = grouped_teams.get_group("Arizona Cardinals")
