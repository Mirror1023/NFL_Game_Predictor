# %% [markdown]
# # Data Preparation

# %%
# common imports
import requests
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sys
from datetime import datetime

sys.executable
# Out:
# '/opt/anaconda3/bin/python'

# %%
sys.path
# Out:
# ['/Users/mirror/Desktop/GitHub/NFL_Game_Predictor',
#  '/opt/anaconda3/lib/python38.zip',
#  '/opt/anaconda3/lib/python3.8',
#  '/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/Users/mirror/.local/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/mirror/.ipython']

# %%
# Importing data from csv file
path = "/Users/mirror/Desktop/GitHub/nfl_game_predictor/data/scraped_data.csv"
df = pd.read_csv(path)

# %% [markdown]
# ### Quick Exploration

# %%
df.shape
# Out:
# (15000, 26)

# %%
df.dtypes
# Out:
# season                 int64
# team                  object
# week                  object
# day                   object
# date                  object
# time                  object
# result                object
# ot                    object
# record                object
# home_team             object
# opp                   object
# points_scored        float64
# points_allowed       float64
# 1st_downs            float64
# totyd                float64
# passyd               float64
# rushyd               float64
# to                   float64
# 1st_downs_allowed    float64
# totyd_allowed        float64
# passyd_allowed       float64
# rushyd_allowed       float64
# to_forced            float64
# off_exp_pts          float64
# def_exp_pts          float64
# sts_exp_pts          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# season                   0
# team                     0
# week                     0
# day                      0
# date                     0
# time                     0
# result                   0
# ot                   14078
# record                   0
# home_team             7472
# opp                      0
# points_scored            0
# points_allowed           0
# 1st_downs                0
# totyd                    0
# passyd                   2
# rushyd                   0
# to                    3287
# 1st_downs_allowed        0
# totyd_allowed            0
# passyd_allowed           2
# rushyd_allowed           0
# to_forced             3287
# off_exp_pts              0
# def_exp_pts              0
# sts_exp_pts              0
# dtype: int64

# %%
df['ot'].isnull().sum()
# Out:
# 14078

# %%
# discovering how many times an opponent played a game
df.opp.value_counts()
# Out:
# New England Patriots        506
# Green Bay Packers           498
# Pittsburgh Steelers         493
# Indianapolis Colts          489
# Philadelphia Eagles         487
# Seattle Seahawks            485
# San Francisco 49ers         484
# Denver Broncos              480
# Kansas City Chiefs          478
# Minnesota Vikings           477
# Dallas Cowboys              477
# New Orleans Saints          476
# Atlanta Falcons             475
# New York Giants             474
# Tampa Bay Buccaneers        474
# New York Jets               471
# Miami Dolphins              470
# Arizona Cardinals           469
# Chicago Bears               468
# Buffalo Bills               468
# Cincinnati Bengals          468
# Detroit Lions               463
# Carolina Panthers           458
# Jacksonville Jaguars        455
# Baltimore Ravens            452
# Washington Redskins         423
# Cleveland Browns            414
# Oakland Raiders             408
# Tennessee Titans            394
# San Diego Chargers          382
# St. Louis Rams              346
# Houston Texans              339
# Los Angeles Rams            130
# Los Angeles Chargers         90
# Houston Oilers               48
# Las Vegas Raiders            41
# Washington Football Team     34
# Tennessee Oilers             32
# Los Angeles Raiders          16
# Washington Commanders         8
# Name: opp, dtype: int64

# %%
# importing a new library that was recommended to me by my mentor
import sweetviz as sv

df_report = sv.analyze(df)
df_report.show_html()
#df_report.show_notebook()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=27.0), HTML(value='')), layout=Layout(dis…
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_text.py:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in to_process.source_counts["value_counts_without_nan"].iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_text.py:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in to_process.source_counts["value_counts_without_nan"].iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_text.py:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in to_process.source_counts["value_counts_without_nan"].iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# compares two dataframes via sweetviz
#df_comp = sv.compare(df)

# %%
# another way to get great insights is to use the comparison functionality to split your dataset into 2 sub-populations.
#df_comp_intra = sv.compare_intra(df)

# %% [markdown]
# ### Initial data cleansing

# %%
# there are only supposed to be 32 teams in the NFL. some teams have changed their name and/or location.
len(df.opp.unique())
# Out:
# 40

# %%
# some teams have changed their name and/or location, which created another opponent.
# manually replacing team names.
df.loc[df["opp"] == "Washington Redskins", "opp"] = "Washington Commanders"
df.loc[df["opp"] == "Washington Football Team", "opp"] = "Washington Commanders"
df.loc[df["opp"] == "Oakland Raiders", "opp"] = "Las Vegas Raiders"
df.loc[df["opp"] == "Los Angeles Raiders", "opp"] = "Las Vegas Raiders"
df.loc[df["opp"] == "Houston Oilers", "opp"] = "Tennessee Titans"
df.loc[df["opp"] == "Tennessee Oilers", "opp"] = "Tennessee Titans"
df.loc[df["opp"] == "San Diego Chargers", "opp"] = "Los Angeles Chargers"
df.loc[df["opp"] == "St. Louis Rams", "opp"] = "Los Angeles Rams"

# %%
# verifying that there are only 32 teams in the df.opp column now.
len(df.opp.unique())
# Out:
# 32

# %% [markdown]
# ### Converting Missing Values and Categorical Data Types

# %%
# convert misc values for columns "home/away" (home team?) and "ot" (overtime) to a binary integer
df.loc[df["home_team"] == "@", "home_team"] = 0
df.loc[df["home_team"] == "N", "home_team"] = 0
df.loc[df["ot"] == "OT", "ot"] = 1

# %%
# convert NaN values for columns "home/away" (home team?) to the integer 1.
df['home_team'] = df['home_team'].fillna(1)

# %%
# convert NaN values for columns "ot" (overtime), "to" (turnovers), and "to_forced" to the integer 0.
df['ot'] = df['ot'].fillna(0)
df['to'] = df['to'].fillna(0)
df['to_forced'] = df['to_forced'].fillna(0)

# %%
# convert playoff games to follow week numbers (wildcard = 19, divisional = 20, and so on... for seasons 2021).
# but remember - before 2021, teams only played 17 week regular seasons, so wildcard would be = to 18 for these years. 
# For the seasons of 2021 and beyond, teams play an 18 week season.
w = []
y = df.loc[df['season'] == 2021]
for i in y['week']:
    if i == 'Wild Card':
        w.append(19)
    elif i == 'Division':
        w.append(20)
    elif i == 'Conf. Champ.':
        w.append(21)
    elif i == 'SuperBowl':
        w.append(23)
    else:
        w.append(int(i))

dfy = df.loc[df['season'] == 2021].assign(week = w)
dfy
# Out:
#      season team  week  day          date       time result  ot record  \
# 248    2021  BUF     1  Sun  September 12  1:00PM ET      L   0    0-1
# 249    2021  BUF     2  Sun  September 19  1:00PM ET      W   0    1-1
# 250    2021  BUF     3  Sun  September 26  1:00PM ET      W   0    2-1
# 251    2021  BUF     4  Sun     October 3  1:00PM ET      W   0    3-1
# 252    2021  BUF     5  Sun    October 10  8:20PM ET      W   0    4-1
# ..      ...  ...   ...  ...           ...        ...    ...  ..    ...
# 813    2021  SEA    14  Sun   December 12  1:00PM ET      W   0    5-8
# 814    2021  SEA    15  Tue   December 21  7:00PM ET      L   0    5-9
# 815    2021  SEA    16  Sun   December 26  4:05PM ET      L   0   5-10
# 816    2021  SEA    17  Sun     January 2  4:25PM ET      W   0   6-10
# 817    2021  SEA    18  Sun     January 9  4:25PM ET      W   0   7-10
#
#      home_team  ... rushyd   to  1st_downs_allowed  totyd_allowed  \
# 248          1  ...  117.0  1.0               16.0          252.0
# 249          0  ...  143.0  2.0               13.0          216.0
# 250          1  ...  122.0  0.0               13.0          290.0
# 251          1  ...  199.0  1.0                6.0          109.0
# 252          0  ...  121.0  0.0               29.0          392.0
# ..         ...  ...    ...  ...                ...            ...
# 813          0  ...  193.0  0.0               25.0          380.0
# 814          0  ...   80.0  1.0               20.0          332.0
# 815          1  ...  170.0  0.0               26.0          317.0
# 816          1  ...  265.0  0.0               20.0          357.0
# 817          0  ...  202.0  2.0               20.0          305.0
#
#      passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
# 248           177.0            75.0        0.0        -3.55         0.54
# 249           145.0            71.0        3.0         8.16        24.67
# 250           212.0            78.0        3.0        20.55         8.27
# 251            61.0            48.0        5.0        14.54        32.68
# 252           272.0           120.0        4.0        19.84         1.20
# ..              ...             ...        ...          ...          ...
# 813           317.0            63.0        0.0        21.71         2.60
# 814           209.0           123.0        1.0        -8.13        -4.19
# 815           229.0            88.0        0.0         8.31        -7.60
# 816           262.0            95.0        3.0        32.32        -3.55
# 817           187.0           118.0        1.0        12.83        -0.21
#
#      sts_exp_pts
# 248        -5.01
# 249        -0.37
# 250        -7.29
# 251        -6.40
# 252        -1.50
# ..           ...
# 813        -9.75
# 814         3.72
# 815        -3.95
# 816        -2.68
# 817        -1.02
#
# [570 rows x 26 columns]

# %%
# convert playoff games to follow week numbers (wildcard = 19, divisional = 20, and so on... for seasons 2021).
# but remember - before 2021, teams only played 17 week regular seasons, so wildcard would be = to 18 for these years. 
# For the seasons of 2021 and beyond, teams play an 18 week season.
e = []
r = df.loc[df['season'] != 2021]
for i in r['week']:
    if i == 'Wild Card':
        e.append(18)
    elif i == 'Division':
        e.append(19)
    elif i == 'Conf. Champ.':
        e.append(20)
    elif i == 'SuperBowl':
        e.append(22)
    else:
        e.append(int(i))

dfe = df.loc[df['season'] != 2021].assign(week = e)
dfe
# Out:
#        season team  week  day          date       time result  ot record  \
# 0        2022  BUF     1  Thu   September 8  8:20PM ET      W   0    1-0
# 1        2022  BUF     2  Mon  September 19  7:15PM ET      W   0    2-0
# 2        2022  BUF     3  Sun  September 25  1:00PM ET      L   0    2-1
# 3        2022  BUF     4  Sun     October 2  1:00PM ET      W   0    3-1
# 4        2022  BUF     5  Sun     October 9  1:00PM ET      W   0    4-1
# ...       ...  ...   ...  ...           ...        ...    ...  ..    ...
# 14995    1994  LAR    13  Sun   November 27  4:00PM ET      L   0    4-8
# 14996    1994  LAR    14  Sun    December 4  4:00PM ET      L   0    4-9
# 14997    1994  LAR    15  Sun   December 11  1:00PM ET      L   0   4-10
# 14998    1994  LAR    16  Sun   December 18  1:00PM ET      L   0   4-11
# 14999    1994  LAR    17  Sat   December 24  4:00PM ET      L   0   4-12
#
#        home_team  ... rushyd   to  1st_downs_allowed  totyd_allowed  \
# 0              0  ...  121.0  4.0               19.0          243.0
# 1              1  ...  101.0  0.0               12.0          187.0
# 2              0  ...  115.0  1.0               15.0          212.0
# 3              0  ...  125.0  2.0               22.0          296.0
# 4              1  ...  120.0  2.0               23.0          364.0
# ...          ...  ...    ...  ...                ...            ...
# 14995          0  ...   48.0  5.0               16.0          243.0
# 14996          1  ...   75.0  4.0               20.0          328.0
# 14997          0  ...   63.0  2.0               17.0          355.0
# 14998          0  ...   37.0  1.0               19.0          298.0
# 14999          1  ...   77.0  1.0               19.0          288.0
#
#        passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
# 0               191.0            52.0        3.0        13.89        10.29
# 1               107.0            80.0        4.0        17.69        18.01
# 2               171.0            41.0        0.0        15.88        -7.45
# 3               134.0           162.0        2.0         2.10         2.66
# 4               310.0            54.0        2.0        20.66         9.42
# ...               ...             ...        ...          ...          ...
# 14995           129.0           114.0        1.0       -15.08        12.27
# 14996           191.0           137.0        1.0        -1.17        -3.52
# 14997           230.0           125.0        0.0       -11.84       -12.38
# 14998           135.0           163.0        0.0        -1.42        -6.17
# 14999           138.0           150.0        1.0        -2.22         4.36
#
#        sts_exp_pts
# 0            -3.96
# 1             1.55
# 2            -4.86
# 3            -1.69
# 4             3.54
# ...            ...
# 14995        -6.03
# 14996       -13.22
# 14997         5.25
# 14998        -8.99
# 14999        -3.89
#
# [14430 rows x 26 columns]

# %%
# combining the dataframes back together and sorting based on index.
df = pd.concat([dfy, dfe])
df = df.sort_index()

# %%
# game's "result" needs to be converted into an integer
df.loc[df["result"] == "W", "result"] = 1
df.loc[df["result"] == "T", "result"] = 0
df.loc[df["result"] == "L", "result"] = 0

# %%
# changing the data types for some of the object columns
df[["result", "home_team"]] = df[["result", "home_team"]].apply(pd.to_numeric)

# %%
# dropping bye week rows, playoff rows, etc.
df = df[df['result'].notna()]

# %%
# checking how many rows still have missing values in them
df[df.isnull().any(axis=1)]
# Out:
#        season team  week  day         date       time  result  ot record  \
# 6728     2009  NYJ    17  Sun    January 3  8:31PM ET       1   0    9-7
# 6779     2009  CIN    17  Sun    January 3  8:31PM ET       0   0   10-6
# 10150    2003   LV    17  Sun  December 28  4:15PM ET       0   0   4-12
# 10166    2003  LAC    17  Sun  December 28  4:15PM ET       1   0   4-12
#
#        home_team  ... rushyd   to  1st_downs_allowed  totyd_allowed  \
# 6728           1  ...  257.0  0.0                5.0           72.0
# 6779           0  ...   72.0  3.0               21.0          320.0
# 10150          0  ...  141.0  1.0               20.0          337.0
# 10166          1  ...  263.0  0.0                9.0          141.0
#
#        passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
# 6728              NaN            72.0        3.0        10.82        33.61
# 6779             63.0           257.0        0.0       -33.61       -10.82
# 10150            74.0           263.0        0.0       -25.91        -1.64
# 10166             NaN           141.0        1.0         1.64        25.91
#
#        sts_exp_pts
# 6728         -6.11
# 6779          6.11
# 10150        16.75
# 10166       -16.75
#
# [4 rows x 26 columns]

# %%
# converting the last four missing values to zero. The net passing yards equaled zero due to sacks.
df['passyd'] = df['passyd'].fillna(0)
df['passyd_allowed'] = df['passyd_allowed'].fillna(0)

# %%
# verifying the data types in the df
df.dtypes
# Out:
# season                 int64
# team                  object
# week                   int64
# day                   object
# date                  object
# time                  object
# result                 int64
# ot                     int64
# record                object
# home_team              int64
# opp                   object
# points_scored        float64
# points_allowed       float64
# 1st_downs            float64
# totyd                float64
# passyd               float64
# rushyd               float64
# to                   float64
# 1st_downs_allowed    float64
# totyd_allowed        float64
# passyd_allowed       float64
# rushyd_allowed       float64
# to_forced            float64
# off_exp_pts          float64
# def_exp_pts          float64
# sts_exp_pts          float64
# dtype: object

# %%
# checking how many rows still have missing values in them
len(df[df.isnull().any(axis=1)])
# Out:
# 0

# %% [markdown]
# ### Converting Date and Time columns

# %%
# "day" of the week needs to be converted into an integer.
day_dict = {"Tue":1, "Wed":2, "Thu":3, "Fri":4, "Sat":5, "Sun":6, "Mon":7}

# using the manually created day_dictionary to replace the day of the week.
df = df.replace({"day_of_week": day_dict})

# %%
df['year'] = df['season']

# %%
# date need to be converted into a numerical value (month and day_of_month)
c = []
v = []
for i in df['date']:
    c.append((i.split(' ')[0]))
    v.append(int(i.split(' ')[1]))
df = df.assign(month = c)
df = df.assign(day = v)

# %%
# "month of the year needs to be converted into an integer. NFL games start in August (preseason) and end in February (super bowl).
month_dict = {"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, 
            "July":7, "August":8, "September":9, "October":10, "November":11, "December":12}

# using the manually created day_dictionary to replace the day of the week.
df = df.replace({"month": month_dict})

# %%
# we can drop the date column after converting it
df = df.drop('date', axis=1)

# %%
# time needs to be converted into a numerical value
b = []
for i in df['time']:
    if 'PM' in i:
        b.append(int(i[0]) + 12)
    else:
        b.append(int(i[0]))
df = df.assign(hour = b)

# %%
# we can drop the time column after converting it
df = df.drop('time', axis=1)

# %%
# record need to be converted into a numerical value (cumulative wins and cumulative losses)
y = []
z = []
for i in df['record']:
    y.append(int(i.split('-')[0]))
    z.append(int(i.split('-')[1]))
df = df.assign(win_count = y)
df = df.assign(loss_count = z)

# we can drop the record column after converting it
df = df.drop('record', axis=1)

# %%
################# verify that these numerical codes correspond to the df["team"] #################
# converting opponent's team name to a nurmerical category
# we need to verify that the opp_code matches with the team_code. Each team should be labeled with identical opp and team codes.
df["opp_code"] = df["opp"].astype("category").cat.codes
df["team_code"] = df["team"].astype("category").cat.codes

# %%
df.loc[df['team'] == 'LAC'].head(50)
# Out:
#       season team  week  day  result  ot  home_team                    opp  \
# 101     2022  LAC     1   11       1   0          1      Las Vegas Raiders
# 102     2022  LAC     2   15       0   0          0     Kansas City Chiefs
# 103     2022  LAC     3   25       0   0          1   Jacksonville Jaguars
# 104     2022  LAC     4    2       1   0          0         Houston Texans
# 105     2022  LAC     5    9       1   0          0       Cleveland Browns
# 106     2022  LAC     6   17       1   1          1         Denver Broncos
# 107     2022  LAC     7   23       0   0          1       Seattle Seahawks
# 499     2021  LAC     1   12       1   0          0  Washington Commanders
# 500     2021  LAC     2   19       0   0          1         Dallas Cowboys
# 501     2021  LAC     3   26       1   0          0     Kansas City Chiefs
# 502     2021  LAC     4    4       1   0          1      Las Vegas Raiders
# 503     2021  LAC     5   10       1   0          1       Cleveland Browns
# 504     2021  LAC     6   17       0   0          0       Baltimore Ravens
# 505     2021  LAC     8   31       0   0          1   New England Patriots
# 506     2021  LAC     9    7       1   0          0    Philadelphia Eagles
# 507     2021  LAC    10   14       0   0          1      Minnesota Vikings
# 508     2021  LAC    11   21       1   0          1    Pittsburgh Steelers
# 509     2021  LAC    12   28       0   0          0         Denver Broncos
# 510     2021  LAC    13    5       1   0          0     Cincinnati Bengals
# 511     2021  LAC    14   12       1   0          1        New York Giants
# 512     2021  LAC    15   16       0   1          1     Kansas City Chiefs
# 513     2021  LAC    16   26       0   0          0         Houston Texans
# 514     2021  LAC    17    2       1   0          1         Denver Broncos
# 515     2021  LAC    18    9       0   1          0      Las Vegas Raiders
# 1055    2020  LAC     1   13       1   0          0     Cincinnati Bengals
# 1056    2020  LAC     2   20       0   1          1     Kansas City Chiefs
# 1057    2020  LAC     3   27       0   0          1      Carolina Panthers
# 1058    2020  LAC     4    4       0   0          0   Tampa Bay Buccaneers
# 1059    2020  LAC     5   12       0   1          0     New Orleans Saints
# 1060    2020  LAC     7   25       1   0          1   Jacksonville Jaguars
# 1061    2020  LAC     8    1       0   0          0         Denver Broncos
# 1062    2020  LAC     9    8       0   0          1      Las Vegas Raiders
# 1063    2020  LAC    10   15       0   0          0         Miami Dolphins
# 1064    2020  LAC    11   22       1   0          1          New York Jets
# 1065    2020  LAC    12   29       0   0          0          Buffalo Bills
# 1066    2020  LAC    13    6       0   0          1   New England Patriots
# 1067    2020  LAC    14   13       1   0          1        Atlanta Falcons
# 1068    2020  LAC    15   17       1   1          0      Las Vegas Raiders
# 1069    2020  LAC    16   27       1   0          1         Denver Broncos
# 1070    2020  LAC    17    3       1   0          0     Kansas City Chiefs
# 1607    2019  LAC     1    8       1   1          1     Indianapolis Colts
# 1608    2019  LAC     2   15       0   0          0          Detroit Lions
# 1609    2019  LAC     3   22       0   0          1         Houston Texans
# 1610    2019  LAC     4   29       1   0          0         Miami Dolphins
# 1611    2019  LAC     5    6       0   0          1         Denver Broncos
# 1612    2019  LAC     6   13       0   0          1    Pittsburgh Steelers
# 1613    2019  LAC     7   20       0   0          0       Tennessee Titans
# 1614    2019  LAC     8   27       1   0          0          Chicago Bears
# 1615    2019  LAC     9    3       1   0          1      Green Bay Packers
# 1616    2019  LAC    10    7       0   0          0      Las Vegas Raiders
#
#       points_scored  points_allowed  ...  off_exp_pts  def_exp_pts  \
# 101            24.0            19.0  ...         6.30         2.73
# 102            24.0            27.0  ...         4.12        -5.54
# 103            10.0            38.0  ...       -10.35       -18.06
# 104            34.0            24.0  ...        16.95        -3.13
# 105            30.0            28.0  ...        16.01       -16.53
# 106            19.0            16.0  ...        -1.03         3.11
# 107            23.0            37.0  ...        -4.60       -12.13
# 499            20.0            16.0  ...         9.45        -1.45
# 500            17.0            20.0  ...         5.55       -17.50
# 501            30.0            24.0  ...        16.65        -9.49
# 502            28.0            14.0  ...        11.99         7.95
# 503            47.0            42.0  ...        31.81       -22.52
# 504             6.0            34.0  ...       -13.93        -7.50
# 505            24.0            27.0  ...         1.35         1.47
# 506            27.0            24.0  ...        20.72       -17.56
# 507            20.0            27.0  ...         3.95        -8.75
# 508            41.0            37.0  ...        20.68        -7.04
# 509            13.0            28.0  ...        -6.58       -12.16
# 510            41.0            22.0  ...         1.98        12.31
# 511            37.0            21.0  ...        18.32         0.24
# 512            28.0            34.0  ...         6.23       -13.18
# 513            29.0            41.0  ...         5.49       -24.35
# 514            34.0            13.0  ...        15.09         7.80
# 515            32.0            35.0  ...        16.16       -11.13
# 1055           16.0            13.0  ...        -2.07         8.27
# 1056           20.0            23.0  ...        13.33       -10.92
# 1057           16.0            21.0  ...        -5.44        -1.18
# 1058           31.0            38.0  ...         5.88       -12.95
# 1059           27.0            30.0  ...         6.80        -3.09
# 1060           39.0            29.0  ...        20.27         2.30
# 1061           30.0            31.0  ...         9.03        -8.64
# 1062           26.0            31.0  ...        17.58       -11.13
# 1063           21.0            29.0  ...        -1.88         7.96
# 1064           34.0            28.0  ...        16.66        -7.52
# 1065           17.0            27.0  ...         4.93        -5.65
# 1066            0.0            45.0  ...       -16.13        -9.66
# 1067           20.0            17.0  ...        10.14        -5.82
# 1068           30.0            27.0  ...        23.38       -16.83
# 1069           19.0            16.0  ...         1.63        -4.25
# 1070           38.0            21.0  ...        25.49       -10.71
# 1607           30.0            24.0  ...        15.32       -18.02
# 1608           10.0            13.0  ...         5.86        -8.62
# 1609           20.0            27.0  ...         6.08       -16.39
# 1610           30.0            10.0  ...        15.45        -0.41
# 1611           13.0            20.0  ...       -12.18         2.29
# 1612           17.0            24.0  ...        -2.12        -5.45
# 1613           20.0            23.0  ...         8.93       -10.83
# 1614           17.0            16.0  ...        -5.45        -0.44
# 1615           26.0            11.0  ...        16.68         5.74
# 1616           24.0            26.0  ...         0.55        -5.96
#
#       sts_exp_pts  year  month  hour  win_count  loss_count  opp_code  \
# 101         -1.95  2022      9    16          1           0        16
# 102         -3.72  2022      9    20          1           1        15
# 103          2.60  2022      9    16          1           2        14
# 104         -4.62  2022     10    13          2           2        12
# 105          4.92  2022     10    13          3           2         7
# 106          0.92  2022     10    20          4           2         9
# 107          1.10  2022     10    16          4           3        28
# 499         -1.24  2021      9    13          1           0        31
# 500         -1.81  2021      9    16          1           1         8
# 501         -3.01  2021      9    13          2           1        15
# 502         -2.22  2021     10    20          3           1        16
# 503         -3.45  2021     10    16          4           1         7
# 504         -4.48  2021     10    13          4           2         2
# 505         -9.98  2021     10    16          4           3        21
# 506         -1.49  2021     11    16          5           3        25
# 507         -2.56  2021     11    16          5           4        20
# 508         -7.92  2021     11    20          6           4        26
# 509         -1.43  2021     11    16          6           5         9
# 510          1.02  2021     12    13          7           5         6
# 511         -3.58  2021     12    16          8           5        23
# 512          1.57  2021     12    20          8           6        15
# 513          2.75  2021     12    13          8           7        12
# 514          1.00  2021      1    16          9           7         9
# 515         -8.69  2021      1    20          9           8        16
# 1055        -3.54  2020      9    16          1           0         6
# 1056        -3.80  2020      9    16          1           1        15
# 1057         0.62  2020      9    16          1           2         4
# 1058        -0.20  2020     10    13          1           3        29
# 1059        -7.44  2020     10    20          1           4        22
# 1060        -8.03  2020     10    16          2           4        14
# 1061        -1.18  2020     11    16          2           5         9
# 1062       -10.69  2020     11    16          2           6        16
# 1063       -14.67  2020     11    16          2           7        19
# 1064        -3.42  2020     11    16          3           7        24
# 1065        -4.65  2020     11    13          3           8         3
# 1066       -22.19  2020     12    16          3           9        21
# 1067        -1.54  2020     12    16          4           9         1
# 1068        -4.42  2020     12    20          5           9        16
# 1069         4.44  2020     12    16          6           9         9
# 1070         3.07  2020      1    16          7           9        15
# 1607         8.43  2019      9    16          1           0        13
# 1608        -0.56  2019      9    13          1           1        10
# 1609         1.94  2019      9    16          1           2        12
# 1610         3.89  2019      9    13          2           2        19
# 1611         0.78  2019     10    16          2           3         9
# 1612        -4.54  2019     10    20          2           4        26
# 1613        -0.57  2019     10    16          2           5        30
# 1614         6.02  2019     10    13          3           5         5
# 1615        -6.12  2019     11    16          4           5        11
# 1616         1.54  2019     11    20          4           6        16
#
#       team_code
# 101          16
# 102          16
# 103          16
# 104          16
# 105          16
# 106          16
# 107          16
# 499          16
# 500          16
# 501          16
# 502          16
# 503          16
# 504          16
# 505          16
# 506          16
# 507          16
# 508          16
# 509          16
# 510          16
# 511          16
# 512          16
# 513          16
# 514          16
# 515          16
# 1055         16
# 1056         16
# 1057         16
# 1058         16
# 1059         16
# 1060         16
# 1061         16
# 1062         16
# 1063         16
# 1064         16
# 1065         16
# 1066         16
# 1067         16
# 1068         16
# 1069         16
# 1070         16
# 1607         16
# 1608         16
# 1609         16
# 1610         16
# 1611         16
# 1612         16
# 1613         16
# 1614         16
# 1615         16
# 1616         16
#
# [50 rows x 30 columns]

# %%
# we can drop the opp and team columns after converting it into numerical codes.
df = df.drop('opp', axis=1)
df = df.drop('team', axis=1)

# %%
# Reordering the columns to my preference
cols = df.columns.tolist()
cols = cols[0:1] + cols[-1:] + cols[1:3] + cols[-7:-1] + cols[3:-7]
df = df[cols]
df
# Out:
#        season  team_code  week  day  year  month  hour  win_count  loss_count  \
# 0        2022          3     1    8  2022      9    20          1           0
# 1        2022          3     2   19  2022      9    19          2           0
# 2        2022          3     3   25  2022      9    13          2           1
# 3        2022          3     4    2  2022     10    13          3           1
# 4        2022          3     5    9  2022     10    13          4           1
# ...       ...        ...   ...  ...   ...    ...   ...        ...         ...
# 14995    1994         17    13   27  1994     11    16          4           8
# 14996    1994         17    14    4  1994     12    16          4           9
# 14997    1994         17    15   11  1994     12    13          4          10
# 14998    1994         17    16   18  1994     12    13          4          11
# 14999    1994         17    17   24  1994     12    16          4          12
#
#        opp_code  ...  rushyd   to  1st_downs_allowed  totyd_allowed  \
# 0            18  ...   121.0  4.0               19.0          243.0
# 1            30  ...   101.0  0.0               12.0          187.0
# 2            19  ...   115.0  1.0               15.0          212.0
# 3             2  ...   125.0  2.0               22.0          296.0
# 4            26  ...   120.0  2.0               23.0          364.0
# ...         ...  ...     ...  ...                ...            ...
# 14995        17  ...    48.0  5.0               16.0          243.0
# 14996        22  ...    75.0  4.0               20.0          328.0
# 14997        29  ...    63.0  2.0               17.0          355.0
# 14998         5  ...    37.0  1.0               19.0          298.0
# 14999        31  ...    77.0  1.0               19.0          288.0
#
#        passyd_allowed  rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  \
# 0               191.0            52.0        3.0        13.89        10.29
# 1               107.0            80.0        4.0        17.69        18.01
# 2               171.0            41.0        0.0        15.88        -7.45
# 3               134.0           162.0        2.0         2.10         2.66
# 4               310.0            54.0        2.0        20.66         9.42
# ...               ...             ...        ...          ...          ...
# 14995           129.0           114.0        1.0       -15.08        12.27
# 14996           191.0           137.0        1.0        -1.17        -3.52
# 14997           230.0           125.0        0.0       -11.84       -12.38
# 14998           135.0           163.0        0.0        -1.42        -6.17
# 14999           138.0           150.0        1.0        -2.22         4.36
#
#        sts_exp_pts
# 0            -3.96
# 1             1.55
# 2            -4.86
# 3            -1.69
# 4             3.54
# ...            ...
# 14995        -6.03
# 14996       -13.22
# 14997         5.25
# 14998        -8.99
# 14999        -3.89
#
# [15000 rows x 28 columns]

# %%
df.dtypes
# Out:
# season                 int64
# team_code               int8
# week                   int64
# day                    int64
# year                   int64
# month                  int64
# hour                   int64
# win_count              int64
# loss_count             int64
# opp_code                int8
# result                 int64
# ot                     int64
# home_team              int64
# points_scored        float64
# points_allowed       float64
# 1st_downs            float64
# totyd                float64
# passyd               float64
# rushyd               float64
# to                   float64
# 1st_downs_allowed    float64
# totyd_allowed        float64
# passyd_allowed       float64
# rushyd_allowed       float64
# to_forced            float64
# off_exp_pts          float64
# def_exp_pts          float64
# sts_exp_pts          float64
# dtype: object

# %%
#df['date'] =  pd.to_datetime(df['date'], format='%b%d')

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# %%
df.dtypes
# Out:
# season                        int64
# team_code                      int8
# week                          int64
# day                           int64
# year                          int64
# month                         int64
# hour                          int64
# win_count                     int64
# loss_count                    int64
# opp_code                       int8
# result                        int64
# ot                            int64
# home_team                     int64
# points_scored               float64
# points_allowed              float64
# 1st_downs                   float64
# totyd                       float64
# passyd                      float64
# rushyd                      float64
# to                          float64
# 1st_downs_allowed           float64
# totyd_allowed               float64
# passyd_allowed              float64
# rushyd_allowed              float64
# to_forced                   float64
# off_exp_pts                 float64
# def_exp_pts                 float64
# sts_exp_pts                 float64
# date                 datetime64[ns]
# dtype: object

# %%
df
# Out:
#        season  team_code  week  day  year  month  hour  win_count  loss_count  \
# 0        2022          3     1    8  2022      9    20          1           0
# 1        2022          3     2   19  2022      9    19          2           0
# 2        2022          3     3   25  2022      9    13          2           1
# 3        2022          3     4    2  2022     10    13          3           1
# 4        2022          3     5    9  2022     10    13          4           1
# ...       ...        ...   ...  ...   ...    ...   ...        ...         ...
# 14995    1994         17    13   27  1994     11    16          4           8
# 14996    1994         17    14    4  1994     12    16          4           9
# 14997    1994         17    15   11  1994     12    13          4          10
# 14998    1994         17    16   18  1994     12    13          4          11
# 14999    1994         17    17   24  1994     12    16          4          12
#
#        opp_code  ...   to  1st_downs_allowed  totyd_allowed  passyd_allowed  \
# 0            18  ...  4.0               19.0          243.0           191.0
# 1            30  ...  0.0               12.0          187.0           107.0
# 2            19  ...  1.0               15.0          212.0           171.0
# 3             2  ...  2.0               22.0          296.0           134.0
# 4            26  ...  2.0               23.0          364.0           310.0
# ...         ...  ...  ...                ...            ...             ...
# 14995        17  ...  5.0               16.0          243.0           129.0
# 14996        22  ...  4.0               20.0          328.0           191.0
# 14997        29  ...  2.0               17.0          355.0           230.0
# 14998         5  ...  1.0               19.0          298.0           135.0
# 14999        31  ...  1.0               19.0          288.0           138.0
#
#        rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  sts_exp_pts  \
# 0                52.0        3.0        13.89        10.29        -3.96
# 1                80.0        4.0        17.69        18.01         1.55
# 2                41.0        0.0        15.88        -7.45        -4.86
# 3               162.0        2.0         2.10         2.66        -1.69
# 4                54.0        2.0        20.66         9.42         3.54
# ...               ...        ...          ...          ...          ...
# 14995           114.0        1.0       -15.08        12.27        -6.03
# 14996           137.0        1.0        -1.17        -3.52       -13.22
# 14997           125.0        0.0       -11.84       -12.38         5.25
# 14998           163.0        0.0        -1.42        -6.17        -8.99
# 14999           150.0        1.0        -2.22         4.36        -3.89
#
#                      date
# 0     2022-09-08 20:00:00
# 1     2022-09-19 19:00:00
# 2     2022-09-25 13:00:00
# 3     2022-10-02 13:00:00
# 4     2022-10-09 13:00:00
# ...                   ...
# 14995 1994-11-27 16:00:00
# 14996 1994-12-04 16:00:00
# 14997 1994-12-11 13:00:00
# 14998 1994-12-18 13:00:00
# 14999 1994-12-24 16:00:00
#
# [15000 rows x 29 columns]

# %% [markdown]
# ### Feature Engineering

# %%
# the goal is to obtain a new column that contains rolling_averages for a team over the last four games.
# should the end of a season reset the rolling percentage??? Yes
# creating a df that is organized at the team and season level
grouped_teams = df.groupby("team_code")

# %%
# viewing one instance
group1 = grouped_teams.get_group(1)
group1
# Out:
#        season  team_code  week  day  year  month  hour  win_count  loss_count  \
# 185      2022          1     1   11  2022      9    13          0           1
# 186      2022          1     2   18  2022      9    16          0           2
# 187      2022          1     3   25  2022      9    16          1           2
# 188      2022          1     4    2  2022     10    13          2           2
# 189      2022          1     5    9  2022     10    13          2           3
# ...       ...        ...   ...  ...   ...    ...   ...        ...         ...
# 14979    1994          1    13   27  1994     11    13          6           6
# 14980    1994          1    14    4  1994     12    16          6           7
# 14981    1994          1    15   11  1994     12    20          6           8
# 14982    1994          1    16   18  1994     12    13          6           9
# 14983    1994          1    17   24  1994     12    13          7           9
#
#        opp_code  ...   to  1st_downs_allowed  totyd_allowed  passyd_allowed  \
# 185          22  ...  2.0               18.0          385.0           234.0
# 186          18  ...  3.0               24.0          337.0           272.0
# 187          28  ...  2.0               23.0          420.0           308.0
# 188           7  ...  1.0               22.0          403.0           226.0
# 189          29  ...  0.0               26.0          420.0           351.0
# ...         ...  ...  ...                ...            ...             ...
# 14979        25  ...  3.0               14.0          318.0           203.0
# 14980        27  ...  5.0               28.0          476.0           315.0
# 14981        22  ...  1.0               19.0          402.0           264.0
# 14982        11  ...  2.0               23.0          384.0           310.0
# 14983         0  ...  1.0               18.0          385.0           313.0
#
#        rushyd_allowed  to_forced  off_exp_pts  def_exp_pts  sts_exp_pts  \
# 185             151.0        1.0         7.50        -4.62         0.51
# 186              65.0        3.0        -3.49        -8.46         8.11
# 187             112.0        1.0        20.84       -15.09         1.20
# 188             177.0        2.0         5.92        -5.25         1.44
# 189              69.0        0.0         3.90       -13.30         1.34
# ...               ...        ...          ...          ...          ...
# 14979           115.0        2.0        -9.04        12.82        -2.86
# 14980           161.0        1.0       -16.65       -15.35         1.22
# 14981           138.0        0.0         9.09       -13.55        -3.68
# 14982            74.0        1.0         4.46        -9.31         2.71
# 14983            72.0        2.0        -4.05         8.63        -6.35
#
#                      date
# 185   2022-09-11 13:00:00
# 186   2022-09-18 16:00:00
# 187   2022-09-25 16:00:00
# 188   2022-10-02 13:00:00
# 189   2022-10-09 13:00:00
# ...                   ...
# 14979 1994-11-27 13:00:00
# 14980 1994-12-04 16:00:00
# 14981 1994-12-11 20:00:00
# 14982 1994-12-18 13:00:00
# 14983 1994-12-24 13:00:00
#
# [475 rows x 29 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(4, closed='left').mean() # closed='left' inside rolling parameters
    # the problem is that it is using the fourth games' info to predict the fourth game and beyond.
    # closed='left' would solve this problem, but that requires datetime. How do I resolve this???
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["result", "points_scored", "points_allowed",
        "totyd", "to", "totyd_allowed", "to_forced",
        "off_exp_pts", "def_exp_pts", "sts_exp_pts"]

new_cols = [f"{c}_rolling" for c in cols]

# %%
# first four weeks are being dropped because of na values from rolling(4)
# should we bring datetime back??
rolling_averages(group1, cols, new_cols)
# Out:
#        season  team_code  week  day  year  month  hour  win_count  loss_count  \
# 14972    1994          1     5    2  1994     10    16          3           2
# 14973    1994          1     6    9  1994     10    13          4           2
# 14974    1994          1     7   16  1994     10    13          4           3
# 14975    1994          1     8   23  1994     10    16          4           4
# 14976    1994          1    10    6  1994     11    13          5           4
# ...       ...        ...   ...  ...   ...    ...   ...        ...         ...
# 188      2022          1     4    2  2022     10    13          2           2
# 189      2022          1     5    9  2022     10    13          2           3
# 190      2022          1     6   16  2022     10    13          3           3
# 191      2022          1     7   23  2022     10    13          3           4
# 192      2022          1     8   30  2022     10    13          4           4
#
#        opp_code  ...  result_rolling  points_scored_rolling  \
# 14972        18  ...            0.50                  24.00
# 14973        29  ...            0.75                  19.00
# 14974        27  ...            0.75                  19.75
# 14975        16  ...            0.75                  18.00
# 14976        17  ...            0.50                  15.50
# ...         ...  ...             ...                    ...
# 188           7  ...            0.50                  25.00
# 189          29  ...            0.50                  25.75
# 190          27  ...            0.50                  23.00
# 191           6  ...            0.75                  23.25
# 192           4  ...            0.50                  20.75
#
#        points_allowed_rolling  totyd_rolling  to_rolling  \
# 14972                   23.50         377.50        2.25
# 14973                   17.00         371.75        2.50
# 14974                   17.00         353.75        2.75
# 14975                   20.00         321.25        2.75
# 14976                   22.50         307.75        3.00
# ...                       ...            ...         ...
# 188                     24.25         329.25        2.00
# 189                     25.25         349.00        2.00
# 190                     23.75         310.25        1.50
# 191                     19.50         317.25        0.75
# 192                     22.50         274.25        0.25
#
#        totyd_allowed_rolling  to_forced_rolling  off_exp_pts_rolling  \
# 14972                 388.50               3.50               4.2750
# 14973                 362.00               3.75               1.6875
# 14974                 336.75               3.50              -3.7350
# 14975                 300.25               2.50             -10.8675
# 14976                 290.00               1.50              -9.5000
# ...                      ...                ...                  ...
# 188                   370.00               1.50               7.5675
# 189                   386.25               1.75               7.6925
# 190                   395.00               1.50               6.7925
# 191                   397.25               1.50              10.5550
# 192                   426.50               1.25               6.1425
#
#        def_exp_pts_rolling  sts_exp_pts_rolling
# 14972               2.3575              -4.1050
# 14973               6.7875              -3.5875
# 14974              10.0575              -2.4250
# 14975               8.0200              -2.3575
# 14976               6.0425              -3.0400
# ...                    ...                  ...
# 188                -8.6825               3.0125
# 189                -8.3550               2.8150
# 190               -10.5250               3.0225
# 191                -8.5575               0.5725
# 192               -13.0475               1.8550
#
# [471 rows x 39 columns]

# %%
#apply the new rolling_averages columns to each group
df_rolling = df.groupby(["team_code", "season"]).apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
df_rolling
# Out:
#                         season  team_code  week  day  year  month  hour  \
# team_code season
# 0         1994   14803    1994          0     6    9  1994     10    16
#                  14804    1994          0     7   16  1994     10    13
#                  14805    1994          0     8   23  1994     10    16
#                  14806    1994          0     9   30  1994     10    20
#                  14807    1994          0    10    6  1994     11    16
# ...                        ...        ...   ...  ...   ...    ...   ...
# 31        2021   583      2021         31    16   26  2021     12    20
#           2022   151      2022         31     5    9  2022     10    13
#                  152      2022         31     6   13  2022     10    20
#                  153      2022         31     7   23  2022     10    13
#                  154      2022         31     8   30  2022     10    16
#
#                         win_count  loss_count  opp_code  ...  result_rolling  \
# team_code season                                         ...
# 0         1994   14803          1           4         8  ...            0.25
#                  14804          2           4        31  ...            0.25
#                  14805          2           5         8  ...            0.50
#                  14806          3           5        26  ...            0.50
#                  14807          3           6        25  ...            0.50
# ...                           ...         ...       ...  ...             ...
# 31        2021   583            6           9         8  ...            0.50
#           2022   151            1           4        30  ...            0.25
#                  152            2           4         5  ...            0.00
#                  153            3           4        11  ...            0.25
#                  154            4           4        13  ...            0.50
#
#                         points_scored_rolling  points_allowed_rolling  \
# team_code season
# 0         1994   14803                  11.50                   18.25
#                  14804                   9.25                   24.25
#                  14805                   9.75                   23.25
#                  14806                  15.00                   22.25
#                  14807                  15.75                   24.75
# ...                                       ...                     ...
# 31        2021   583                    17.75                   21.00
#           2022   151                    18.25                   26.75
#                  152                    15.50                   26.50
#                  153                    11.75                   19.25
#                  154                    15.50                   18.50
#
#                         totyd_rolling  to_rolling  totyd_allowed_rolling  \
# team_code season
# 0         1994   14803         258.75        2.75                 259.50
#                  14804         255.50        3.25                 309.25
#                  14805         293.00        3.25                 316.25
#                  14806         292.25        2.50                 313.75
#                  14807         298.75        2.25                 303.50
# ...                               ...         ...                    ...
# 31        2021   583           282.50        1.50                 354.75
#           2022   151           330.75        1.75                 371.75
#                  152           329.50        1.25                 336.25
#                  153           284.00        1.00                 327.75
#                  154           315.00        1.00                 285.75
#
#                         to_forced_rolling  off_exp_pts_rolling  \
# team_code season
# 0         1994   14803               2.50             -14.1225
#                  14804               2.00             -16.9475
#                  14805               2.75             -17.5550
#                  14806               2.25             -10.5900
#                  14807               2.00             -10.1350
# ...                                   ...                  ...
# 31        2021   583                 1.25              -2.9050
#           2022   151                 0.25              -4.0950
#                  152                 0.00              -6.2225
#                  153                 0.50              -9.4900
#                  154                 0.75              -4.7425
#
#                         def_exp_pts_rolling  sts_exp_pts_rolling
# team_code season
# 0         1994   14803               7.6750               2.9600
#                  14804               0.2700               3.9425
#                  14805               7.3875               1.8750
#                  14806               5.3700               2.3050
#                  14807               3.6550               0.7575
# ...                                     ...                  ...
# 31        2021   583                -1.2000               1.2875
#           2022   151                -6.1525               0.5475
#                  152                -5.3050              -0.4250
#                  153                -2.9675               3.7075
#                  154                -1.0125               1.6200
#
# [11348 rows x 39 columns]

# %%
# dropping extra index levels
df_rolling = df_rolling.droplevel('team_code')
df_rolling = df_rolling.droplevel('season')
df_rolling
# Out:
#        season  team_code  week  day  year  month  hour  win_count  loss_count  \
# 14803    1994          0     6    9  1994     10    16          1           4
# 14804    1994          0     7   16  1994     10    13          2           4
# 14805    1994          0     8   23  1994     10    16          2           5
# 14806    1994          0     9   30  1994     10    20          3           5
# 14807    1994          0    10    6  1994     11    16          3           6
# ...       ...        ...   ...  ...   ...    ...   ...        ...         ...
# 583      2021         31    16   26  2021     12    20          6           9
# 151      2022         31     5    9  2022     10    13          1           4
# 152      2022         31     6   13  2022     10    20          2           4
# 153      2022         31     7   23  2022     10    13          3           4
# 154      2022         31     8   30  2022     10    16          4           4
#
#        opp_code  ...  result_rolling  points_scored_rolling  \
# 14803         8  ...            0.25                  11.50
# 14804        31  ...            0.25                   9.25
# 14805         8  ...            0.50                   9.75
# 14806        26  ...            0.50                  15.00
# 14807        25  ...            0.50                  15.75
# ...         ...  ...             ...                    ...
# 583           8  ...            0.50                  17.75
# 151          30  ...            0.25                  18.25
# 152           5  ...            0.00                  15.50
# 153          11  ...            0.25                  11.75
# 154          13  ...            0.50                  15.50
#
#        points_allowed_rolling  totyd_rolling  to_rolling  \
# 14803                   18.25         258.75        2.75
# 14804                   24.25         255.50        3.25
# 14805                   23.25         293.00        3.25
# 14806                   22.25         292.25        2.50
# 14807                   24.75         298.75        2.25
# ...                       ...            ...         ...
# 583                     21.00         282.50        1.50
# 151                     26.75         330.75        1.75
# 152                     26.50         329.50        1.25
# 153                     19.25         284.00        1.00
# 154                     18.50         315.00        1.00
#
#        totyd_allowed_rolling  to_forced_rolling  off_exp_pts_rolling  \
# 14803                 259.50               2.50             -14.1225
# 14804                 309.25               2.00             -16.9475
# 14805                 316.25               2.75             -17.5550
# 14806                 313.75               2.25             -10.5900
# 14807                 303.50               2.00             -10.1350
# ...                      ...                ...                  ...
# 583                   354.75               1.25              -2.9050
# 151                   371.75               0.25              -4.0950
# 152                   336.25               0.00              -6.2225
# 153                   327.75               0.50              -9.4900
# 154                   285.75               0.75              -4.7425
#
#        def_exp_pts_rolling  sts_exp_pts_rolling
# 14803               7.6750               2.9600
# 14804               0.2700               3.9425
# 14805               7.3875               1.8750
# 14806               5.3700               2.3050
# 14807               3.6550               0.7575
# ...                    ...                  ...
# 583                -1.2000               1.2875
# 151                -6.1525               0.5475
# 152                -5.3050              -0.4250
# 153                -2.9675               3.7075
# 154                -1.0125               1.6200
#
# [11348 rows x 39 columns]

# %%
# resetting the index for the df
df_rolling.index = range(df_rolling.shape[0])
df_rolling.tail(50)
# Out:
#        season  team_code  week  day  year  month  hour  win_count  loss_count  \
# 11298    2018         31    10   11  2018     11    13          6           3
# 11299    2018         31    11   18  2018     11    13          6           4
# 11300    2018         31    12   22  2018     11    16          6           5
# 11301    2018         31    13    3  2018     12    20          6           6
# 11302    2018         31    14    9  2018     12    13          6           7
# 11303    2018         31    15   16  2018     12    13          7           7
# 11304    2018         31    16   22  2018     12    16          7           8
# 11305    2018         31    17   30  2018     12    16          7           9
# 11306    2019         31     5    6  2019     10    13          0           5
# 11307    2019         31     6   13  2019     10    13          1           5
# 11308    2019         31     7   20  2019     10    13          1           6
# 11309    2019         31     8   24  2019     10    20          1           7
# 11310    2019         31     9    3  2019     11    13          1           8
# 11311    2019         31    11   17  2019     11    13          1           9
# 11312    2019         31    12   24  2019     11    13          2           9
# 11313    2019         31    13    1  2019     12    13          3           9
# 11314    2019         31    14    8  2019     12    13          3          10
# 11315    2019         31    15   15  2019     12    13          3          11
# 11316    2019         31    16   22  2019     12    13          3          12
# 11317    2019         31    17   29  2019     12    16          3          13
# 11318    2020         31     3   27  2020      9    13          1           2
# 11319    2020         31     4    4  2020     10    13          1           3
# 11320    2020         31     5   11  2020     10    13          1           4
# 11321    2020         31     6   18  2020     10    13          1           5
# 11322    2020         31     7   25  2020     10    13          2           5
# 11323    2020         31     9    8  2020     11    13          2           6
# 11324    2020         31    10   15  2020     11    13          2           7
# 11325    2020         31    11   22  2020     11    13          3           7
# 11326    2020         31    12   26  2020     11    16          4           7
# 11327    2020         31    13    7  2020     12    17          5           7
# 11328    2020         31    14   13  2020     12    16          6           7
# 11329    2020         31    15   20  2020     12    13          6           8
# 11330    2020         31    16   27  2020     12    16          6           9
# 11331    2021         31     3   26  2021      9    13          1           2
# 11332    2021         31     4    3  2021     10    13          2           2
# 11333    2021         31     5   10  2021     10    13          2           3
# 11334    2021         31     6   17  2021     10    13          2           4
# 11335    2021         31     7   24  2021     10    13          2           5
# 11336    2021         31     8   31  2021     10    16          2           6
# 11337    2021         31    10   14  2021     11    13          3           6
# 11338    2021         31    11   21  2021     11    13          4           6
# 11339    2021         31    12   29  2021     11    20          5           6
# 11340    2021         31    13    5  2021     12    16          6           6
# 11341    2021         31    14   12  2021     12    13          6           7
# 11342    2021         31    15   21  2021     12    19          6           8
# 11343    2021         31    16   26  2021     12    20          6           9
# 11344    2022         31     5    9  2022     10    13          1           4
# 11345    2022         31     6   13  2022     10    20          2           4
# 11346    2022         31     7   23  2022     10    13          3           4
# 11347    2022         31     8   30  2022     10    16          4           4
#
#        opp_code  ...  result_rolling  points_scored_rolling  \
# 11298        29  ...            0.75                  19.25
# 11299        12  ...            0.75                  17.50
# 11300         8  ...            0.50                  17.75
# 11301        25  ...            0.25                  18.50
# 11302        23  ...            0.25                  18.25
# 11303        14  ...            0.00                  18.25
# 11304        30  ...            0.25                  17.00
# 11305        25  ...            0.25                  15.25
# 11306        21  ...            0.00                  16.50
# 11307        19  ...            0.00                  11.50
# 11308        27  ...            0.25                  10.50
# 11309        20  ...            0.25                   6.75
# 11310         3  ...            0.25                   8.25
# 11311        24  ...            0.25                   8.75
# 11312        10  ...            0.00                   8.75
# 11313         4  ...            0.25                  13.50
# 11314        11  ...            0.50                  18.50
# 11315        25  ...            0.50                  20.00
# 11316        23  ...            0.50                  22.50
# 11317         8  ...            0.25                  26.50
# 11318         7  ...            0.50                  21.25
# 11319         2  ...            0.25                  21.25
# 11320        18  ...            0.25                  19.75
# 11321        23  ...            0.00                  15.50
# 11322         8  ...            0.00                  16.50
# 11323        23  ...            0.25                  17.75
# 11324        10  ...            0.25                  18.50
# 11325         6  ...            0.25                  22.75
# 11326         8  ...            0.50                  23.00
# 11327        26  ...            0.50                  27.00
# 11328        27  ...            0.75                  27.75
# 11329        28  ...            1.00                  26.75
# 11330         4  ...            0.75                  25.50
# 11331         3  ...            0.50                  21.00
# 11332         1  ...            0.50                  22.25
# 11333        22  ...            0.50                  25.25
# 11334        15  ...            0.50                  26.75
# 11335        11  ...            0.25                  22.50
# 11336         9  ...            0.25                  19.75
# 11337        29  ...            0.00                  13.75
# 11338         4  ...            0.25                  15.50
# 11339        28  ...            0.50                  19.00
# 11340        16  ...            0.75                  20.75
# 11341         8  ...            1.00                  22.50
# 11342        25  ...            0.75                  20.25
# 11343         8  ...            0.50                  17.75
# 11344        30  ...            0.25                  18.25
# 11345         5  ...            0.00                  15.50
# 11346        11  ...            0.25                  11.75
# 11347        13  ...            0.50                  15.50
#
#        points_allowed_rolling  totyd_rolling  to_rolling  \
# 11298                   21.25         329.75        0.50
# 11299                   17.75         329.25        0.50
# 11300                   19.25         322.50        1.00
# 11301                   23.75         315.25        1.50
# 11302                   21.25         282.50        1.50
# 11303                   30.50         283.00        2.25
# 11304                   28.00         274.75        1.75
# 11305                   26.50         265.00        1.50
# 11306                   29.50         296.25        2.25
# 11307                   29.75         252.50        2.75
# 11308                   26.00         266.50        2.75
# 11309                   20.50         216.00        1.75
# 11310                   19.25         226.00        1.25
# 11311                   17.00         231.00        0.75
# 11312                   21.50         209.50        1.00
# 11313                   23.25         228.50        1.25
# 11314                   23.75         265.00        0.75
# 11315                   22.75         269.75        1.00
# 11316                   23.50         301.50        1.00
# 11317                   29.75         334.25        0.50
# 11318                   23.00         294.50        1.25
# 11319                   28.00         309.75        2.00
# 11320                   28.00         301.75        2.00
# 11321                   31.25         269.00        2.00
# 11322                   28.75         274.25        2.00
# 11323                   21.00         296.25        0.75
# 11324                   19.00         311.00        1.75
# 11325                   19.00         400.00        2.00
# 11326                   16.25         397.00        1.75
# 11327                   19.50         382.25        2.00
# 11328                   18.00         361.25        0.75
# 11329                   14.25         293.50        0.75
# 11330                   17.00         300.50        1.00
# 11331                   19.00         325.75        0.75
# 11332                   24.75         320.25        1.25
# 11333                   30.50         342.00        1.25
# 11334                   33.75         370.50        1.50
# 11335                   34.25         337.75        1.75
# 11336                   29.50         372.75        1.50
# 11337                   26.25         355.25        2.00
# 11338                   22.75         342.00        1.75
# 11339                   20.25         365.25        1.50
# 11340                   18.00         350.50        1.25
# 11341                   17.50         339.50        1.00
# 11342                   19.50         315.50        1.75
# 11343                   21.00         282.50        1.50
# 11344                   26.75         330.75        1.75
# 11345                   26.50         329.50        1.25
# 11346                   19.25         284.00        1.00
# 11347                   18.50         315.00        1.00
#
#        totyd_allowed_rolling  to_forced_rolling  off_exp_pts_rolling  \
# 11298                 366.75               2.00               2.0100
# 11299                 404.50               2.25               2.1575
# 11300                 403.75               2.50               0.4050
# 11301                 429.00               2.00               0.2725
# 11302                 415.25               2.00              -3.1525
# 11303                 390.50               1.25              -8.4575
# 11304                 358.50               1.00              -7.5850
# 11305                 330.25               1.00              -7.7050
# 11306                 399.25               1.50              -4.6150
# 11307                 400.75               1.75             -12.8300
# 11308                 350.00               2.00             -14.2900
# 11309                 346.25               2.00             -14.8550
# 11310                 357.50               1.25              -9.6850
# 11311                 314.00               1.00              -6.0000
# 11312                 346.25               1.00             -10.8850
# 11313                 366.50               1.75             -10.7475
# 11314                 327.50               2.00              -8.8350
# 11315                 345.75               2.25              -7.5850
# 11316                 349.50               2.00              -1.6250
# 11317                 396.50               1.00               6.2850
# 11318                 356.50               2.00              -2.4075
# 11319                 377.50               1.25              -1.4950
# 11320                 338.25               1.50              -2.1400
# 11321                 379.25               1.00              -4.4575
# 11322                 329.75               1.00              -3.9675
# 11323                 290.25               1.25               1.1125
# 11324                 290.25               0.75               1.1500
# 11325                 276.00               0.50               9.9800
# 11326                 284.00               0.75               9.3025
# 11327                 310.25               1.00               7.4875
# 11328                 304.25               1.25               5.0500
# 11329                 297.25               2.00              -4.7475
# 11330                 304.75               1.75              -4.1625
# 11331                 330.50               1.25               4.1200
# 11332                 368.25               1.25               1.4000
# 11333                 417.50               0.50               5.8800
# 11334                 403.75               0.50               3.6900
# 11335                 430.75               1.25              -0.7725
# 11336                 386.50               1.50               1.1975
# 11337                 361.25               1.75              -2.9025
# 11338                 337.25               1.75               1.4275
# 11339                 286.75               1.00               6.1625
# 11340                 277.50               1.00               7.8325
# 11341                 286.75               0.75               9.4500
# 11342                 299.25               0.75               0.5750
# 11343                 354.75               1.25              -2.9050
# 11344                 371.75               0.25              -4.0950
# 11345                 336.25               0.00              -6.2225
# 11346                 327.75               0.50              -9.4900
# 11347                 285.75               0.75              -4.7425
#
#        def_exp_pts_rolling  sts_exp_pts_rolling
# 11298              -7.6600               5.0150
# 11299              -6.4825               4.5575
# 11300              -6.0925               4.8050
# 11301              -9.8900               4.3275
# 11302              -5.2000               4.3975
# 11303              -7.1900               4.3475
# 11304              -4.3425               2.0925
# 11305              -4.2350               3.4925
# 11306             -12.7100               2.8075
# 11307             -10.5975               4.6025
# 11308              -2.3775               2.1775
# 11309               0.4275               1.4500
# 11310              -1.0375               0.9100
# 11311              -0.1500              -1.7850
# 11312              -5.0150               2.0125
# 11313              -3.3000               4.5800
# 11314              -0.6400               4.1475
# 11315              -0.4875               4.9800
# 11316              -2.9650               3.6525
# 11317             -13.2950               2.9250
# 11318               1.1825              -0.7850
# 11319              -3.8150              -1.9600
# 11320              -2.3725              -4.6800
# 11321              -9.5650              -2.0975
# 11322              -8.3700              -0.9900
# 11323              -2.5800              -3.2175
# 11324              -0.7825              -1.9000
# 11325              -1.5600              -5.9000
# 11326               2.3375              -5.4950
# 11327               3.0975              -2.6325
# 11328               4.9100              -0.6050
# 11329              15.1700               1.1625
# 11330              11.5150               0.2775
# 11331              -2.0900              -1.1375
# 11332              -4.8675               0.1800
# 11333             -14.9525               2.7975
# 11334             -14.7300               3.3400
# 11335             -14.4050               3.1300
# 11336             -11.4275               0.4800
# 11337              -7.8625              -1.0125
# 11338              -6.5250              -1.6975
# 11339              -5.8300              -1.3250
# 11340              -3.0250              -1.1025
# 11341              -3.3475              -0.4075
# 11342               0.4950              -0.0400
# 11343              -1.2000               1.2875
# 11344              -6.1525               0.5475
# 11345              -5.3050              -0.4250
# 11346              -2.9675               3.7075
# 11347              -1.0125               1.6200
#
# [50 rows x 39 columns]

# %% [markdown]
# ### SweetViz

# %%
df_report = sv.analyze(df_rolling)
#df_report.show_html()
#df_report.show_notebook()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=40.0), HTML(value='')), layout=Layout(dis…
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_text.py:19: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in to_process.source_counts["value_counts_without_nan"].iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_cat.py:28: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for item in category_counts.iteritems():
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()
# /opt/anaconda3/lib/python3.8/site-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   stats["mad"] = series.mad()

# %%
# compares two dataframes via sweetviz
#df_comp = sv.compare(df, df_rolling)
#df_comp.show_notebook()

# %%
# another way to get great insights is to use the comparison functionality to split your dataset into 2 sub-populations.
#df_comp_intra = sv.compare_intra(df_rolling)

# %%
# using pandas to convert the prepared dataframe into a csv file that is model ready.
df_rolling.to_csv("Data/transformed.csv", index=False)
